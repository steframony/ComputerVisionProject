# %% [markdown]
# # CARICAMENTO MODELLO

# %%
import torch
import torchvision
import torchvision
from functools import partial
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

def get_the_model(num_classes = 2):
    """
        Metodo per la creazione del modello

        :Params:
            : num_classes = rappresenta il numero di classi di output desiderate. 
    """
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn_v2(weights="DEFAULT")
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features,num_classes)
    return model

num_classes = 2 #[Palla e Background]
model = get_the_model(num_classes)

optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Device -> {device}")

model.to(device)

checkpoint_path = '/kaggle/input/result-faster-r-cnn/FASTER-R-CNN_finetuned_epoch-5.pth'

checkpoint = torch.load(checkpoint_path, map_location=torch.device(device))

model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

epoch = checkpoint['epoch']
losses = checkpoint['loss']

print(f"Ripristinato il modello dopo {epoch+1} epoche, con una perdita di {losses}.")
print(f"Nota che la loss è relativa all'ultimo batch dell'epoca e non è quella media.")
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100%|██████████| 167M/167M [00:00<00:00, 215MB/s]
# Device -> cuda
# <ipython-input-1-c851faf2f844>:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=torch.device(device))
# Ripristinato il modello dopo 5 epoche, con una perdita di 0.00832930114120245.
# Nota che la loss è relativa all'ultimo batch dell'epoca e non è quella media.

# %% [markdown]
# ## VISUALIZZAZIONE DI TEST PER UNA SINGOLA IMMAGINE

# %%
import os
import random
import torch
from PIL import Image
import matplotlib.pyplot as plt
from torchvision import transforms, models
from torchvision.io import read_image
from torchvision import transforms

if not torch.cuda.is_available():
    image_folder = '/kaggle/input/computer-vision-futbal/dataset/dataset/test/ID-5'
    
    model.eval()
    
    def load_image(image_folder, image_path=None):
        """
            Funzione per caricare una immagine, se image_path è nulla allora estrae un immagine random dalla cartella image_folder.
        """
        if image_path is None:
            image_files = [f for f in os.listdir(image_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
            random_image_file = random.choice(image_files)
            image_path = os.path.join(image_folder, random_image_file)
    
        image = Image.open(image_path)
        return image, image_path
    
    def show_image(image):
        image = Image.open(image).convert('RGB')
        plt.imshow(image)
        plt.axis('off')
        plt.show()
    
    image_path  = '/kaggle/input/computer-vision-futbal/dataset/dataset/test/ID-5/frame_2966.jpg'
    
    image, image_path = load_image(image_folder, image_path)
    
    #Stesse trasformazioni in fase di training
    transform = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    image = transform(image)
    
    print(f"Visualizzazzione dell'immagine: {image_path}")
    show_image(image_path)
    
    # Aggiunto una dimensione per il batch: [1, C, H, W]
    image_tensor = image.unsqueeze(0)
    
    with torch.no_grad():
        prediction = model(image_tensor)
    
    boxes = prediction[0]['boxes']
    labels = prediction[0]['labels']
    scores = prediction[0]['scores']
    
    print("Risultati dell'inferenza:")
    for i in range(len(boxes)):
        print(f"Box {i}: {boxes[i].tolist()}")
        print(f"Label {i}: {labels[i].item()} (probabilità: {scores[i].item():.4f})")
    
    fig, ax = plt.subplots(1)
    image_pil = Image.open(image_path).convert('RGB')
    ax.imshow(image_pil)
    
    for i, box in enumerate(boxes):
        if scores[i] > 0.5:
            xmin, ymin, xmax, ymax = box
            rect = plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                 linewidth=1, edgecolor='r', facecolor='none')
            ax.add_patch(rect)
    
    plt.axis('off')
    plt.show()
else:
    print("Skipping perchè siamo su GPU...")
# Out:
# Skipping perchè siamo su GPU...

# %% [markdown]
# # ANNOTAZIONI JSON

# %%
import os
import random
import json
import torch
from PIL import Image
from torchvision import transforms

def process_images(model, image_folder, output_file):

    """
       Per ogni immagine in image_folder esegue in inferenza e salva le previsioni.
       
    :Params:
        _model = Il modello usato;
        :image_folder = La cartella contenente le immagini da elaborare;
        :output_file = Il percorso del file dove salvare i risultati in formato JSON.
    """

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Usando device: {device}")

    model = model.to(device)
    model.eval()

    def load_image(image_folder, image_path=None):
        """
            Funzione per caricare una immagine, se image_path è nulla allora estrae un immagine random dalla cartella image_folder.
        """
        if image_path is None: 
            image_files = [f for f in os.listdir(image_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
            random_image_file = random.choice(image_files)
            image_path = os.path.join(image_folder, random_image_file)

        image = Image.open(image_path)
        return image, image_path

    def preprocess_image(image):
        """
            Metodo per richiamare le trasformazioni per rendere l'immagine a come è stata addestrata.
        """
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) 
        ])
        
        return transform(image)

    results = {}

    imgss = sorted([f for f in os.listdir(image_folder) if f.endswith(('.png', '.jpg', '.jpeg'))])

    for idx, image_file in enumerate(imgss):
        parti = image_file.split("_")
        numero_str = parti[1].split(".")[0]
        index = int(numero_str)
        
        print(f"Processing file: {image_file} with index:{index}")
        
        image_path = os.path.join(image_folder, image_file)
        image, _ = load_image(image_folder, image_path)
        image_tensor = preprocess_image(image).unsqueeze(0).to(device)
        
        with torch.no_grad():
            prediction = model(image_tensor)
        
        image_name = f"{index:05d}.jpg" 
        bboxes = []
        for box, score in zip(prediction[0]['boxes'], prediction[0]['scores']):
            bboxes.append({
                "bbox": box.tolist(),
                "score": score.item()
            })
        
        results[image_name] = bboxes

    with open(output_file, 'w') as f:
        json.dump(results, f, indent=4)

    print(f"Results saved in: {output_file}")

# %%
image_folder = '/kaggle/input/computer-vision-futbal/dataset/dataset/test/ID-5'
output_file = '/kaggle/working/bounding_boxes_5_model.json'
process_images(model, image_folder, output_file)
# Out:
# Usando device: cuda
# Processing file: frame_0.jpg with index:0
# Processing file: frame_1.jpg with index:1
# Processing file: frame_10.jpg with index:10
# Processing file: frame_100.jpg with index:100
# Processing file: frame_1000.jpg with index:1000
# Processing file: frame_1001.jpg with index:1001
# Processing file: frame_1002.jpg with index:1002
# Processing file: frame_1003.jpg with index:1003
# Processing file: frame_1004.jpg with index:1004
# Processing file: frame_1005.jpg with index:1005
# Processing file: frame_1006.jpg with index:1006
# Processing file: frame_1007.jpg with index:1007
# Processing file: frame_1008.jpg with index:1008
# Processing file: frame_1009.jpg with index:1009
# Processing file: frame_101.jpg with index:101
# Processing file: frame_1010.jpg with index:1010
# Processing file: frame_1011.jpg with index:1011
# Processing file: frame_1012.jpg with index:1012
# Processing file: frame_1013.jpg with index:1013
# Processing file: frame_1014.jpg with index:1014
# Processing file: frame_1015.jpg with index:1015
# Processing file: frame_1016.jpg with index:1016
# Processing file: frame_1017.jpg with index:1017
# Processing file: frame_1018.jpg with index:1018
# Processing file: frame_1019.jpg with index:1019
# Processing file: frame_102.jpg with index:102
# Processing file: frame_1020.jpg with index:1020
# Processing file: frame_1021.jpg with index:1021
# Processing file: frame_1022.jpg with index:1022
# Processing file: frame_1023.jpg with index:1023
# Processing file: frame_1024.jpg with index:1024
# Processing file: frame_1025.jpg with index:1025
# Processing file: frame_1026.jpg with index:1026
# Processing file: frame_1027.jpg with index:1027
# Processing file: frame_1028.jpg with index:1028
# Processing file: frame_1029.jpg with index:1029
# Processing file: frame_103.jpg with index:103
# Processing file: frame_1030.jpg with index:1030
# Processing file: frame_1031.jpg with index:1031
# Processing file: frame_1032.jpg with index:1032
# Processing file: frame_1033.jpg with index:1033
# Processing file: frame_1034.jpg with index:1034
# Processing file: frame_1035.jpg with index:1035
# Processing file: frame_1036.jpg with index:1036
# Processing file: frame_1037.jpg with index:1037
# Processing file: frame_1038.jpg with index:1038
# Processing file: frame_1039.jpg with index:1039
# Processing file: frame_104.jpg with index:104
# Processing file: frame_1040.jpg with index:1040
# Processing file: frame_1041.jpg with index:1041
# Processing file: frame_1042.jpg with index:1042
# Processing file: frame_1043.jpg with index:1043
# Processing file: frame_1044.jpg with index:1044
# Processing file: frame_1045.jpg with index:1045
# Processing file: frame_1046.jpg with index:1046
# Processing file: frame_1047.jpg with index:1047
# Processing file: frame_1048.jpg with index:1048
# Processing file: frame_1049.jpg with index:1049
# Processing file: frame_105.jpg with index:105
# Processing file: frame_1050.jpg with index:1050
# Processing file: frame_1051.jpg with index:1051
# Processing file: frame_1052.jpg with index:1052
# Processing file: frame_1053.jpg with index:1053
# Processing file: frame_1054.jpg with index:1054
# Processing file: frame_1055.jpg with index:1055
# Processing file: frame_1056.jpg with index:1056
# Processing file: frame_1057.jpg with index:1057
# Processing file: frame_1058.jpg with index:1058
# Processing file: frame_1059.jpg with index:1059
# Processing file: frame_106.jpg with index:106
# Processing file: frame_1060.jpg with index:1060
# Processing file: frame_1061.jpg with index:1061
# Processing file: frame_1062.jpg with index:1062
# Processing file: frame_1063.jpg with index:1063
# Processing file: frame_1064.jpg with index:1064
# Processing file: frame_1065.jpg with index:1065
# Processing file: frame_1066.jpg with index:1066
# Processing file: frame_1067.jpg with index:1067
# Processing file: frame_1068.jpg with index:1068
# Processing file: frame_1069.jpg with index:1069
# Processing file: frame_107.jpg with index:107
# Processing file: frame_1070.jpg with index:1070
# Processing file: frame_1071.jpg with index:1071
# Processing file: frame_1072.jpg with index:1072
# Processing file: frame_1073.jpg with index:1073
# Processing file: frame_1074.jpg with index:1074
# Processing file: frame_1075.jpg with index:1075
# Processing file: frame_1076.jpg with index:1076
# Processing file: frame_1077.jpg with index:1077
# Processing file: frame_1078.jpg with index:1078
# Processing file: frame_1079.jpg with index:1079
# Processing file: frame_108.jpg with index:108
# Processing file: frame_1080.jpg with index:1080
# Processing file: frame_1081.jpg with index:1081
# Processing file: frame_1082.jpg with index:1082
# Processing file: frame_1083.jpg with index:1083
# Processing file: frame_1084.jpg with index:1084
# Processing file: frame_1085.jpg with index:1085
# Processing file: frame_1086.jpg with index:1086
# Processing file: frame_1087.jpg with index:1087
# Processing file: frame_1088.jpg with index:1088
# Processing file: frame_1089.jpg with index:1089
# Processing file: frame_109.jpg with index:109
# Processing file: frame_1090.jpg with index:1090
# Processing file: frame_1091.jpg with index:1091
# Processing file: frame_1092.jpg with index:1092
# Processing file: frame_1093.jpg with index:1093
# Processing file: frame_1094.jpg with index:1094
# Processing file: frame_1095.jpg with index:1095
# Processing file: frame_1096.jpg with index:1096
# Processing file: frame_1097.jpg with index:1097
# Processing file: frame_1098.jpg with index:1098
# Processing file: frame_1099.jpg with index:1099
# Processing file: frame_11.jpg with index:11
# Processing file: frame_110.jpg with index:110
# Processing file: frame_1100.jpg with index:1100
# Processing file: frame_1101.jpg with index:1101
# Processing file: frame_1102.jpg with index:1102
# Processing file: frame_1103.jpg with index:1103
# Processing file: frame_1104.jpg with index:1104
# Processing file: frame_1105.jpg with index:1105
# Processing file: frame_1106.jpg with index:1106
# Processing file: frame_1107.jpg with index:1107
# Processing file: frame_1108.jpg with index:1108
# Processing file: frame_1109.jpg with index:1109
# Processing file: frame_111.jpg with index:111
# Processing file: frame_1110.jpg with index:1110
# Processing file: frame_1111.jpg with index:1111
# Processing file: frame_1112.jpg with index:1112
# Processing file: frame_1113.jpg with index:1113
# Processing file: frame_1114.jpg with index:1114
# Processing file: frame_1115.jpg with index:1115
# Processing file: frame_1116.jpg with index:1116
# Processing file: frame_1117.jpg with index:1117
# Processing file: frame_1118.jpg with index:1118
# Processing file: frame_1119.jpg with index:1119
# Processing file: frame_112.jpg with index:112
# Processing file: frame_1120.jpg with index:1120
# Processing file: frame_1121.jpg with index:1121
# Processing file: frame_1122.jpg with index:1122
# Processing file: frame_1123.jpg with index:1123
# Processing file: frame_1124.jpg with index:1124
# Processing file: frame_1125.jpg with index:1125
# Processing file: frame_1126.jpg with index:1126
# Processing file: frame_1127.jpg with index:1127
# Processing file: frame_1128.jpg with index:1128
# Processing file: frame_1129.jpg with index:1129
# Processing file: frame_113.jpg with index:113
# Processing file: frame_1130.jpg with index:1130
# Processing file: frame_1131.jpg with index:1131
# Processing file: frame_1132.jpg with index:1132
# Processing file: frame_1133.jpg with index:1133
# Processing file: frame_1134.jpg with index:1134
# Processing file: frame_1135.jpg with index:1135
# Processing file: frame_1136.jpg with index:1136
# Processing file: frame_1137.jpg with index:1137
# Processing file: frame_1138.jpg with index:1138
# Processing file: frame_1139.jpg with index:1139
# Processing file: frame_114.jpg with index:114
# Processing file: frame_1140.jpg with index:1140
# Processing file: frame_1141.jpg with index:1141
# Processing file: frame_1142.jpg with index:1142
# Processing file: frame_1143.jpg with index:1143
# Processing file: frame_1144.jpg with index:1144
# Processing file: frame_1145.jpg with index:1145
# Processing file: frame_1146.jpg with index:1146
# Processing file: frame_1147.jpg with index:1147
# Processing file: frame_1148.jpg with index:1148
# Processing file: frame_1149.jpg with index:1149
# Processing file: frame_115.jpg with index:115
# Processing file: frame_1150.jpg with index:1150
# Processing file: frame_1151.jpg with index:1151
# Processing file: frame_1152.jpg with index:1152
# Processing file: frame_1153.jpg with index:1153
# Processing file: frame_1154.jpg with index:1154
# Processing file: frame_1155.jpg with index:1155
# Processing file: frame_1156.jpg with index:1156
# Processing file: frame_1157.jpg with index:1157
# Processing file: frame_1158.jpg with index:1158
# Processing file: frame_1159.jpg with index:1159
# Processing file: frame_116.jpg with index:116
# Processing file: frame_1160.jpg with index:1160
# Processing file: frame_1161.jpg with index:1161
# Processing file: frame_1162.jpg with index:1162
# Processing file: frame_1163.jpg with index:1163
# Processing file: frame_1164.jpg with index:1164
# Processing file: frame_1165.jpg with index:1165
# Processing file: frame_1166.jpg with index:1166
# Processing file: frame_1167.jpg with index:1167
# Processing file: frame_1168.jpg with index:1168
# Processing file: frame_1169.jpg with index:1169
# Processing file: frame_117.jpg with index:117
# Processing file: frame_1170.jpg with index:1170
# Processing file: frame_1171.jpg with index:1171
# Processing file: frame_1172.jpg with index:1172
# Processing file: frame_1173.jpg with index:1173
# Processing file: frame_1174.jpg with index:1174
# Processing file: frame_1175.jpg with index:1175
# Processing file: frame_1176.jpg with index:1176
# Processing file: frame_1177.jpg with index:1177
# Processing file: frame_1178.jpg with index:1178
# Processing file: frame_1179.jpg with index:1179
# Processing file: frame_118.jpg with index:118
# Processing file: frame_1180.jpg with index:1180
# Processing file: frame_1181.jpg with index:1181
# Processing file: frame_1182.jpg with index:1182
# Processing file: frame_1183.jpg with index:1183
# Processing file: frame_1184.jpg with index:1184
# Processing file: frame_1185.jpg with index:1185
# Processing file: frame_1186.jpg with index:1186
# Processing file: frame_1187.jpg with index:1187
# Processing file: frame_1188.jpg with index:1188
# Processing file: frame_1189.jpg with index:1189
# Processing file: frame_119.jpg with index:119
# Processing file: frame_1190.jpg with index:1190
# Processing file: frame_1191.jpg with index:1191
# Processing file: frame_1192.jpg with index:1192
# Processing file: frame_1193.jpg with index:1193
# Processing file: frame_1194.jpg with index:1194
# Processing file: frame_1195.jpg with index:1195
# Processing file: frame_1196.jpg with index:1196
# Processing file: frame_1197.jpg with index:1197
# Processing file: frame_1198.jpg with index:1198
# Processing file: frame_1199.jpg with index:1199
# Processing file: frame_12.jpg with index:12
# Processing file: frame_120.jpg with index:120
# Processing file: frame_1200.jpg with index:1200
# Processing file: frame_1201.jpg with index:1201
# Processing file: frame_1202.jpg with index:1202
# Processing file: frame_1203.jpg with index:1203
# Processing file: frame_1204.jpg with index:1204
# Processing file: frame_1205.jpg with index:1205
# Processing file: frame_1206.jpg with index:1206
# Processing file: frame_1207.jpg with index:1207
# Processing file: frame_1208.jpg with index:1208
# Processing file: frame_1209.jpg with index:1209
# Processing file: frame_121.jpg with index:121
# Processing file: frame_1210.jpg with index:1210
# Processing file: frame_1211.jpg with index:1211
# Processing file: frame_1212.jpg with index:1212
# Processing file: frame_1213.jpg with index:1213
# Processing file: frame_1214.jpg with index:1214
# Processing file: frame_1215.jpg with index:1215
# Processing file: frame_1216.jpg with index:1216
# Processing file: frame_1217.jpg with index:1217
# Processing file: frame_1218.jpg with index:1218
# Processing file: frame_1219.jpg with index:1219
# Processing file: frame_122.jpg with index:122
# Processing file: frame_1220.jpg with index:1220
# Processing file: frame_1221.jpg with index:1221
# Processing file: frame_1222.jpg with index:1222
# Processing file: frame_1223.jpg with index:1223
# Processing file: frame_1224.jpg with index:1224
# Processing file: frame_1225.jpg with index:1225
# Processing file: frame_1226.jpg with index:1226
# Processing file: frame_1227.jpg with index:1227
# Processing file: frame_1228.jpg with index:1228
# Processing file: frame_1229.jpg with index:1229
# Processing file: frame_123.jpg with index:123
# Processing file: frame_1230.jpg with index:1230
# Processing file: frame_1231.jpg with index:1231
# Processing file: frame_1232.jpg with index:1232
# Processing file: frame_1233.jpg with index:1233
# Processing file: frame_1234.jpg with index:1234
# Processing file: frame_1235.jpg with index:1235
# Processing file: frame_1236.jpg with index:1236
# Processing file: frame_1237.jpg with index:1237
# Processing file: frame_1238.jpg with index:1238
# Processing file: frame_1239.jpg with index:1239
# Processing file: frame_124.jpg with index:124
# Processing file: frame_1240.jpg with index:1240
# Processing file: frame_1241.jpg with index:1241
# Processing file: frame_1242.jpg with index:1242
# Processing file: frame_1243.jpg with index:1243
# Processing file: frame_1244.jpg with index:1244
# Processing file: frame_1245.jpg with index:1245
# Processing file: frame_1246.jpg with index:1246
# Processing file: frame_1247.jpg with index:1247
# Processing file: frame_1248.jpg with index:1248
# Processing file: frame_1249.jpg with index:1249
# Processing file: frame_125.jpg with index:125
# Processing file: frame_1250.jpg with index:1250
# Processing file: frame_1251.jpg with index:1251
# Processing file: frame_1252.jpg with index:1252
# Processing file: frame_1253.jpg with index:1253
# Processing file: frame_1254.jpg with index:1254
# Processing file: frame_1255.jpg with index:1255
# Processing file: frame_1256.jpg with index:1256
# Processing file: frame_1257.jpg with index:1257
# Processing file: frame_1258.jpg with index:1258
# Processing file: frame_1259.jpg with index:1259
# Processing file: frame_126.jpg with index:126
# Processing file: frame_1260.jpg with index:1260
# Processing file: frame_1261.jpg with index:1261
# Processing file: frame_1262.jpg with index:1262
# Processing file: frame_1263.jpg with index:1263
# Processing file: frame_1264.jpg with index:1264
# Processing file: frame_1265.jpg with index:1265
# Processing file: frame_1266.jpg with index:1266
# Processing file: frame_1267.jpg with index:1267
# Processing file: frame_1268.jpg with index:1268
# Processing file: frame_1269.jpg with index:1269
# Processing file: frame_127.jpg with index:127
# Processing file: frame_1270.jpg with index:1270
# Processing file: frame_1271.jpg with index:1271
# Processing file: frame_1272.jpg with index:1272
# Processing file: frame_1273.jpg with index:1273
# Processing file: frame_1274.jpg with index:1274
# Processing file: frame_1275.jpg with index:1275
# Processing file: frame_1276.jpg with index:1276
# Processing file: frame_1277.jpg with index:1277
# Processing file: frame_1278.jpg with index:1278
# Processing file: frame_1279.jpg with index:1279
# Processing file: frame_128.jpg with index:128
# Processing file: frame_1280.jpg with index:1280
# Processing file: frame_1281.jpg with index:1281
# Processing file: frame_1282.jpg with index:1282
# Processing file: frame_1283.jpg with index:1283
# Processing file: frame_1284.jpg with index:1284
# Processing file: frame_1285.jpg with index:1285
# Processing file: frame_1286.jpg with index:1286
# Processing file: frame_1287.jpg with index:1287
# Processing file: frame_1288.jpg with index:1288
# Processing file: frame_1289.jpg with index:1289
# Processing file: frame_129.jpg with index:129
# Processing file: frame_1290.jpg with index:1290
# Processing file: frame_1291.jpg with index:1291
# Processing file: frame_1292.jpg with index:1292
# Processing file: frame_1293.jpg with index:1293
# Processing file: frame_1294.jpg with index:1294
# Processing file: frame_1295.jpg with index:1295
# Processing file: frame_1296.jpg with index:1296
# Processing file: frame_1297.jpg with index:1297
# Processing file: frame_1298.jpg with index:1298
# Processing file: frame_1299.jpg with index:1299
# Processing file: frame_13.jpg with index:13
# Processing file: frame_130.jpg with index:130
# Processing file: frame_1300.jpg with index:1300
# Processing file: frame_1301.jpg with index:1301
# Processing file: frame_1302.jpg with index:1302
# Processing file: frame_1303.jpg with index:1303
# Processing file: frame_1304.jpg with index:1304
# Processing file: frame_1305.jpg with index:1305
# Processing file: frame_1306.jpg with index:1306
# Processing file: frame_1307.jpg with index:1307
# Processing file: frame_1308.jpg with index:1308
# Processing file: frame_1309.jpg with index:1309
# Processing file: frame_131.jpg with index:131
# Processing file: frame_1310.jpg with index:1310
# Processing file: frame_1311.jpg with index:1311
# Processing file: frame_1312.jpg with index:1312
# Processing file: frame_1313.jpg with index:1313
# Processing file: frame_1314.jpg with index:1314
# Processing file: frame_1315.jpg with index:1315
# Processing file: frame_1316.jpg with index:1316
# Processing file: frame_1317.jpg with index:1317
# Processing file: frame_1318.jpg with index:1318
# Processing file: frame_1319.jpg with index:1319
# Processing file: frame_132.jpg with index:132
# Processing file: frame_1320.jpg with index:1320
# Processing file: frame_1321.jpg with index:1321
# Processing file: frame_1322.jpg with index:1322
# Processing file: frame_1323.jpg with index:1323
# Processing file: frame_1324.jpg with index:1324
# Processing file: frame_1325.jpg with index:1325
# Processing file: frame_1326.jpg with index:1326
# Processing file: frame_1327.jpg with index:1327
# Processing file: frame_1328.jpg with index:1328
# Processing file: frame_1329.jpg with index:1329
# Processing file: frame_133.jpg with index:133
# Processing file: frame_1330.jpg with index:1330
# Processing file: frame_1331.jpg with index:1331
# Processing file: frame_1332.jpg with index:1332
# Processing file: frame_1333.jpg with index:1333
# Processing file: frame_1334.jpg with index:1334
# Processing file: frame_1335.jpg with index:1335
# Processing file: frame_1336.jpg with index:1336
# Processing file: frame_1337.jpg with index:1337
# Processing file: frame_1338.jpg with index:1338
# Processing file: frame_1339.jpg with index:1339
# Processing file: frame_134.jpg with index:134
# Processing file: frame_1340.jpg with index:1340
# Processing file: frame_1341.jpg with index:1341
# Processing file: frame_1342.jpg with index:1342
# Processing file: frame_1343.jpg with index:1343
# Processing file: frame_1344.jpg with index:1344
# Processing file: frame_1345.jpg with index:1345
# Processing file: frame_1346.jpg with index:1346
# Processing file: frame_1347.jpg with index:1347
# Processing file: frame_1348.jpg with index:1348
# Processing file: frame_1349.jpg with index:1349
# Processing file: frame_135.jpg with index:135
# Processing file: frame_1350.jpg with index:1350
# Processing file: frame_1351.jpg with index:1351
# Processing file: frame_1352.jpg with index:1352
# Processing file: frame_1353.jpg with index:1353
# Processing file: frame_1354.jpg with index:1354
# Processing file: frame_1355.jpg with index:1355
# Processing file: frame_1356.jpg with index:1356
# Processing file: frame_1357.jpg with index:1357
# Processing file: frame_1358.jpg with index:1358
# Processing file: frame_1359.jpg with index:1359
# Processing file: frame_136.jpg with index:136
# Processing file: frame_1360.jpg with index:1360
# Processing file: frame_1361.jpg with index:1361
# Processing file: frame_1362.jpg with index:1362
# Processing file: frame_1363.jpg with index:1363
# Processing file: frame_1364.jpg with index:1364
# Processing file: frame_1365.jpg with index:1365
# Processing file: frame_1366.jpg with index:1366
# Processing file: frame_1367.jpg with index:1367
# Processing file: frame_1368.jpg with index:1368
# Processing file: frame_1369.jpg with index:1369
# Processing file: frame_137.jpg with index:137
# Processing file: frame_1370.jpg with index:1370
# Processing file: frame_1371.jpg with index:1371
# Processing file: frame_1372.jpg with index:1372
# Processing file: frame_1373.jpg with index:1373
# Processing file: frame_1374.jpg with index:1374
# Processing file: frame_1375.jpg with index:1375
# Processing file: frame_1376.jpg with index:1376
# Processing file: frame_1377.jpg with index:1377
# Processing file: frame_1378.jpg with index:1378
# Processing file: frame_1379.jpg with index:1379
# Processing file: frame_138.jpg with index:138
# Processing file: frame_1380.jpg with index:1380
# Processing file: frame_1381.jpg with index:1381
# Processing file: frame_1382.jpg with index:1382
# Processing file: frame_1383.jpg with index:1383
# Processing file: frame_1384.jpg with index:1384
# Processing file: frame_1385.jpg with index:1385
# Processing file: frame_1386.jpg with index:1386
# Processing file: frame_1387.jpg with index:1387
# Processing file: frame_1388.jpg with index:1388
# Processing file: frame_1389.jpg with index:1389
# Processing file: frame_139.jpg with index:139
# Processing file: frame_1390.jpg with index:1390
# Processing file: frame_1391.jpg with index:1391
# Processing file: frame_1392.jpg with index:1392
# Processing file: frame_1393.jpg with index:1393
# Processing file: frame_1394.jpg with index:1394
# Processing file: frame_1395.jpg with index:1395
# Processing file: frame_1396.jpg with index:1396
# Processing file: frame_1397.jpg with index:1397
# Processing file: frame_1398.jpg with index:1398
# Processing file: frame_1399.jpg with index:1399
# Processing file: frame_14.jpg with index:14
# Processing file: frame_140.jpg with index:140
# Processing file: frame_1400.jpg with index:1400
# Processing file: frame_1401.jpg with index:1401
# Processing file: frame_1402.jpg with index:1402
# Processing file: frame_1403.jpg with index:1403
# Processing file: frame_1404.jpg with index:1404
# Processing file: frame_1405.jpg with index:1405
# Processing file: frame_1406.jpg with index:1406
# Processing file: frame_1407.jpg with index:1407
# Processing file: frame_1408.jpg with index:1408
# Processing file: frame_1409.jpg with index:1409
# Processing file: frame_141.jpg with index:141
# Processing file: frame_1410.jpg with index:1410
# Processing file: frame_1411.jpg with index:1411
# Processing file: frame_1412.jpg with index:1412
# Processing file: frame_1413.jpg with index:1413
# Processing file: frame_1414.jpg with index:1414
# Processing file: frame_1415.jpg with index:1415
# Processing file: frame_1416.jpg with index:1416
# Processing file: frame_1417.jpg with index:1417
# Processing file: frame_1418.jpg with index:1418
# Processing file: frame_1419.jpg with index:1419
# Processing file: frame_142.jpg with index:142
# Processing file: frame_1420.jpg with index:1420
# Processing file: frame_1421.jpg with index:1421
# Processing file: frame_1422.jpg with index:1422
# Processing file: frame_1423.jpg with index:1423
# Processing file: frame_1424.jpg with index:1424
# Processing file: frame_1425.jpg with index:1425
# Processing file: frame_1426.jpg with index:1426
# Processing file: frame_1427.jpg with index:1427
# Processing file: frame_1428.jpg with index:1428
# Processing file: frame_1429.jpg with index:1429
# Processing file: frame_143.jpg with index:143
# Processing file: frame_1430.jpg with index:1430
# Processing file: frame_1431.jpg with index:1431
# Processing file: frame_1432.jpg with index:1432
# Processing file: frame_1433.jpg with index:1433
# Processing file: frame_1434.jpg with index:1434
# Processing file: frame_1435.jpg with index:1435
# Processing file: frame_1436.jpg with index:1436
# Processing file: frame_1437.jpg with index:1437
# Processing file: frame_1438.jpg with index:1438
# Processing file: frame_1439.jpg with index:1439
# Processing file: frame_144.jpg with index:144
# Processing file: frame_1440.jpg with index:1440
# Processing file: frame_1441.jpg with index:1441
# Processing file: frame_1442.jpg with index:1442
# Processing file: frame_1443.jpg with index:1443
# Processing file: frame_1444.jpg with index:1444
# Processing file: frame_1445.jpg with index:1445
# Processing file: frame_1446.jpg with index:1446
# Processing file: frame_1447.jpg with index:1447
# Processing file: frame_1448.jpg with index:1448
# Processing file: frame_1449.jpg with index:1449
# Processing file: frame_145.jpg with index:145
# Processing file: frame_1450.jpg with index:1450
# Processing file: frame_1451.jpg with index:1451
# Processing file: frame_1452.jpg with index:1452
# Processing file: frame_1453.jpg with index:1453
# Processing file: frame_1454.jpg with index:1454
# Processing file: frame_1455.jpg with index:1455
# Processing file: frame_1456.jpg with index:1456
# Processing file: frame_1457.jpg with index:1457
# Processing file: frame_1458.jpg with index:1458
# Processing file: frame_1459.jpg with index:1459
# Processing file: frame_146.jpg with index:146
# Processing file: frame_1460.jpg with index:1460
# Processing file: frame_1461.jpg with index:1461
# Processing file: frame_1462.jpg with index:1462
# Processing file: frame_1463.jpg with index:1463
# Processing file: frame_1464.jpg with index:1464
# Processing file: frame_1465.jpg with index:1465
# Processing file: frame_1466.jpg with index:1466
# Processing file: frame_1467.jpg with index:1467
# Processing file: frame_1468.jpg with index:1468
# Processing file: frame_1469.jpg with index:1469
# Processing file: frame_147.jpg with index:147
# Processing file: frame_1470.jpg with index:1470
# Processing file: frame_1471.jpg with index:1471
# Processing file: frame_1472.jpg with index:1472
# Processing file: frame_1473.jpg with index:1473
# Processing file: frame_1474.jpg with index:1474
# Processing file: frame_1475.jpg with index:1475
# Processing file: frame_1476.jpg with index:1476
# Processing file: frame_1477.jpg with index:1477
# Processing file: frame_1478.jpg with index:1478
# Processing file: frame_1479.jpg with index:1479
# Processing file: frame_148.jpg with index:148
# Processing file: frame_1480.jpg with index:1480
# Processing file: frame_1481.jpg with index:1481
# Processing file: frame_1482.jpg with index:1482
# Processing file: frame_1483.jpg with index:1483
# Processing file: frame_1484.jpg with index:1484
# Processing file: frame_1485.jpg with index:1485
# Processing file: frame_1486.jpg with index:1486
# Processing file: frame_1487.jpg with index:1487
# Processing file: frame_1488.jpg with index:1488
# Processing file: frame_1489.jpg with index:1489
# Processing file: frame_149.jpg with index:149
# Processing file: frame_1490.jpg with index:1490
# Processing file: frame_1491.jpg with index:1491
# Processing file: frame_1492.jpg with index:1492
# Processing file: frame_1493.jpg with index:1493
# Processing file: frame_1494.jpg with index:1494
# Processing file: frame_1495.jpg with index:1495
# Processing file: frame_1496.jpg with index:1496
# Processing file: frame_1497.jpg with index:1497
# Processing file: frame_1498.jpg with index:1498
# Processing file: frame_1499.jpg with index:1499
# Processing file: frame_15.jpg with index:15
# Processing file: frame_150.jpg with index:150
# Processing file: frame_1500.jpg with index:1500
# Processing file: frame_1501.jpg with index:1501
# Processing file: frame_1502.jpg with index:1502
# Processing file: frame_1503.jpg with index:1503
# Processing file: frame_1504.jpg with index:1504
# Processing file: frame_1505.jpg with index:1505
# Processing file: frame_1506.jpg with index:1506
# Processing file: frame_1507.jpg with index:1507
# Processing file: frame_1508.jpg with index:1508
# Processing file: frame_1509.jpg with index:1509
# Processing file: frame_151.jpg with index:151
# Processing file: frame_1510.jpg with index:1510
# Processing file: frame_1511.jpg with index:1511
# Processing file: frame_1512.jpg with index:1512
# Processing file: frame_1513.jpg with index:1513
# Processing file: frame_1514.jpg with index:1514
# Processing file: frame_1515.jpg with index:1515
# Processing file: frame_1516.jpg with index:1516
# Processing file: frame_1517.jpg with index:1517
# Processing file: frame_1518.jpg with index:1518
# Processing file: frame_1519.jpg with index:1519
# Processing file: frame_152.jpg with index:152
# Processing file: frame_1520.jpg with index:1520
# Processing file: frame_1521.jpg with index:1521
# Processing file: frame_1522.jpg with index:1522
# Processing file: frame_1523.jpg with index:1523
# Processing file: frame_1524.jpg with index:1524
# Processing file: frame_1525.jpg with index:1525
# Processing file: frame_1526.jpg with index:1526
# Processing file: frame_1527.jpg with index:1527
# Processing file: frame_1528.jpg with index:1528
# Processing file: frame_1529.jpg with index:1529
# Processing file: frame_153.jpg with index:153
# Processing file: frame_1530.jpg with index:1530
# Processing file: frame_1531.jpg with index:1531
# Processing file: frame_1532.jpg with index:1532
# Processing file: frame_1533.jpg with index:1533
# Processing file: frame_1534.jpg with index:1534
# Processing file: frame_1535.jpg with index:1535
# Processing file: frame_1536.jpg with index:1536
# Processing file: frame_1537.jpg with index:1537
# Processing file: frame_1538.jpg with index:1538
# Processing file: frame_1539.jpg with index:1539
# Processing file: frame_154.jpg with index:154
# Processing file: frame_1540.jpg with index:1540
# Processing file: frame_1541.jpg with index:1541
# Processing file: frame_1542.jpg with index:1542
# Processing file: frame_1543.jpg with index:1543
# Processing file: frame_1544.jpg with index:1544
# Processing file: frame_1545.jpg with index:1545
# Processing file: frame_1546.jpg with index:1546
# Processing file: frame_1547.jpg with index:1547
# Processing file: frame_1548.jpg with index:1548
# Processing file: frame_1549.jpg with index:1549
# Processing file: frame_155.jpg with index:155
# Processing file: frame_1550.jpg with index:1550
# Processing file: frame_1551.jpg with index:1551
# Processing file: frame_1552.jpg with index:1552
# Processing file: frame_1553.jpg with index:1553
# Processing file: frame_1554.jpg with index:1554
# Processing file: frame_1555.jpg with index:1555
# Processing file: frame_1556.jpg with index:1556
# Processing file: frame_1557.jpg with index:1557
# Processing file: frame_1558.jpg with index:1558
# Processing file: frame_1559.jpg with index:1559
# Processing file: frame_156.jpg with index:156
# Processing file: frame_1560.jpg with index:1560
# Processing file: frame_1561.jpg with index:1561
# Processing file: frame_1562.jpg with index:1562
# Processing file: frame_1563.jpg with index:1563
# Processing file: frame_1564.jpg with index:1564
# Processing file: frame_1565.jpg with index:1565
# Processing file: frame_1566.jpg with index:1566
# Processing file: frame_1567.jpg with index:1567
# Processing file: frame_1568.jpg with index:1568
# Processing file: frame_1569.jpg with index:1569
# Processing file: frame_157.jpg with index:157
# Processing file: frame_1570.jpg with index:1570
# Processing file: frame_1571.jpg with index:1571
# Processing file: frame_1572.jpg with index:1572
# Processing file: frame_1573.jpg with index:1573
# Processing file: frame_1574.jpg with index:1574
# Processing file: frame_1575.jpg with index:1575
# Processing file: frame_1576.jpg with index:1576
# Processing file: frame_1577.jpg with index:1577
# Processing file: frame_1578.jpg with index:1578
# Processing file: frame_1579.jpg with index:1579
# Processing file: frame_158.jpg with index:158
# Processing file: frame_1580.jpg with index:1580
# Processing file: frame_1581.jpg with index:1581
# Processing file: frame_1582.jpg with index:1582
# Processing file: frame_1583.jpg with index:1583
# Processing file: frame_1584.jpg with index:1584
# Processing file: frame_1585.jpg with index:1585
# Processing file: frame_1586.jpg with index:1586
# Processing file: frame_1587.jpg with index:1587
# Processing file: frame_1588.jpg with index:1588
# Processing file: frame_1589.jpg with index:1589
# Processing file: frame_159.jpg with index:159
# Processing file: frame_1590.jpg with index:1590
# Processing file: frame_1591.jpg with index:1591
# Processing file: frame_1592.jpg with index:1592
# Processing file: frame_1593.jpg with index:1593
# Processing file: frame_1594.jpg with index:1594
# Processing file: frame_1595.jpg with index:1595
# Processing file: frame_1596.jpg with index:1596
# Processing file: frame_1597.jpg with index:1597
# Processing file: frame_1598.jpg with index:1598
# Processing file: frame_1599.jpg with index:1599
# Processing file: frame_16.jpg with index:16
# Processing file: frame_160.jpg with index:160
# Processing file: frame_1600.jpg with index:1600
# Processing file: frame_1601.jpg with index:1601
# Processing file: frame_1602.jpg with index:1602
# Processing file: frame_1603.jpg with index:1603
# Processing file: frame_1604.jpg with index:1604
# Processing file: frame_1605.jpg with index:1605
# Processing file: frame_1606.jpg with index:1606
# Processing file: frame_1607.jpg with index:1607
# Processing file: frame_1608.jpg with index:1608
# Processing file: frame_1609.jpg with index:1609
# Processing file: frame_161.jpg with index:161
# Processing file: frame_1610.jpg with index:1610
# Processing file: frame_1611.jpg with index:1611
# Processing file: frame_1612.jpg with index:1612
# Processing file: frame_1613.jpg with index:1613
# Processing file: frame_1614.jpg with index:1614
# Processing file: frame_1615.jpg with index:1615
# Processing file: frame_1616.jpg with index:1616
# Processing file: frame_1617.jpg with index:1617
# Processing file: frame_1618.jpg with index:1618
# Processing file: frame_1619.jpg with index:1619
# Processing file: frame_162.jpg with index:162
# Processing file: frame_1620.jpg with index:1620
# Processing file: frame_1621.jpg with index:1621
# Processing file: frame_1622.jpg with index:1622
# Processing file: frame_1623.jpg with index:1623
# Processing file: frame_1624.jpg with index:1624
# Processing file: frame_1625.jpg with index:1625
# Processing file: frame_1626.jpg with index:1626
# Processing file: frame_1627.jpg with index:1627
# Processing file: frame_1628.jpg with index:1628
# Processing file: frame_1629.jpg with index:1629
# Processing file: frame_163.jpg with index:163
# Processing file: frame_1630.jpg with index:1630
# Processing file: frame_1631.jpg with index:1631
# Processing file: frame_1632.jpg with index:1632
# Processing file: frame_1633.jpg with index:1633
# Processing file: frame_1634.jpg with index:1634
# Processing file: frame_1635.jpg with index:1635
# Processing file: frame_1636.jpg with index:1636
# Processing file: frame_1637.jpg with index:1637
# Processing file: frame_1638.jpg with index:1638
# Processing file: frame_1639.jpg with index:1639
# Processing file: frame_164.jpg with index:164
# Processing file: frame_1640.jpg with index:1640
# Processing file: frame_1641.jpg with index:1641
# Processing file: frame_1642.jpg with index:1642
# Processing file: frame_1643.jpg with index:1643
# Processing file: frame_1644.jpg with index:1644
# Processing file: frame_1645.jpg with index:1645
# Processing file: frame_1646.jpg with index:1646
# Processing file: frame_1647.jpg with index:1647
# Processing file: frame_1648.jpg with index:1648
# Processing file: frame_1649.jpg with index:1649
# Processing file: frame_165.jpg with index:165
# Processing file: frame_1650.jpg with index:1650
# Processing file: frame_1651.jpg with index:1651
# Processing file: frame_1652.jpg with index:1652
# Processing file: frame_1653.jpg with index:1653
# Processing file: frame_1654.jpg with index:1654
# Processing file: frame_1655.jpg with index:1655
# Processing file: frame_1656.jpg with index:1656
# Processing file: frame_1657.jpg with index:1657
# Processing file: frame_1658.jpg with index:1658
# Processing file: frame_1659.jpg with index:1659
# Processing file: frame_166.jpg with index:166
# Processing file: frame_1660.jpg with index:1660
# Processing file: frame_1661.jpg with index:1661
# Processing file: frame_1662.jpg with index:1662
# Processing file: frame_1663.jpg with index:1663
# Processing file: frame_1664.jpg with index:1664
# Processing file: frame_1665.jpg with index:1665
# Processing file: frame_1666.jpg with index:1666
# Processing file: frame_1667.jpg with index:1667
# Processing file: frame_1668.jpg with index:1668
# Processing file: frame_1669.jpg with index:1669
# Processing file: frame_167.jpg with index:167
# Processing file: frame_1670.jpg with index:1670
# Processing file: frame_1671.jpg with index:1671
# Processing file: frame_1672.jpg with index:1672
# Processing file: frame_1673.jpg with index:1673
# Processing file: frame_1674.jpg with index:1674
# Processing file: frame_1675.jpg with index:1675
# Processing file: frame_1676.jpg with index:1676
# Processing file: frame_1677.jpg with index:1677
# Processing file: frame_1678.jpg with index:1678
# Processing file: frame_1679.jpg with index:1679
# Processing file: frame_168.jpg with index:168
# Processing file: frame_1680.jpg with index:1680
# Processing file: frame_1681.jpg with index:1681
# Processing file: frame_1682.jpg with index:1682
# Processing file: frame_1683.jpg with index:1683
# Processing file: frame_1684.jpg with index:1684
# Processing file: frame_1685.jpg with index:1685
# Processing file: frame_1686.jpg with index:1686
# Processing file: frame_1687.jpg with index:1687
# Processing file: frame_1688.jpg with index:1688
# Processing file: frame_1689.jpg with index:1689
# Processing file: frame_169.jpg with index:169
# Processing file: frame_1690.jpg with index:1690
# Processing file: frame_1691.jpg with index:1691
# Processing file: frame_1692.jpg with index:1692
# Processing file: frame_1693.jpg with index:1693
# Processing file: frame_1694.jpg with index:1694
# Processing file: frame_1695.jpg with index:1695
# Processing file: frame_1696.jpg with index:1696
# Processing file: frame_1697.jpg with index:1697
# Processing file: frame_1698.jpg with index:1698
# Processing file: frame_1699.jpg with index:1699
# Processing file: frame_17.jpg with index:17
# Processing file: frame_170.jpg with index:170
# Processing file: frame_1700.jpg with index:1700
# Processing file: frame_1701.jpg with index:1701
# Processing file: frame_1702.jpg with index:1702
# Processing file: frame_1703.jpg with index:1703
# Processing file: frame_1704.jpg with index:1704
# Processing file: frame_1705.jpg with index:1705
# Processing file: frame_1706.jpg with index:1706
# Processing file: frame_1707.jpg with index:1707
# Processing file: frame_1708.jpg with index:1708
# Processing file: frame_1709.jpg with index:1709
# Processing file: frame_171.jpg with index:171
# Processing file: frame_1710.jpg with index:1710
# Processing file: frame_1711.jpg with index:1711
# Processing file: frame_1712.jpg with index:1712
# Processing file: frame_1713.jpg with index:1713
# Processing file: frame_1714.jpg with index:1714
# Processing file: frame_1715.jpg with index:1715
# Processing file: frame_1716.jpg with index:1716
# Processing file: frame_1717.jpg with index:1717
# Processing file: frame_1718.jpg with index:1718
# Processing file: frame_1719.jpg with index:1719
# Processing file: frame_172.jpg with index:172
# Processing file: frame_1720.jpg with index:1720
# Processing file: frame_1721.jpg with index:1721
# Processing file: frame_1722.jpg with index:1722
# Processing file: frame_1723.jpg with index:1723
# Processing file: frame_1724.jpg with index:1724
# Processing file: frame_1725.jpg with index:1725
# Processing file: frame_1726.jpg with index:1726
# Processing file: frame_1727.jpg with index:1727
# Processing file: frame_1728.jpg with index:1728
# Processing file: frame_1729.jpg with index:1729
# Processing file: frame_173.jpg with index:173
# Processing file: frame_1730.jpg with index:1730
# Processing file: frame_1731.jpg with index:1731
# Processing file: frame_1732.jpg with index:1732
# Processing file: frame_1733.jpg with index:1733
# Processing file: frame_1734.jpg with index:1734
# Processing file: frame_1735.jpg with index:1735
# Processing file: frame_1736.jpg with index:1736
# Processing file: frame_1737.jpg with index:1737
# Processing file: frame_1738.jpg with index:1738
# Processing file: frame_1739.jpg with index:1739
# Processing file: frame_174.jpg with index:174
# Processing file: frame_1740.jpg with index:1740
# Processing file: frame_1741.jpg with index:1741
# Processing file: frame_1742.jpg with index:1742
# Processing file: frame_1743.jpg with index:1743
# Processing file: frame_1744.jpg with index:1744
# Processing file: frame_1745.jpg with index:1745
# Processing file: frame_1746.jpg with index:1746
# Processing file: frame_1747.jpg with index:1747
# Processing file: frame_1748.jpg with index:1748
# Processing file: frame_1749.jpg with index:1749
# Processing file: frame_175.jpg with index:175
# Processing file: frame_1750.jpg with index:1750
# Processing file: frame_1751.jpg with index:1751
# Processing file: frame_1752.jpg with index:1752
# Processing file: frame_1753.jpg with index:1753
# Processing file: frame_1754.jpg with index:1754
# Processing file: frame_1755.jpg with index:1755
# Processing file: frame_1756.jpg with index:1756
# Processing file: frame_1757.jpg with index:1757
# Processing file: frame_1758.jpg with index:1758
# Processing file: frame_1759.jpg with index:1759
# Processing file: frame_176.jpg with index:176
# Processing file: frame_1760.jpg with index:1760
# Processing file: frame_1761.jpg with index:1761
# Processing file: frame_1762.jpg with index:1762
# Processing file: frame_1763.jpg with index:1763
# Processing file: frame_1764.jpg with index:1764
# Processing file: frame_1765.jpg with index:1765
# Processing file: frame_1766.jpg with index:1766
# Processing file: frame_1767.jpg with index:1767
# Processing file: frame_1768.jpg with index:1768
# Processing file: frame_1769.jpg with index:1769
# Processing file: frame_177.jpg with index:177
# Processing file: frame_1770.jpg with index:1770
# Processing file: frame_1771.jpg with index:1771
# Processing file: frame_1772.jpg with index:1772
# Processing file: frame_1773.jpg with index:1773
# Processing file: frame_1774.jpg with index:1774
# Processing file: frame_1775.jpg with index:1775
# Processing file: frame_1776.jpg with index:1776
# Processing file: frame_1777.jpg with index:1777
# Processing file: frame_1778.jpg with index:1778
# Processing file: frame_1779.jpg with index:1779
# Processing file: frame_178.jpg with index:178
# Processing file: frame_1780.jpg with index:1780
# Processing file: frame_1781.jpg with index:1781
# Processing file: frame_1782.jpg with index:1782
# Processing file: frame_1783.jpg with index:1783
# Processing file: frame_1784.jpg with index:1784
# Processing file: frame_1785.jpg with index:1785
# Processing file: frame_1786.jpg with index:1786
# Processing file: frame_1787.jpg with index:1787
# Processing file: frame_1788.jpg with index:1788
# Processing file: frame_1789.jpg with index:1789
# Processing file: frame_179.jpg with index:179
# Processing file: frame_1790.jpg with index:1790
# Processing file: frame_1791.jpg with index:1791
# Processing file: frame_1792.jpg with index:1792
# Processing file: frame_1793.jpg with index:1793
# Processing file: frame_1794.jpg with index:1794
# Processing file: frame_1795.jpg with index:1795
# Processing file: frame_1796.jpg with index:1796
# Processing file: frame_1797.jpg with index:1797
# Processing file: frame_1798.jpg with index:1798
# Processing file: frame_1799.jpg with index:1799
# Processing file: frame_18.jpg with index:18
# Processing file: frame_180.jpg with index:180
# Processing file: frame_1800.jpg with index:1800
# Processing file: frame_1801.jpg with index:1801
# Processing file: frame_1802.jpg with index:1802
# Processing file: frame_1803.jpg with index:1803
# Processing file: frame_1804.jpg with index:1804
# Processing file: frame_1805.jpg with index:1805
# Processing file: frame_1806.jpg with index:1806
# Processing file: frame_1807.jpg with index:1807
# Processing file: frame_1808.jpg with index:1808
# Processing file: frame_1809.jpg with index:1809
# Processing file: frame_181.jpg with index:181
# Processing file: frame_1810.jpg with index:1810
# Processing file: frame_1811.jpg with index:1811
# Processing file: frame_1812.jpg with index:1812
# Processing file: frame_1813.jpg with index:1813
# Processing file: frame_1814.jpg with index:1814
# Processing file: frame_1815.jpg with index:1815
# Processing file: frame_1816.jpg with index:1816
# Processing file: frame_1817.jpg with index:1817
# Processing file: frame_1818.jpg with index:1818
# Processing file: frame_1819.jpg with index:1819
# Processing file: frame_182.jpg with index:182
# Processing file: frame_1820.jpg with index:1820
# Processing file: frame_1821.jpg with index:1821
# Processing file: frame_1822.jpg with index:1822
# Processing file: frame_1823.jpg with index:1823
# Processing file: frame_1824.jpg with index:1824
# Processing file: frame_1825.jpg with index:1825
# Processing file: frame_1826.jpg with index:1826
# Processing file: frame_1827.jpg with index:1827
# Processing file: frame_1828.jpg with index:1828
# Processing file: frame_1829.jpg with index:1829
# Processing file: frame_183.jpg with index:183
# Processing file: frame_1830.jpg with index:1830
# Processing file: frame_1831.jpg with index:1831
# Processing file: frame_1832.jpg with index:1832
# Processing file: frame_1833.jpg with index:1833
# Processing file: frame_1834.jpg with index:1834
# Processing file: frame_1835.jpg with index:1835
# Processing file: frame_1836.jpg with index:1836
# Processing file: frame_1837.jpg with index:1837
# Processing file: frame_1838.jpg with index:1838
# Processing file: frame_1839.jpg with index:1839
# Processing file: frame_184.jpg with index:184
# Processing file: frame_1840.jpg with index:1840
# Processing file: frame_1841.jpg with index:1841
# Processing file: frame_1842.jpg with index:1842
# Processing file: frame_1843.jpg with index:1843
# Processing file: frame_1844.jpg with index:1844
# Processing file: frame_1845.jpg with index:1845
# Processing file: frame_1846.jpg with index:1846
# Processing file: frame_1847.jpg with index:1847
# Processing file: frame_1848.jpg with index:1848
# Processing file: frame_1849.jpg with index:1849
# Processing file: frame_185.jpg with index:185
# Processing file: frame_1850.jpg with index:1850
# Processing file: frame_1851.jpg with index:1851
# Processing file: frame_1852.jpg with index:1852
# Processing file: frame_1853.jpg with index:1853
# Processing file: frame_1854.jpg with index:1854
# Processing file: frame_1855.jpg with index:1855
# Processing file: frame_1856.jpg with index:1856
# Processing file: frame_1857.jpg with index:1857
# Processing file: frame_1858.jpg with index:1858
# Processing file: frame_1859.jpg with index:1859
# Processing file: frame_186.jpg with index:186
# Processing file: frame_1860.jpg with index:1860
# Processing file: frame_1861.jpg with index:1861
# Processing file: frame_1862.jpg with index:1862
# Processing file: frame_1863.jpg with index:1863
# Processing file: frame_1864.jpg with index:1864
# Processing file: frame_1865.jpg with index:1865
# Processing file: frame_1866.jpg with index:1866
# Processing file: frame_1867.jpg with index:1867
# Processing file: frame_1868.jpg with index:1868
# Processing file: frame_1869.jpg with index:1869
# Processing file: frame_187.jpg with index:187
# Processing file: frame_1870.jpg with index:1870
# Processing file: frame_1871.jpg with index:1871
# Processing file: frame_1872.jpg with index:1872
# Processing file: frame_1873.jpg with index:1873
# Processing file: frame_1874.jpg with index:1874
# Processing file: frame_1875.jpg with index:1875
# Processing file: frame_1876.jpg with index:1876
# Processing file: frame_1877.jpg with index:1877
# Processing file: frame_1878.jpg with index:1878
# Processing file: frame_1879.jpg with index:1879
# Processing file: frame_188.jpg with index:188
# Processing file: frame_1880.jpg with index:1880
# Processing file: frame_1881.jpg with index:1881
# Processing file: frame_1882.jpg with index:1882
# Processing file: frame_1883.jpg with index:1883
# Processing file: frame_1884.jpg with index:1884
# Processing file: frame_1885.jpg with index:1885
# Processing file: frame_1886.jpg with index:1886
# Processing file: frame_1887.jpg with index:1887
# Processing file: frame_1888.jpg with index:1888
# Processing file: frame_1889.jpg with index:1889
# Processing file: frame_189.jpg with index:189
# Processing file: frame_1890.jpg with index:1890
# Processing file: frame_1891.jpg with index:1891
# Processing file: frame_1892.jpg with index:1892
# Processing file: frame_1893.jpg with index:1893
# Processing file: frame_1894.jpg with index:1894
# Processing file: frame_1895.jpg with index:1895
# Processing file: frame_1896.jpg with index:1896
# Processing file: frame_1897.jpg with index:1897
# Processing file: frame_1898.jpg with index:1898
# Processing file: frame_1899.jpg with index:1899
# Processing file: frame_19.jpg with index:19
# Processing file: frame_190.jpg with index:190
# Processing file: frame_1900.jpg with index:1900
# ...
# Processing file: frame_686.jpg with index:686
# Processing file: frame_687.jpg with index:687
# Processing file: frame_688.jpg with index:688
# Processing file: frame_689.jpg with index:689
# Processing file: frame_69.jpg with index:69
# Processing file: frame_690.jpg with index:690
# Processing file: frame_691.jpg with index:691
# Processing file: frame_692.jpg with index:692
# Processing file: frame_693.jpg with index:693
# Processing file: frame_694.jpg with index:694
# Processing file: frame_695.jpg with index:695
# Processing file: frame_696.jpg with index:696
# Processing file: frame_697.jpg with index:697
# Processing file: frame_698.jpg with index:698
# Processing file: frame_699.jpg with index:699
# Processing file: frame_7.jpg with index:7
# Processing file: frame_70.jpg with index:70
# Processing file: frame_700.jpg with index:700
# Processing file: frame_701.jpg with index:701
# Processing file: frame_702.jpg with index:702
# Processing file: frame_703.jpg with index:703
# Processing file: frame_704.jpg with index:704
# Processing file: frame_705.jpg with index:705
# Processing file: frame_706.jpg with index:706
# Processing file: frame_707.jpg with index:707
# Processing file: frame_708.jpg with index:708
# Processing file: frame_709.jpg with index:709
# Processing file: frame_71.jpg with index:71
# Processing file: frame_710.jpg with index:710
# Processing file: frame_711.jpg with index:711
# Processing file: frame_712.jpg with index:712
# Processing file: frame_713.jpg with index:713
# Processing file: frame_714.jpg with index:714
# Processing file: frame_715.jpg with index:715
# Processing file: frame_716.jpg with index:716
# Processing file: frame_717.jpg with index:717
# Processing file: frame_718.jpg with index:718
# Processing file: frame_719.jpg with index:719
# Processing file: frame_72.jpg with index:72
# Processing file: frame_720.jpg with index:720
# Processing file: frame_721.jpg with index:721
# Processing file: frame_722.jpg with index:722
# Processing file: frame_723.jpg with index:723
# Processing file: frame_724.jpg with index:724
# Processing file: frame_725.jpg with index:725
# Processing file: frame_726.jpg with index:726
# Processing file: frame_727.jpg with index:727
# Processing file: frame_728.jpg with index:728
# Processing file: frame_729.jpg with index:729
# Processing file: frame_73.jpg with index:73
# Processing file: frame_730.jpg with index:730
# Processing file: frame_731.jpg with index:731
# Processing file: frame_732.jpg with index:732
# Processing file: frame_733.jpg with index:733
# Processing file: frame_734.jpg with index:734
# Processing file: frame_735.jpg with index:735
# Processing file: frame_736.jpg with index:736
# Processing file: frame_737.jpg with index:737
# Processing file: frame_738.jpg with index:738
# Processing file: frame_739.jpg with index:739
# Processing file: frame_74.jpg with index:74
# Processing file: frame_740.jpg with index:740
# Processing file: frame_741.jpg with index:741
# Processing file: frame_742.jpg with index:742
# Processing file: frame_743.jpg with index:743
# Processing file: frame_744.jpg with index:744
# Processing file: frame_745.jpg with index:745
# Processing file: frame_746.jpg with index:746
# Processing file: frame_747.jpg with index:747
# Processing file: frame_748.jpg with index:748
# Processing file: frame_749.jpg with index:749
# Processing file: frame_75.jpg with index:75
# Processing file: frame_750.jpg with index:750
# Processing file: frame_751.jpg with index:751
# Processing file: frame_752.jpg with index:752
# Processing file: frame_753.jpg with index:753
# Processing file: frame_754.jpg with index:754
# Processing file: frame_755.jpg with index:755
# Processing file: frame_756.jpg with index:756
# Processing file: frame_757.jpg with index:757
# Processing file: frame_758.jpg with index:758
# Processing file: frame_759.jpg with index:759
# Processing file: frame_76.jpg with index:76
# Processing file: frame_760.jpg with index:760
# Processing file: frame_761.jpg with index:761
# Processing file: frame_762.jpg with index:762
# Processing file: frame_763.jpg with index:763
# Processing file: frame_764.jpg with index:764
# Processing file: frame_765.jpg with index:765
# Processing file: frame_766.jpg with index:766
# Processing file: frame_767.jpg with index:767
# Processing file: frame_768.jpg with index:768
# Processing file: frame_769.jpg with index:769
# Processing file: frame_77.jpg with index:77
# Processing file: frame_770.jpg with index:770
# Processing file: frame_771.jpg with index:771
# Processing file: frame_772.jpg with index:772
# Processing file: frame_773.jpg with index:773
# Processing file: frame_774.jpg with index:774
# Processing file: frame_775.jpg with index:775
# Processing file: frame_776.jpg with index:776
# Processing file: frame_777.jpg with index:777
# Processing file: frame_778.jpg with index:778
# Processing file: frame_779.jpg with index:779
# Processing file: frame_78.jpg with index:78
# Processing file: frame_780.jpg with index:780
# Processing file: frame_781.jpg with index:781
# Processing file: frame_782.jpg with index:782
# Processing file: frame_783.jpg with index:783
# Processing file: frame_784.jpg with index:784
# Processing file: frame_785.jpg with index:785
# Processing file: frame_786.jpg with index:786
# Processing file: frame_787.jpg with index:787
# Processing file: frame_788.jpg with index:788
# Processing file: frame_789.jpg with index:789
# Processing file: frame_79.jpg with index:79
# Processing file: frame_790.jpg with index:790
# Processing file: frame_791.jpg with index:791
# Processing file: frame_792.jpg with index:792
# Processing file: frame_793.jpg with index:793
# Processing file: frame_794.jpg with index:794
# Processing file: frame_795.jpg with index:795
# Processing file: frame_796.jpg with index:796
# Processing file: frame_797.jpg with index:797
# Processing file: frame_798.jpg with index:798
# Processing file: frame_799.jpg with index:799
# Processing file: frame_8.jpg with index:8
# Processing file: frame_80.jpg with index:80
# Processing file: frame_800.jpg with index:800
# Processing file: frame_801.jpg with index:801
# Processing file: frame_802.jpg with index:802
# Processing file: frame_803.jpg with index:803
# Processing file: frame_804.jpg with index:804
# Processing file: frame_805.jpg with index:805
# Processing file: frame_806.jpg with index:806
# Processing file: frame_807.jpg with index:807
# Processing file: frame_808.jpg with index:808
# Processing file: frame_809.jpg with index:809
# Processing file: frame_81.jpg with index:81
# Processing file: frame_810.jpg with index:810
# Processing file: frame_811.jpg with index:811
# Processing file: frame_812.jpg with index:812
# Processing file: frame_813.jpg with index:813
# Processing file: frame_814.jpg with index:814
# Processing file: frame_815.jpg with index:815
# Processing file: frame_816.jpg with index:816
# Processing file: frame_817.jpg with index:817
# Processing file: frame_818.jpg with index:818
# Processing file: frame_819.jpg with index:819
# Processing file: frame_82.jpg with index:82
# Processing file: frame_820.jpg with index:820
# Processing file: frame_821.jpg with index:821
# Processing file: frame_822.jpg with index:822
# Processing file: frame_823.jpg with index:823
# Processing file: frame_824.jpg with index:824
# Processing file: frame_825.jpg with index:825
# Processing file: frame_826.jpg with index:826
# Processing file: frame_827.jpg with index:827
# Processing file: frame_828.jpg with index:828
# Processing file: frame_829.jpg with index:829
# Processing file: frame_83.jpg with index:83
# Processing file: frame_830.jpg with index:830
# Processing file: frame_831.jpg with index:831
# Processing file: frame_832.jpg with index:832
# Processing file: frame_833.jpg with index:833
# Processing file: frame_834.jpg with index:834
# Processing file: frame_835.jpg with index:835
# Processing file: frame_836.jpg with index:836
# Processing file: frame_837.jpg with index:837
# Processing file: frame_838.jpg with index:838
# Processing file: frame_839.jpg with index:839
# Processing file: frame_84.jpg with index:84
# Processing file: frame_840.jpg with index:840
# Processing file: frame_841.jpg with index:841
# Processing file: frame_842.jpg with index:842
# Processing file: frame_843.jpg with index:843
# Processing file: frame_844.jpg with index:844
# Processing file: frame_845.jpg with index:845
# Processing file: frame_846.jpg with index:846
# Processing file: frame_847.jpg with index:847
# Processing file: frame_848.jpg with index:848
# Processing file: frame_849.jpg with index:849
# Processing file: frame_85.jpg with index:85
# Processing file: frame_850.jpg with index:850
# Processing file: frame_851.jpg with index:851
# Processing file: frame_852.jpg with index:852
# Processing file: frame_853.jpg with index:853
# Processing file: frame_854.jpg with index:854
# Processing file: frame_855.jpg with index:855
# Processing file: frame_856.jpg with index:856
# Processing file: frame_857.jpg with index:857
# Processing file: frame_858.jpg with index:858
# Processing file: frame_859.jpg with index:859
# Processing file: frame_86.jpg with index:86
# Processing file: frame_860.jpg with index:860
# Processing file: frame_861.jpg with index:861
# Processing file: frame_862.jpg with index:862
# Processing file: frame_863.jpg with index:863
# Processing file: frame_864.jpg with index:864
# Processing file: frame_865.jpg with index:865
# Processing file: frame_866.jpg with index:866
# Processing file: frame_867.jpg with index:867
# Processing file: frame_868.jpg with index:868
# Processing file: frame_869.jpg with index:869
# Processing file: frame_87.jpg with index:87
# Processing file: frame_870.jpg with index:870
# Processing file: frame_871.jpg with index:871
# Processing file: frame_872.jpg with index:872
# Processing file: frame_873.jpg with index:873
# Processing file: frame_874.jpg with index:874
# Processing file: frame_875.jpg with index:875
# Processing file: frame_876.jpg with index:876
# Processing file: frame_877.jpg with index:877
# Processing file: frame_878.jpg with index:878
# Processing file: frame_879.jpg with index:879
# Processing file: frame_88.jpg with index:88
# Processing file: frame_880.jpg with index:880
# Processing file: frame_881.jpg with index:881
# Processing file: frame_882.jpg with index:882
# Processing file: frame_883.jpg with index:883
# Processing file: frame_884.jpg with index:884
# Processing file: frame_885.jpg with index:885
# Processing file: frame_886.jpg with index:886
# Processing file: frame_887.jpg with index:887
# Processing file: frame_888.jpg with index:888
# Processing file: frame_889.jpg with index:889
# Processing file: frame_89.jpg with index:89
# Processing file: frame_890.jpg with index:890
# Processing file: frame_891.jpg with index:891
# Processing file: frame_892.jpg with index:892
# Processing file: frame_893.jpg with index:893
# Processing file: frame_894.jpg with index:894
# Processing file: frame_895.jpg with index:895
# Processing file: frame_896.jpg with index:896
# Processing file: frame_897.jpg with index:897
# Processing file: frame_898.jpg with index:898
# Processing file: frame_899.jpg with index:899
# Processing file: frame_9.jpg with index:9
# Processing file: frame_90.jpg with index:90
# Processing file: frame_900.jpg with index:900
# Processing file: frame_901.jpg with index:901
# Processing file: frame_902.jpg with index:902
# Processing file: frame_903.jpg with index:903
# Processing file: frame_904.jpg with index:904
# Processing file: frame_905.jpg with index:905
# Processing file: frame_906.jpg with index:906
# Processing file: frame_907.jpg with index:907
# Processing file: frame_908.jpg with index:908
# Processing file: frame_909.jpg with index:909
# Processing file: frame_91.jpg with index:91
# Processing file: frame_910.jpg with index:910
# Processing file: frame_911.jpg with index:911
# Processing file: frame_912.jpg with index:912
# Processing file: frame_913.jpg with index:913
# Processing file: frame_914.jpg with index:914
# Processing file: frame_915.jpg with index:915
# Processing file: frame_916.jpg with index:916
# Processing file: frame_917.jpg with index:917
# Processing file: frame_918.jpg with index:918
# Processing file: frame_919.jpg with index:919
# Processing file: frame_92.jpg with index:92
# Processing file: frame_920.jpg with index:920
# Processing file: frame_921.jpg with index:921
# Processing file: frame_922.jpg with index:922
# Processing file: frame_923.jpg with index:923
# Processing file: frame_924.jpg with index:924
# Processing file: frame_925.jpg with index:925
# Processing file: frame_926.jpg with index:926
# Processing file: frame_927.jpg with index:927
# Processing file: frame_928.jpg with index:928
# Processing file: frame_929.jpg with index:929
# Processing file: frame_93.jpg with index:93
# Processing file: frame_930.jpg with index:930
# Processing file: frame_931.jpg with index:931
# Processing file: frame_932.jpg with index:932
# Processing file: frame_933.jpg with index:933
# Processing file: frame_934.jpg with index:934
# Processing file: frame_935.jpg with index:935
# Processing file: frame_936.jpg with index:936
# Processing file: frame_937.jpg with index:937
# Processing file: frame_938.jpg with index:938
# Processing file: frame_939.jpg with index:939
# Processing file: frame_94.jpg with index:94
# Processing file: frame_940.jpg with index:940
# Processing file: frame_941.jpg with index:941
# Processing file: frame_942.jpg with index:942
# Processing file: frame_943.jpg with index:943
# Processing file: frame_944.jpg with index:944
# Processing file: frame_945.jpg with index:945
# Processing file: frame_946.jpg with index:946
# Processing file: frame_947.jpg with index:947
# Processing file: frame_948.jpg with index:948
# Processing file: frame_949.jpg with index:949
# Processing file: frame_95.jpg with index:95
# Processing file: frame_950.jpg with index:950
# Processing file: frame_951.jpg with index:951
# Processing file: frame_952.jpg with index:952
# Processing file: frame_953.jpg with index:953
# Processing file: frame_954.jpg with index:954
# Processing file: frame_955.jpg with index:955
# Processing file: frame_956.jpg with index:956
# Processing file: frame_957.jpg with index:957
# Processing file: frame_958.jpg with index:958
# Processing file: frame_959.jpg with index:959
# Processing file: frame_96.jpg with index:96
# Processing file: frame_960.jpg with index:960
# Processing file: frame_961.jpg with index:961
# Processing file: frame_962.jpg with index:962
# Processing file: frame_963.jpg with index:963
# Processing file: frame_964.jpg with index:964
# Processing file: frame_965.jpg with index:965
# Processing file: frame_966.jpg with index:966
# Processing file: frame_967.jpg with index:967
# Processing file: frame_968.jpg with index:968
# Processing file: frame_969.jpg with index:969
# Processing file: frame_97.jpg with index:97
# Processing file: frame_970.jpg with index:970
# Processing file: frame_971.jpg with index:971
# Processing file: frame_972.jpg with index:972
# Processing file: frame_973.jpg with index:973
# Processing file: frame_974.jpg with index:974
# Processing file: frame_975.jpg with index:975
# Processing file: frame_976.jpg with index:976
# Processing file: frame_977.jpg with index:977
# Processing file: frame_978.jpg with index:978
# Processing file: frame_979.jpg with index:979
# Processing file: frame_98.jpg with index:98
# Processing file: frame_980.jpg with index:980
# Processing file: frame_981.jpg with index:981
# Processing file: frame_982.jpg with index:982
# Processing file: frame_983.jpg with index:983
# Processing file: frame_984.jpg with index:984
# Processing file: frame_985.jpg with index:985
# Processing file: frame_986.jpg with index:986
# Processing file: frame_987.jpg with index:987
# Processing file: frame_988.jpg with index:988
# Processing file: frame_989.jpg with index:989
# Processing file: frame_99.jpg with index:99
# Processing file: frame_990.jpg with index:990
# Processing file: frame_991.jpg with index:991
# Processing file: frame_992.jpg with index:992
# Processing file: frame_993.jpg with index:993
# Processing file: frame_994.jpg with index:994
# Processing file: frame_995.jpg with index:995
# Processing file: frame_996.jpg with index:996
# Processing file: frame_997.jpg with index:997
# Processing file: frame_998.jpg with index:998
# Processing file: frame_999.jpg with index:999
# Results saved in: /kaggle/working/bounding_boxes_5_model.json

# %%
image_folder = '/kaggle/input/computer-vision-futbal/dataset/dataset/test/ID-6'
output_file = '/kaggle/working/bounding_boxes_6_model.json'
process_images(model, image_folder, output_file)
# Out:
# Usando device: cuda
# Processing file: frame_0.jpg with index:0
# Processing file: frame_1.jpg with index:1
# Processing file: frame_10.jpg with index:10
# Processing file: frame_100.jpg with index:100
# Processing file: frame_1000.jpg with index:1000
# Processing file: frame_1001.jpg with index:1001
# Processing file: frame_1002.jpg with index:1002
# Processing file: frame_1003.jpg with index:1003
# Processing file: frame_1004.jpg with index:1004
# Processing file: frame_1005.jpg with index:1005
# Processing file: frame_1006.jpg with index:1006
# Processing file: frame_1007.jpg with index:1007
# Processing file: frame_1008.jpg with index:1008
# Processing file: frame_1009.jpg with index:1009
# Processing file: frame_101.jpg with index:101
# Processing file: frame_1010.jpg with index:1010
# Processing file: frame_1011.jpg with index:1011
# Processing file: frame_1012.jpg with index:1012
# Processing file: frame_1013.jpg with index:1013
# Processing file: frame_1014.jpg with index:1014
# Processing file: frame_1015.jpg with index:1015
# Processing file: frame_1016.jpg with index:1016
# Processing file: frame_1017.jpg with index:1017
# Processing file: frame_1018.jpg with index:1018
# Processing file: frame_1019.jpg with index:1019
# Processing file: frame_102.jpg with index:102
# Processing file: frame_1020.jpg with index:1020
# Processing file: frame_1021.jpg with index:1021
# Processing file: frame_1022.jpg with index:1022
# Processing file: frame_1023.jpg with index:1023
# Processing file: frame_1024.jpg with index:1024
# Processing file: frame_1025.jpg with index:1025
# Processing file: frame_1026.jpg with index:1026
# Processing file: frame_1027.jpg with index:1027
# Processing file: frame_1028.jpg with index:1028
# Processing file: frame_1029.jpg with index:1029
# Processing file: frame_103.jpg with index:103
# Processing file: frame_1030.jpg with index:1030
# Processing file: frame_1031.jpg with index:1031
# Processing file: frame_1032.jpg with index:1032
# Processing file: frame_1033.jpg with index:1033
# Processing file: frame_1034.jpg with index:1034
# Processing file: frame_1035.jpg with index:1035
# Processing file: frame_1036.jpg with index:1036
# Processing file: frame_1037.jpg with index:1037
# Processing file: frame_1038.jpg with index:1038
# Processing file: frame_1039.jpg with index:1039
# Processing file: frame_104.jpg with index:104
# Processing file: frame_1040.jpg with index:1040
# Processing file: frame_1041.jpg with index:1041
# Processing file: frame_1042.jpg with index:1042
# Processing file: frame_1043.jpg with index:1043
# Processing file: frame_1044.jpg with index:1044
# Processing file: frame_1045.jpg with index:1045
# Processing file: frame_1046.jpg with index:1046
# Processing file: frame_1047.jpg with index:1047
# Processing file: frame_1048.jpg with index:1048
# Processing file: frame_1049.jpg with index:1049
# Processing file: frame_105.jpg with index:105
# Processing file: frame_1050.jpg with index:1050
# Processing file: frame_1051.jpg with index:1051
# Processing file: frame_1052.jpg with index:1052
# Processing file: frame_1053.jpg with index:1053
# Processing file: frame_1054.jpg with index:1054
# Processing file: frame_1055.jpg with index:1055
# Processing file: frame_1056.jpg with index:1056
# Processing file: frame_1057.jpg with index:1057
# Processing file: frame_1058.jpg with index:1058
# Processing file: frame_1059.jpg with index:1059
# Processing file: frame_106.jpg with index:106
# Processing file: frame_1060.jpg with index:1060
# Processing file: frame_1061.jpg with index:1061
# Processing file: frame_1062.jpg with index:1062
# Processing file: frame_1063.jpg with index:1063
# Processing file: frame_1064.jpg with index:1064
# Processing file: frame_1065.jpg with index:1065
# Processing file: frame_1066.jpg with index:1066
# Processing file: frame_1067.jpg with index:1067
# Processing file: frame_1068.jpg with index:1068
# Processing file: frame_1069.jpg with index:1069
# Processing file: frame_107.jpg with index:107
# Processing file: frame_1070.jpg with index:1070
# Processing file: frame_1071.jpg with index:1071
# Processing file: frame_1072.jpg with index:1072
# Processing file: frame_1073.jpg with index:1073
# Processing file: frame_1074.jpg with index:1074
# Processing file: frame_1075.jpg with index:1075
# Processing file: frame_1076.jpg with index:1076
# Processing file: frame_1077.jpg with index:1077
# Processing file: frame_1078.jpg with index:1078
# Processing file: frame_1079.jpg with index:1079
# Processing file: frame_108.jpg with index:108
# Processing file: frame_1080.jpg with index:1080
# Processing file: frame_1081.jpg with index:1081
# Processing file: frame_1082.jpg with index:1082
# Processing file: frame_1083.jpg with index:1083
# Processing file: frame_1084.jpg with index:1084
# Processing file: frame_1085.jpg with index:1085
# Processing file: frame_1086.jpg with index:1086
# Processing file: frame_1087.jpg with index:1087
# Processing file: frame_1088.jpg with index:1088
# Processing file: frame_1089.jpg with index:1089
# Processing file: frame_109.jpg with index:109
# Processing file: frame_1090.jpg with index:1090
# Processing file: frame_1091.jpg with index:1091
# Processing file: frame_1092.jpg with index:1092
# Processing file: frame_1093.jpg with index:1093
# Processing file: frame_1094.jpg with index:1094
# Processing file: frame_1095.jpg with index:1095
# Processing file: frame_1096.jpg with index:1096
# Processing file: frame_1097.jpg with index:1097
# Processing file: frame_1098.jpg with index:1098
# Processing file: frame_1099.jpg with index:1099
# Processing file: frame_11.jpg with index:11
# Processing file: frame_110.jpg with index:110
# Processing file: frame_1100.jpg with index:1100
# Processing file: frame_1101.jpg with index:1101
# Processing file: frame_1102.jpg with index:1102
# Processing file: frame_1103.jpg with index:1103
# Processing file: frame_1104.jpg with index:1104
# Processing file: frame_1105.jpg with index:1105
# Processing file: frame_1106.jpg with index:1106
# Processing file: frame_1107.jpg with index:1107
# Processing file: frame_1108.jpg with index:1108
# Processing file: frame_1109.jpg with index:1109
# Processing file: frame_111.jpg with index:111
# Processing file: frame_1110.jpg with index:1110
# Processing file: frame_1111.jpg with index:1111
# Processing file: frame_1112.jpg with index:1112
# Processing file: frame_1113.jpg with index:1113
# Processing file: frame_1114.jpg with index:1114
# Processing file: frame_1115.jpg with index:1115
# Processing file: frame_1116.jpg with index:1116
# Processing file: frame_1117.jpg with index:1117
# Processing file: frame_1118.jpg with index:1118
# Processing file: frame_1119.jpg with index:1119
# Processing file: frame_112.jpg with index:112
# Processing file: frame_1120.jpg with index:1120
# Processing file: frame_1121.jpg with index:1121
# Processing file: frame_1122.jpg with index:1122
# Processing file: frame_1123.jpg with index:1123
# Processing file: frame_1124.jpg with index:1124
# Processing file: frame_1125.jpg with index:1125
# Processing file: frame_1126.jpg with index:1126
# Processing file: frame_1127.jpg with index:1127
# Processing file: frame_1128.jpg with index:1128
# Processing file: frame_1129.jpg with index:1129
# Processing file: frame_113.jpg with index:113
# Processing file: frame_1130.jpg with index:1130
# Processing file: frame_1131.jpg with index:1131
# Processing file: frame_1132.jpg with index:1132
# Processing file: frame_1133.jpg with index:1133
# Processing file: frame_1134.jpg with index:1134
# Processing file: frame_1135.jpg with index:1135
# Processing file: frame_1136.jpg with index:1136
# Processing file: frame_1137.jpg with index:1137
# Processing file: frame_1138.jpg with index:1138
# Processing file: frame_1139.jpg with index:1139
# Processing file: frame_114.jpg with index:114
# Processing file: frame_1140.jpg with index:1140
# Processing file: frame_1141.jpg with index:1141
# Processing file: frame_1142.jpg with index:1142
# Processing file: frame_1143.jpg with index:1143
# Processing file: frame_1144.jpg with index:1144
# Processing file: frame_1145.jpg with index:1145
# Processing file: frame_1146.jpg with index:1146
# Processing file: frame_1147.jpg with index:1147
# Processing file: frame_1148.jpg with index:1148
# Processing file: frame_1149.jpg with index:1149
# Processing file: frame_115.jpg with index:115
# Processing file: frame_1150.jpg with index:1150
# Processing file: frame_1151.jpg with index:1151
# Processing file: frame_1152.jpg with index:1152
# Processing file: frame_1153.jpg with index:1153
# Processing file: frame_1154.jpg with index:1154
# Processing file: frame_1155.jpg with index:1155
# Processing file: frame_1156.jpg with index:1156
# Processing file: frame_1157.jpg with index:1157
# Processing file: frame_1158.jpg with index:1158
# Processing file: frame_1159.jpg with index:1159
# Processing file: frame_116.jpg with index:116
# Processing file: frame_1160.jpg with index:1160
# Processing file: frame_1161.jpg with index:1161
# Processing file: frame_1162.jpg with index:1162
# Processing file: frame_1163.jpg with index:1163
# Processing file: frame_1164.jpg with index:1164
# Processing file: frame_1165.jpg with index:1165
# Processing file: frame_1166.jpg with index:1166
# Processing file: frame_1167.jpg with index:1167
# Processing file: frame_1168.jpg with index:1168
# Processing file: frame_1169.jpg with index:1169
# Processing file: frame_117.jpg with index:117
# Processing file: frame_1170.jpg with index:1170
# Processing file: frame_1171.jpg with index:1171
# Processing file: frame_1172.jpg with index:1172
# Processing file: frame_1173.jpg with index:1173
# Processing file: frame_1174.jpg with index:1174
# Processing file: frame_1175.jpg with index:1175
# Processing file: frame_1176.jpg with index:1176
# Processing file: frame_1177.jpg with index:1177
# Processing file: frame_1178.jpg with index:1178
# Processing file: frame_1179.jpg with index:1179
# Processing file: frame_118.jpg with index:118
# Processing file: frame_1180.jpg with index:1180
# Processing file: frame_1181.jpg with index:1181
# Processing file: frame_1182.jpg with index:1182
# Processing file: frame_1183.jpg with index:1183
# Processing file: frame_1184.jpg with index:1184
# Processing file: frame_1185.jpg with index:1185
# Processing file: frame_1186.jpg with index:1186
# Processing file: frame_1187.jpg with index:1187
# Processing file: frame_1188.jpg with index:1188
# Processing file: frame_1189.jpg with index:1189
# Processing file: frame_119.jpg with index:119
# Processing file: frame_1190.jpg with index:1190
# Processing file: frame_1191.jpg with index:1191
# Processing file: frame_1192.jpg with index:1192
# Processing file: frame_1193.jpg with index:1193
# Processing file: frame_1194.jpg with index:1194
# Processing file: frame_1195.jpg with index:1195
# Processing file: frame_1196.jpg with index:1196
# Processing file: frame_1197.jpg with index:1197
# Processing file: frame_1198.jpg with index:1198
# Processing file: frame_1199.jpg with index:1199
# Processing file: frame_12.jpg with index:12
# Processing file: frame_120.jpg with index:120
# Processing file: frame_1200.jpg with index:1200
# Processing file: frame_1201.jpg with index:1201
# Processing file: frame_1202.jpg with index:1202
# Processing file: frame_1203.jpg with index:1203
# Processing file: frame_1204.jpg with index:1204
# Processing file: frame_1205.jpg with index:1205
# Processing file: frame_1206.jpg with index:1206
# Processing file: frame_1207.jpg with index:1207
# Processing file: frame_1208.jpg with index:1208
# Processing file: frame_1209.jpg with index:1209
# Processing file: frame_121.jpg with index:121
# Processing file: frame_1210.jpg with index:1210
# Processing file: frame_1211.jpg with index:1211
# Processing file: frame_1212.jpg with index:1212
# Processing file: frame_1213.jpg with index:1213
# Processing file: frame_1214.jpg with index:1214
# Processing file: frame_1215.jpg with index:1215
# Processing file: frame_1216.jpg with index:1216
# Processing file: frame_1217.jpg with index:1217
# Processing file: frame_1218.jpg with index:1218
# Processing file: frame_1219.jpg with index:1219
# Processing file: frame_122.jpg with index:122
# Processing file: frame_1220.jpg with index:1220
# Processing file: frame_1221.jpg with index:1221
# Processing file: frame_1222.jpg with index:1222
# Processing file: frame_1223.jpg with index:1223
# Processing file: frame_1224.jpg with index:1224
# Processing file: frame_1225.jpg with index:1225
# Processing file: frame_1226.jpg with index:1226
# Processing file: frame_1227.jpg with index:1227
# Processing file: frame_1228.jpg with index:1228
# Processing file: frame_1229.jpg with index:1229
# Processing file: frame_123.jpg with index:123
# Processing file: frame_1230.jpg with index:1230
# Processing file: frame_1231.jpg with index:1231
# Processing file: frame_1232.jpg with index:1232
# Processing file: frame_1233.jpg with index:1233
# Processing file: frame_1234.jpg with index:1234
# Processing file: frame_1235.jpg with index:1235
# Processing file: frame_1236.jpg with index:1236
# Processing file: frame_1237.jpg with index:1237
# Processing file: frame_1238.jpg with index:1238
# Processing file: frame_1239.jpg with index:1239
# Processing file: frame_124.jpg with index:124
# Processing file: frame_1240.jpg with index:1240
# Processing file: frame_1241.jpg with index:1241
# Processing file: frame_1242.jpg with index:1242
# Processing file: frame_1243.jpg with index:1243
# Processing file: frame_1244.jpg with index:1244
# Processing file: frame_1245.jpg with index:1245
# Processing file: frame_1246.jpg with index:1246
# Processing file: frame_1247.jpg with index:1247
# Processing file: frame_1248.jpg with index:1248
# Processing file: frame_1249.jpg with index:1249
# Processing file: frame_125.jpg with index:125
# Processing file: frame_1250.jpg with index:1250
# Processing file: frame_1251.jpg with index:1251
# Processing file: frame_1252.jpg with index:1252
# Processing file: frame_1253.jpg with index:1253
# Processing file: frame_1254.jpg with index:1254
# Processing file: frame_1255.jpg with index:1255
# Processing file: frame_1256.jpg with index:1256
# Processing file: frame_1257.jpg with index:1257
# Processing file: frame_1258.jpg with index:1258
# Processing file: frame_1259.jpg with index:1259
# Processing file: frame_126.jpg with index:126
# Processing file: frame_1260.jpg with index:1260
# Processing file: frame_1261.jpg with index:1261
# Processing file: frame_1262.jpg with index:1262
# Processing file: frame_1263.jpg with index:1263
# Processing file: frame_1264.jpg with index:1264
# Processing file: frame_1265.jpg with index:1265
# Processing file: frame_1266.jpg with index:1266
# Processing file: frame_1267.jpg with index:1267
# Processing file: frame_1268.jpg with index:1268
# Processing file: frame_1269.jpg with index:1269
# Processing file: frame_127.jpg with index:127
# Processing file: frame_1270.jpg with index:1270
# Processing file: frame_1271.jpg with index:1271
# Processing file: frame_1272.jpg with index:1272
# Processing file: frame_1273.jpg with index:1273
# Processing file: frame_1274.jpg with index:1274
# Processing file: frame_1275.jpg with index:1275
# Processing file: frame_1276.jpg with index:1276
# Processing file: frame_1277.jpg with index:1277
# Processing file: frame_1278.jpg with index:1278
# Processing file: frame_1279.jpg with index:1279
# Processing file: frame_128.jpg with index:128
# Processing file: frame_1280.jpg with index:1280
# Processing file: frame_1281.jpg with index:1281
# Processing file: frame_1282.jpg with index:1282
# Processing file: frame_1283.jpg with index:1283
# Processing file: frame_1284.jpg with index:1284
# Processing file: frame_1285.jpg with index:1285
# Processing file: frame_1286.jpg with index:1286
# Processing file: frame_1287.jpg with index:1287
# Processing file: frame_1288.jpg with index:1288
# Processing file: frame_1289.jpg with index:1289
# Processing file: frame_129.jpg with index:129
# Processing file: frame_1290.jpg with index:1290
# Processing file: frame_1291.jpg with index:1291
# Processing file: frame_1292.jpg with index:1292
# Processing file: frame_1293.jpg with index:1293
# Processing file: frame_1294.jpg with index:1294
# Processing file: frame_1295.jpg with index:1295
# Processing file: frame_1296.jpg with index:1296
# Processing file: frame_1297.jpg with index:1297
# Processing file: frame_1298.jpg with index:1298
# Processing file: frame_1299.jpg with index:1299
# Processing file: frame_13.jpg with index:13
# Processing file: frame_130.jpg with index:130
# Processing file: frame_1300.jpg with index:1300
# Processing file: frame_1301.jpg with index:1301
# Processing file: frame_1302.jpg with index:1302
# Processing file: frame_1303.jpg with index:1303
# Processing file: frame_1304.jpg with index:1304
# Processing file: frame_1305.jpg with index:1305
# Processing file: frame_1306.jpg with index:1306
# Processing file: frame_1307.jpg with index:1307
# Processing file: frame_1308.jpg with index:1308
# Processing file: frame_1309.jpg with index:1309
# Processing file: frame_131.jpg with index:131
# Processing file: frame_1310.jpg with index:1310
# Processing file: frame_1311.jpg with index:1311
# Processing file: frame_1312.jpg with index:1312
# Processing file: frame_1313.jpg with index:1313
# Processing file: frame_1314.jpg with index:1314
# Processing file: frame_1315.jpg with index:1315
# Processing file: frame_1316.jpg with index:1316
# Processing file: frame_1317.jpg with index:1317
# Processing file: frame_1318.jpg with index:1318
# Processing file: frame_1319.jpg with index:1319
# Processing file: frame_132.jpg with index:132
# Processing file: frame_1320.jpg with index:1320
# Processing file: frame_1321.jpg with index:1321
# Processing file: frame_1322.jpg with index:1322
# Processing file: frame_1323.jpg with index:1323
# Processing file: frame_1324.jpg with index:1324
# Processing file: frame_1325.jpg with index:1325
# Processing file: frame_1326.jpg with index:1326
# Processing file: frame_1327.jpg with index:1327
# Processing file: frame_1328.jpg with index:1328
# Processing file: frame_1329.jpg with index:1329
# Processing file: frame_133.jpg with index:133
# Processing file: frame_1330.jpg with index:1330
# Processing file: frame_1331.jpg with index:1331
# Processing file: frame_1332.jpg with index:1332
# Processing file: frame_1333.jpg with index:1333
# Processing file: frame_1334.jpg with index:1334
# Processing file: frame_1335.jpg with index:1335
# Processing file: frame_1336.jpg with index:1336
# Processing file: frame_1337.jpg with index:1337
# Processing file: frame_1338.jpg with index:1338
# Processing file: frame_1339.jpg with index:1339
# Processing file: frame_134.jpg with index:134
# Processing file: frame_1340.jpg with index:1340
# Processing file: frame_1341.jpg with index:1341
# Processing file: frame_1342.jpg with index:1342
# Processing file: frame_1343.jpg with index:1343
# Processing file: frame_1344.jpg with index:1344
# Processing file: frame_1345.jpg with index:1345
# Processing file: frame_1346.jpg with index:1346
# Processing file: frame_1347.jpg with index:1347
# Processing file: frame_1348.jpg with index:1348
# Processing file: frame_1349.jpg with index:1349
# Processing file: frame_135.jpg with index:135
# Processing file: frame_1350.jpg with index:1350
# Processing file: frame_1351.jpg with index:1351
# Processing file: frame_1352.jpg with index:1352
# Processing file: frame_1353.jpg with index:1353
# Processing file: frame_1354.jpg with index:1354
# Processing file: frame_1355.jpg with index:1355
# Processing file: frame_1356.jpg with index:1356
# Processing file: frame_1357.jpg with index:1357
# Processing file: frame_1358.jpg with index:1358
# Processing file: frame_1359.jpg with index:1359
# Processing file: frame_136.jpg with index:136
# Processing file: frame_1360.jpg with index:1360
# Processing file: frame_1361.jpg with index:1361
# Processing file: frame_1362.jpg with index:1362
# Processing file: frame_1363.jpg with index:1363
# Processing file: frame_1364.jpg with index:1364
# Processing file: frame_1365.jpg with index:1365
# Processing file: frame_1366.jpg with index:1366
# Processing file: frame_1367.jpg with index:1367
# Processing file: frame_1368.jpg with index:1368
# Processing file: frame_1369.jpg with index:1369
# Processing file: frame_137.jpg with index:137
# Processing file: frame_1370.jpg with index:1370
# Processing file: frame_1371.jpg with index:1371
# Processing file: frame_1372.jpg with index:1372
# Processing file: frame_1373.jpg with index:1373
# Processing file: frame_1374.jpg with index:1374
# Processing file: frame_1375.jpg with index:1375
# Processing file: frame_1376.jpg with index:1376
# Processing file: frame_1377.jpg with index:1377
# Processing file: frame_1378.jpg with index:1378
# Processing file: frame_1379.jpg with index:1379
# Processing file: frame_138.jpg with index:138
# Processing file: frame_1380.jpg with index:1380
# Processing file: frame_1381.jpg with index:1381
# Processing file: frame_1382.jpg with index:1382
# Processing file: frame_1383.jpg with index:1383
# Processing file: frame_1384.jpg with index:1384
# Processing file: frame_1385.jpg with index:1385
# Processing file: frame_1386.jpg with index:1386
# Processing file: frame_1387.jpg with index:1387
# Processing file: frame_1388.jpg with index:1388
# Processing file: frame_1389.jpg with index:1389
# Processing file: frame_139.jpg with index:139
# Processing file: frame_1390.jpg with index:1390
# Processing file: frame_1391.jpg with index:1391
# Processing file: frame_1392.jpg with index:1392
# Processing file: frame_1393.jpg with index:1393
# Processing file: frame_1394.jpg with index:1394
# Processing file: frame_1395.jpg with index:1395
# Processing file: frame_1396.jpg with index:1396
# Processing file: frame_1397.jpg with index:1397
# Processing file: frame_1398.jpg with index:1398
# Processing file: frame_1399.jpg with index:1399
# Processing file: frame_14.jpg with index:14
# Processing file: frame_140.jpg with index:140
# Processing file: frame_1400.jpg with index:1400
# Processing file: frame_1401.jpg with index:1401
# Processing file: frame_1402.jpg with index:1402
# Processing file: frame_1403.jpg with index:1403
# Processing file: frame_1404.jpg with index:1404
# Processing file: frame_1405.jpg with index:1405
# Processing file: frame_1406.jpg with index:1406
# Processing file: frame_1407.jpg with index:1407
# Processing file: frame_1408.jpg with index:1408
# Processing file: frame_1409.jpg with index:1409
# Processing file: frame_141.jpg with index:141
# Processing file: frame_1410.jpg with index:1410
# Processing file: frame_1411.jpg with index:1411
# Processing file: frame_1412.jpg with index:1412
# Processing file: frame_1413.jpg with index:1413
# Processing file: frame_1414.jpg with index:1414
# Processing file: frame_1415.jpg with index:1415
# Processing file: frame_1416.jpg with index:1416
# Processing file: frame_1417.jpg with index:1417
# Processing file: frame_1418.jpg with index:1418
# Processing file: frame_1419.jpg with index:1419
# Processing file: frame_142.jpg with index:142
# Processing file: frame_1420.jpg with index:1420
# Processing file: frame_1421.jpg with index:1421
# Processing file: frame_1422.jpg with index:1422
# Processing file: frame_1423.jpg with index:1423
# Processing file: frame_1424.jpg with index:1424
# Processing file: frame_1425.jpg with index:1425
# Processing file: frame_1426.jpg with index:1426
# Processing file: frame_1427.jpg with index:1427
# Processing file: frame_1428.jpg with index:1428
# Processing file: frame_1429.jpg with index:1429
# Processing file: frame_143.jpg with index:143
# Processing file: frame_1430.jpg with index:1430
# Processing file: frame_1431.jpg with index:1431
# Processing file: frame_1432.jpg with index:1432
# Processing file: frame_1433.jpg with index:1433
# Processing file: frame_1434.jpg with index:1434
# Processing file: frame_1435.jpg with index:1435
# Processing file: frame_1436.jpg with index:1436
# Processing file: frame_1437.jpg with index:1437
# Processing file: frame_1438.jpg with index:1438
# Processing file: frame_1439.jpg with index:1439
# Processing file: frame_144.jpg with index:144
# Processing file: frame_1440.jpg with index:1440
# Processing file: frame_1441.jpg with index:1441
# Processing file: frame_1442.jpg with index:1442
# Processing file: frame_1443.jpg with index:1443
# Processing file: frame_1444.jpg with index:1444
# Processing file: frame_1445.jpg with index:1445
# Processing file: frame_1446.jpg with index:1446
# Processing file: frame_1447.jpg with index:1447
# Processing file: frame_1448.jpg with index:1448
# Processing file: frame_1449.jpg with index:1449
# Processing file: frame_145.jpg with index:145
# Processing file: frame_1450.jpg with index:1450
# Processing file: frame_1451.jpg with index:1451
# Processing file: frame_1452.jpg with index:1452
# Processing file: frame_1453.jpg with index:1453
# Processing file: frame_1454.jpg with index:1454
# Processing file: frame_1455.jpg with index:1455
# Processing file: frame_1456.jpg with index:1456
# Processing file: frame_1457.jpg with index:1457
# Processing file: frame_1458.jpg with index:1458
# Processing file: frame_1459.jpg with index:1459
# Processing file: frame_146.jpg with index:146
# Processing file: frame_1460.jpg with index:1460
# Processing file: frame_1461.jpg with index:1461
# Processing file: frame_1462.jpg with index:1462
# Processing file: frame_1463.jpg with index:1463
# Processing file: frame_1464.jpg with index:1464
# Processing file: frame_1465.jpg with index:1465
# Processing file: frame_1466.jpg with index:1466
# Processing file: frame_1467.jpg with index:1467
# Processing file: frame_1468.jpg with index:1468
# Processing file: frame_1469.jpg with index:1469
# Processing file: frame_147.jpg with index:147
# Processing file: frame_1470.jpg with index:1470
# Processing file: frame_1471.jpg with index:1471
# Processing file: frame_1472.jpg with index:1472
# Processing file: frame_1473.jpg with index:1473
# Processing file: frame_1474.jpg with index:1474
# Processing file: frame_1475.jpg with index:1475
# Processing file: frame_1476.jpg with index:1476
# Processing file: frame_1477.jpg with index:1477
# Processing file: frame_1478.jpg with index:1478
# Processing file: frame_1479.jpg with index:1479
# Processing file: frame_148.jpg with index:148
# Processing file: frame_1480.jpg with index:1480
# Processing file: frame_1481.jpg with index:1481
# Processing file: frame_1482.jpg with index:1482
# Processing file: frame_1483.jpg with index:1483
# Processing file: frame_1484.jpg with index:1484
# Processing file: frame_1485.jpg with index:1485
# Processing file: frame_1486.jpg with index:1486
# Processing file: frame_1487.jpg with index:1487
# Processing file: frame_1488.jpg with index:1488
# Processing file: frame_1489.jpg with index:1489
# Processing file: frame_149.jpg with index:149
# Processing file: frame_1490.jpg with index:1490
# Processing file: frame_1491.jpg with index:1491
# Processing file: frame_1492.jpg with index:1492
# Processing file: frame_1493.jpg with index:1493
# Processing file: frame_1494.jpg with index:1494
# Processing file: frame_1495.jpg with index:1495
# Processing file: frame_1496.jpg with index:1496
# Processing file: frame_1497.jpg with index:1497
# Processing file: frame_1498.jpg with index:1498
# Processing file: frame_1499.jpg with index:1499
# Processing file: frame_15.jpg with index:15
# Processing file: frame_150.jpg with index:150
# Processing file: frame_1500.jpg with index:1500
# Processing file: frame_1501.jpg with index:1501
# Processing file: frame_1502.jpg with index:1502
# Processing file: frame_1503.jpg with index:1503
# Processing file: frame_1504.jpg with index:1504
# Processing file: frame_1505.jpg with index:1505
# Processing file: frame_1506.jpg with index:1506
# Processing file: frame_1507.jpg with index:1507
# Processing file: frame_1508.jpg with index:1508
# Processing file: frame_1509.jpg with index:1509
# Processing file: frame_151.jpg with index:151
# Processing file: frame_1510.jpg with index:1510
# Processing file: frame_1511.jpg with index:1511
# Processing file: frame_1512.jpg with index:1512
# Processing file: frame_1513.jpg with index:1513
# Processing file: frame_1514.jpg with index:1514
# Processing file: frame_1515.jpg with index:1515
# Processing file: frame_1516.jpg with index:1516
# Processing file: frame_1517.jpg with index:1517
# Processing file: frame_1518.jpg with index:1518
# Processing file: frame_1519.jpg with index:1519
# Processing file: frame_152.jpg with index:152
# Processing file: frame_1520.jpg with index:1520
# Processing file: frame_1521.jpg with index:1521
# Processing file: frame_1522.jpg with index:1522
# Processing file: frame_1523.jpg with index:1523
# Processing file: frame_1524.jpg with index:1524
# Processing file: frame_1525.jpg with index:1525
# Processing file: frame_1526.jpg with index:1526
# Processing file: frame_1527.jpg with index:1527
# Processing file: frame_1528.jpg with index:1528
# Processing file: frame_1529.jpg with index:1529
# Processing file: frame_153.jpg with index:153
# Processing file: frame_1530.jpg with index:1530
# Processing file: frame_1531.jpg with index:1531
# Processing file: frame_1532.jpg with index:1532
# Processing file: frame_1533.jpg with index:1533
# Processing file: frame_1534.jpg with index:1534
# Processing file: frame_1535.jpg with index:1535
# Processing file: frame_1536.jpg with index:1536
# Processing file: frame_1537.jpg with index:1537
# Processing file: frame_1538.jpg with index:1538
# Processing file: frame_1539.jpg with index:1539
# Processing file: frame_154.jpg with index:154
# Processing file: frame_1540.jpg with index:1540
# Processing file: frame_1541.jpg with index:1541
# Processing file: frame_1542.jpg with index:1542
# Processing file: frame_1543.jpg with index:1543
# Processing file: frame_1544.jpg with index:1544
# Processing file: frame_1545.jpg with index:1545
# Processing file: frame_1546.jpg with index:1546
# Processing file: frame_1547.jpg with index:1547
# Processing file: frame_1548.jpg with index:1548
# Processing file: frame_1549.jpg with index:1549
# Processing file: frame_155.jpg with index:155
# Processing file: frame_1550.jpg with index:1550
# Processing file: frame_1551.jpg with index:1551
# Processing file: frame_1552.jpg with index:1552
# Processing file: frame_1553.jpg with index:1553
# Processing file: frame_1554.jpg with index:1554
# Processing file: frame_1555.jpg with index:1555
# Processing file: frame_1556.jpg with index:1556
# Processing file: frame_1557.jpg with index:1557
# Processing file: frame_1558.jpg with index:1558
# Processing file: frame_1559.jpg with index:1559
# Processing file: frame_156.jpg with index:156
# Processing file: frame_1560.jpg with index:1560
# Processing file: frame_1561.jpg with index:1561
# Processing file: frame_1562.jpg with index:1562
# Processing file: frame_1563.jpg with index:1563
# Processing file: frame_1564.jpg with index:1564
# Processing file: frame_1565.jpg with index:1565
# Processing file: frame_1566.jpg with index:1566
# Processing file: frame_1567.jpg with index:1567
# Processing file: frame_1568.jpg with index:1568
# Processing file: frame_1569.jpg with index:1569
# Processing file: frame_157.jpg with index:157
# Processing file: frame_1570.jpg with index:1570
# Processing file: frame_1571.jpg with index:1571
# Processing file: frame_1572.jpg with index:1572
# Processing file: frame_1573.jpg with index:1573
# Processing file: frame_1574.jpg with index:1574
# Processing file: frame_1575.jpg with index:1575
# Processing file: frame_1576.jpg with index:1576
# Processing file: frame_1577.jpg with index:1577
# Processing file: frame_1578.jpg with index:1578
# Processing file: frame_1579.jpg with index:1579
# Processing file: frame_158.jpg with index:158
# Processing file: frame_1580.jpg with index:1580
# Processing file: frame_1581.jpg with index:1581
# Processing file: frame_1582.jpg with index:1582
# Processing file: frame_1583.jpg with index:1583
# Processing file: frame_1584.jpg with index:1584
# Processing file: frame_1585.jpg with index:1585
# Processing file: frame_1586.jpg with index:1586
# Processing file: frame_1587.jpg with index:1587
# Processing file: frame_1588.jpg with index:1588
# Processing file: frame_1589.jpg with index:1589
# Processing file: frame_159.jpg with index:159
# Processing file: frame_1590.jpg with index:1590
# Processing file: frame_1591.jpg with index:1591
# Processing file: frame_1592.jpg with index:1592
# Processing file: frame_1593.jpg with index:1593
# Processing file: frame_1594.jpg with index:1594
# Processing file: frame_1595.jpg with index:1595
# Processing file: frame_1596.jpg with index:1596
# Processing file: frame_1597.jpg with index:1597
# Processing file: frame_1598.jpg with index:1598
# Processing file: frame_1599.jpg with index:1599
# Processing file: frame_16.jpg with index:16
# Processing file: frame_160.jpg with index:160
# Processing file: frame_1600.jpg with index:1600
# Processing file: frame_1601.jpg with index:1601
# Processing file: frame_1602.jpg with index:1602
# Processing file: frame_1603.jpg with index:1603
# Processing file: frame_1604.jpg with index:1604
# Processing file: frame_1605.jpg with index:1605
# Processing file: frame_1606.jpg with index:1606
# Processing file: frame_1607.jpg with index:1607
# Processing file: frame_1608.jpg with index:1608
# Processing file: frame_1609.jpg with index:1609
# Processing file: frame_161.jpg with index:161
# Processing file: frame_1610.jpg with index:1610
# Processing file: frame_1611.jpg with index:1611
# Processing file: frame_1612.jpg with index:1612
# Processing file: frame_1613.jpg with index:1613
# Processing file: frame_1614.jpg with index:1614
# Processing file: frame_1615.jpg with index:1615
# Processing file: frame_1616.jpg with index:1616
# Processing file: frame_1617.jpg with index:1617
# Processing file: frame_1618.jpg with index:1618
# Processing file: frame_1619.jpg with index:1619
# Processing file: frame_162.jpg with index:162
# Processing file: frame_1620.jpg with index:1620
# Processing file: frame_1621.jpg with index:1621
# Processing file: frame_1622.jpg with index:1622
# Processing file: frame_1623.jpg with index:1623
# Processing file: frame_1624.jpg with index:1624
# Processing file: frame_1625.jpg with index:1625
# Processing file: frame_1626.jpg with index:1626
# Processing file: frame_1627.jpg with index:1627
# Processing file: frame_1628.jpg with index:1628
# Processing file: frame_1629.jpg with index:1629
# Processing file: frame_163.jpg with index:163
# Processing file: frame_1630.jpg with index:1630
# Processing file: frame_1631.jpg with index:1631
# Processing file: frame_1632.jpg with index:1632
# Processing file: frame_1633.jpg with index:1633
# Processing file: frame_1634.jpg with index:1634
# Processing file: frame_1635.jpg with index:1635
# Processing file: frame_1636.jpg with index:1636
# Processing file: frame_1637.jpg with index:1637
# Processing file: frame_1638.jpg with index:1638
# Processing file: frame_1639.jpg with index:1639
# Processing file: frame_164.jpg with index:164
# Processing file: frame_1640.jpg with index:1640
# Processing file: frame_1641.jpg with index:1641
# Processing file: frame_1642.jpg with index:1642
# Processing file: frame_1643.jpg with index:1643
# Processing file: frame_1644.jpg with index:1644
# Processing file: frame_1645.jpg with index:1645
# Processing file: frame_1646.jpg with index:1646
# Processing file: frame_1647.jpg with index:1647
# Processing file: frame_1648.jpg with index:1648
# Processing file: frame_1649.jpg with index:1649
# Processing file: frame_165.jpg with index:165
# Processing file: frame_1650.jpg with index:1650
# Processing file: frame_1651.jpg with index:1651
# Processing file: frame_1652.jpg with index:1652
# Processing file: frame_1653.jpg with index:1653
# Processing file: frame_1654.jpg with index:1654
# Processing file: frame_1655.jpg with index:1655
# Processing file: frame_1656.jpg with index:1656
# Processing file: frame_1657.jpg with index:1657
# Processing file: frame_1658.jpg with index:1658
# Processing file: frame_1659.jpg with index:1659
# Processing file: frame_166.jpg with index:166
# Processing file: frame_1660.jpg with index:1660
# Processing file: frame_1661.jpg with index:1661
# Processing file: frame_1662.jpg with index:1662
# Processing file: frame_1663.jpg with index:1663
# Processing file: frame_1664.jpg with index:1664
# Processing file: frame_1665.jpg with index:1665
# Processing file: frame_1666.jpg with index:1666
# Processing file: frame_1667.jpg with index:1667
# Processing file: frame_1668.jpg with index:1668
# Processing file: frame_1669.jpg with index:1669
# Processing file: frame_167.jpg with index:167
# Processing file: frame_1670.jpg with index:1670
# Processing file: frame_1671.jpg with index:1671
# Processing file: frame_1672.jpg with index:1672
# Processing file: frame_1673.jpg with index:1673
# Processing file: frame_1674.jpg with index:1674
# Processing file: frame_1675.jpg with index:1675
# Processing file: frame_1676.jpg with index:1676
# Processing file: frame_1677.jpg with index:1677
# Processing file: frame_1678.jpg with index:1678
# Processing file: frame_1679.jpg with index:1679
# Processing file: frame_168.jpg with index:168
# Processing file: frame_1680.jpg with index:1680
# Processing file: frame_1681.jpg with index:1681
# Processing file: frame_1682.jpg with index:1682
# Processing file: frame_1683.jpg with index:1683
# Processing file: frame_1684.jpg with index:1684
# Processing file: frame_1685.jpg with index:1685
# Processing file: frame_1686.jpg with index:1686
# Processing file: frame_1687.jpg with index:1687
# Processing file: frame_1688.jpg with index:1688
# Processing file: frame_1689.jpg with index:1689
# Processing file: frame_169.jpg with index:169
# Processing file: frame_1690.jpg with index:1690
# Processing file: frame_1691.jpg with index:1691
# Processing file: frame_1692.jpg with index:1692
# Processing file: frame_1693.jpg with index:1693
# Processing file: frame_1694.jpg with index:1694
# Processing file: frame_1695.jpg with index:1695
# Processing file: frame_1696.jpg with index:1696
# Processing file: frame_1697.jpg with index:1697
# Processing file: frame_1698.jpg with index:1698
# Processing file: frame_1699.jpg with index:1699
# Processing file: frame_17.jpg with index:17
# Processing file: frame_170.jpg with index:170
# Processing file: frame_1700.jpg with index:1700
# Processing file: frame_1701.jpg with index:1701
# Processing file: frame_1702.jpg with index:1702
# Processing file: frame_1703.jpg with index:1703
# Processing file: frame_1704.jpg with index:1704
# Processing file: frame_1705.jpg with index:1705
# Processing file: frame_1706.jpg with index:1706
# Processing file: frame_1707.jpg with index:1707
# Processing file: frame_1708.jpg with index:1708
# Processing file: frame_1709.jpg with index:1709
# Processing file: frame_171.jpg with index:171
# Processing file: frame_1710.jpg with index:1710
# Processing file: frame_1711.jpg with index:1711
# Processing file: frame_1712.jpg with index:1712
# Processing file: frame_1713.jpg with index:1713
# Processing file: frame_1714.jpg with index:1714
# Processing file: frame_1715.jpg with index:1715
# Processing file: frame_1716.jpg with index:1716
# Processing file: frame_1717.jpg with index:1717
# Processing file: frame_1718.jpg with index:1718
# Processing file: frame_1719.jpg with index:1719
# Processing file: frame_172.jpg with index:172
# Processing file: frame_1720.jpg with index:1720
# Processing file: frame_1721.jpg with index:1721
# Processing file: frame_1722.jpg with index:1722
# Processing file: frame_1723.jpg with index:1723
# Processing file: frame_1724.jpg with index:1724
# Processing file: frame_1725.jpg with index:1725
# Processing file: frame_1726.jpg with index:1726
# Processing file: frame_1727.jpg with index:1727
# Processing file: frame_1728.jpg with index:1728
# Processing file: frame_1729.jpg with index:1729
# Processing file: frame_173.jpg with index:173
# Processing file: frame_1730.jpg with index:1730
# Processing file: frame_1731.jpg with index:1731
# Processing file: frame_1732.jpg with index:1732
# Processing file: frame_1733.jpg with index:1733
# Processing file: frame_1734.jpg with index:1734
# Processing file: frame_1735.jpg with index:1735
# Processing file: frame_1736.jpg with index:1736
# Processing file: frame_1737.jpg with index:1737
# Processing file: frame_1738.jpg with index:1738
# Processing file: frame_1739.jpg with index:1739
# Processing file: frame_174.jpg with index:174
# Processing file: frame_1740.jpg with index:1740
# Processing file: frame_1741.jpg with index:1741
# Processing file: frame_1742.jpg with index:1742
# Processing file: frame_1743.jpg with index:1743
# Processing file: frame_1744.jpg with index:1744
# Processing file: frame_1745.jpg with index:1745
# Processing file: frame_1746.jpg with index:1746
# Processing file: frame_1747.jpg with index:1747
# Processing file: frame_1748.jpg with index:1748
# Processing file: frame_1749.jpg with index:1749
# Processing file: frame_175.jpg with index:175
# Processing file: frame_1750.jpg with index:1750
# Processing file: frame_1751.jpg with index:1751
# Processing file: frame_1752.jpg with index:1752
# Processing file: frame_1753.jpg with index:1753
# Processing file: frame_1754.jpg with index:1754
# Processing file: frame_1755.jpg with index:1755
# Processing file: frame_1756.jpg with index:1756
# Processing file: frame_1757.jpg with index:1757
# Processing file: frame_1758.jpg with index:1758
# Processing file: frame_1759.jpg with index:1759
# Processing file: frame_176.jpg with index:176
# Processing file: frame_1760.jpg with index:1760
# Processing file: frame_1761.jpg with index:1761
# Processing file: frame_1762.jpg with index:1762
# Processing file: frame_1763.jpg with index:1763
# Processing file: frame_1764.jpg with index:1764
# Processing file: frame_1765.jpg with index:1765
# Processing file: frame_1766.jpg with index:1766
# Processing file: frame_1767.jpg with index:1767
# Processing file: frame_1768.jpg with index:1768
# Processing file: frame_1769.jpg with index:1769
# Processing file: frame_177.jpg with index:177
# Processing file: frame_1770.jpg with index:1770
# Processing file: frame_1771.jpg with index:1771
# Processing file: frame_1772.jpg with index:1772
# Processing file: frame_1773.jpg with index:1773
# Processing file: frame_1774.jpg with index:1774
# Processing file: frame_1775.jpg with index:1775
# Processing file: frame_1776.jpg with index:1776
# Processing file: frame_1777.jpg with index:1777
# Processing file: frame_1778.jpg with index:1778
# Processing file: frame_1779.jpg with index:1779
# Processing file: frame_178.jpg with index:178
# Processing file: frame_1780.jpg with index:1780
# Processing file: frame_1781.jpg with index:1781
# Processing file: frame_1782.jpg with index:1782
# Processing file: frame_1783.jpg with index:1783
# Processing file: frame_1784.jpg with index:1784
# Processing file: frame_1785.jpg with index:1785
# Processing file: frame_1786.jpg with index:1786
# Processing file: frame_1787.jpg with index:1787
# Processing file: frame_1788.jpg with index:1788
# Processing file: frame_1789.jpg with index:1789
# Processing file: frame_179.jpg with index:179
# Processing file: frame_1790.jpg with index:1790
# Processing file: frame_1791.jpg with index:1791
# Processing file: frame_1792.jpg with index:1792
# Processing file: frame_1793.jpg with index:1793
# Processing file: frame_1794.jpg with index:1794
# Processing file: frame_1795.jpg with index:1795
# Processing file: frame_1796.jpg with index:1796
# Processing file: frame_1797.jpg with index:1797
# Processing file: frame_1798.jpg with index:1798
# Processing file: frame_1799.jpg with index:1799
# Processing file: frame_18.jpg with index:18
# Processing file: frame_180.jpg with index:180
# Processing file: frame_1800.jpg with index:1800
# Processing file: frame_1801.jpg with index:1801
# Processing file: frame_1802.jpg with index:1802
# Processing file: frame_1803.jpg with index:1803
# Processing file: frame_1804.jpg with index:1804
# Processing file: frame_1805.jpg with index:1805
# Processing file: frame_1806.jpg with index:1806
# Processing file: frame_1807.jpg with index:1807
# Processing file: frame_1808.jpg with index:1808
# Processing file: frame_1809.jpg with index:1809
# Processing file: frame_181.jpg with index:181
# Processing file: frame_1810.jpg with index:1810
# Processing file: frame_1811.jpg with index:1811
# Processing file: frame_1812.jpg with index:1812
# Processing file: frame_1813.jpg with index:1813
# Processing file: frame_1814.jpg with index:1814
# Processing file: frame_1815.jpg with index:1815
# Processing file: frame_1816.jpg with index:1816
# Processing file: frame_1817.jpg with index:1817
# Processing file: frame_1818.jpg with index:1818
# Processing file: frame_1819.jpg with index:1819
# Processing file: frame_182.jpg with index:182
# Processing file: frame_1820.jpg with index:1820
# Processing file: frame_1821.jpg with index:1821
# Processing file: frame_1822.jpg with index:1822
# Processing file: frame_1823.jpg with index:1823
# Processing file: frame_1824.jpg with index:1824
# Processing file: frame_1825.jpg with index:1825
# Processing file: frame_1826.jpg with index:1826
# Processing file: frame_1827.jpg with index:1827
# Processing file: frame_1828.jpg with index:1828
# Processing file: frame_1829.jpg with index:1829
# Processing file: frame_183.jpg with index:183
# Processing file: frame_1830.jpg with index:1830
# Processing file: frame_1831.jpg with index:1831
# Processing file: frame_1832.jpg with index:1832
# Processing file: frame_1833.jpg with index:1833
# Processing file: frame_1834.jpg with index:1834
# Processing file: frame_1835.jpg with index:1835
# Processing file: frame_1836.jpg with index:1836
# Processing file: frame_1837.jpg with index:1837
# Processing file: frame_1838.jpg with index:1838
# Processing file: frame_1839.jpg with index:1839
# Processing file: frame_184.jpg with index:184
# Processing file: frame_1840.jpg with index:1840
# Processing file: frame_1841.jpg with index:1841
# Processing file: frame_1842.jpg with index:1842
# Processing file: frame_1843.jpg with index:1843
# Processing file: frame_1844.jpg with index:1844
# Processing file: frame_1845.jpg with index:1845
# Processing file: frame_1846.jpg with index:1846
# Processing file: frame_1847.jpg with index:1847
# Processing file: frame_1848.jpg with index:1848
# Processing file: frame_1849.jpg with index:1849
# Processing file: frame_185.jpg with index:185
# Processing file: frame_1850.jpg with index:1850
# Processing file: frame_1851.jpg with index:1851
# Processing file: frame_1852.jpg with index:1852
# Processing file: frame_1853.jpg with index:1853
# Processing file: frame_1854.jpg with index:1854
# Processing file: frame_1855.jpg with index:1855
# Processing file: frame_1856.jpg with index:1856
# Processing file: frame_1857.jpg with index:1857
# Processing file: frame_1858.jpg with index:1858
# Processing file: frame_1859.jpg with index:1859
# Processing file: frame_186.jpg with index:186
# Processing file: frame_1860.jpg with index:1860
# Processing file: frame_1861.jpg with index:1861
# Processing file: frame_1862.jpg with index:1862
# Processing file: frame_1863.jpg with index:1863
# Processing file: frame_1864.jpg with index:1864
# Processing file: frame_1865.jpg with index:1865
# Processing file: frame_1866.jpg with index:1866
# Processing file: frame_1867.jpg with index:1867
# Processing file: frame_1868.jpg with index:1868
# Processing file: frame_1869.jpg with index:1869
# Processing file: frame_187.jpg with index:187
# Processing file: frame_1870.jpg with index:1870
# Processing file: frame_1871.jpg with index:1871
# Processing file: frame_1872.jpg with index:1872
# Processing file: frame_1873.jpg with index:1873
# Processing file: frame_1874.jpg with index:1874
# Processing file: frame_1875.jpg with index:1875
# Processing file: frame_1876.jpg with index:1876
# Processing file: frame_1877.jpg with index:1877
# Processing file: frame_1878.jpg with index:1878
# Processing file: frame_1879.jpg with index:1879
# Processing file: frame_188.jpg with index:188
# Processing file: frame_1880.jpg with index:1880
# Processing file: frame_1881.jpg with index:1881
# Processing file: frame_1882.jpg with index:1882
# Processing file: frame_1883.jpg with index:1883
# Processing file: frame_1884.jpg with index:1884
# Processing file: frame_1885.jpg with index:1885
# Processing file: frame_1886.jpg with index:1886
# Processing file: frame_1887.jpg with index:1887
# Processing file: frame_1888.jpg with index:1888
# Processing file: frame_1889.jpg with index:1889
# Processing file: frame_189.jpg with index:189
# Processing file: frame_1890.jpg with index:1890
# Processing file: frame_1891.jpg with index:1891
# Processing file: frame_1892.jpg with index:1892
# Processing file: frame_1893.jpg with index:1893
# Processing file: frame_1894.jpg with index:1894
# Processing file: frame_1895.jpg with index:1895
# Processing file: frame_1896.jpg with index:1896
# Processing file: frame_1897.jpg with index:1897
# Processing file: frame_1898.jpg with index:1898
# Processing file: frame_1899.jpg with index:1899
# Processing file: frame_19.jpg with index:19
# Processing file: frame_190.jpg with index:190
# Processing file: frame_1900.jpg with index:1900
# ...
# Processing file: frame_686.jpg with index:686
# Processing file: frame_687.jpg with index:687
# Processing file: frame_688.jpg with index:688
# Processing file: frame_689.jpg with index:689
# Processing file: frame_69.jpg with index:69
# Processing file: frame_690.jpg with index:690
# Processing file: frame_691.jpg with index:691
# Processing file: frame_692.jpg with index:692
# Processing file: frame_693.jpg with index:693
# Processing file: frame_694.jpg with index:694
# Processing file: frame_695.jpg with index:695
# Processing file: frame_696.jpg with index:696
# Processing file: frame_697.jpg with index:697
# Processing file: frame_698.jpg with index:698
# Processing file: frame_699.jpg with index:699
# Processing file: frame_7.jpg with index:7
# Processing file: frame_70.jpg with index:70
# Processing file: frame_700.jpg with index:700
# Processing file: frame_701.jpg with index:701
# Processing file: frame_702.jpg with index:702
# Processing file: frame_703.jpg with index:703
# Processing file: frame_704.jpg with index:704
# Processing file: frame_705.jpg with index:705
# Processing file: frame_706.jpg with index:706
# Processing file: frame_707.jpg with index:707
# Processing file: frame_708.jpg with index:708
# Processing file: frame_709.jpg with index:709
# Processing file: frame_71.jpg with index:71
# Processing file: frame_710.jpg with index:710
# Processing file: frame_711.jpg with index:711
# Processing file: frame_712.jpg with index:712
# Processing file: frame_713.jpg with index:713
# Processing file: frame_714.jpg with index:714
# Processing file: frame_715.jpg with index:715
# Processing file: frame_716.jpg with index:716
# Processing file: frame_717.jpg with index:717
# Processing file: frame_718.jpg with index:718
# Processing file: frame_719.jpg with index:719
# Processing file: frame_72.jpg with index:72
# Processing file: frame_720.jpg with index:720
# Processing file: frame_721.jpg with index:721
# Processing file: frame_722.jpg with index:722
# Processing file: frame_723.jpg with index:723
# Processing file: frame_724.jpg with index:724
# Processing file: frame_725.jpg with index:725
# Processing file: frame_726.jpg with index:726
# Processing file: frame_727.jpg with index:727
# Processing file: frame_728.jpg with index:728
# Processing file: frame_729.jpg with index:729
# Processing file: frame_73.jpg with index:73
# Processing file: frame_730.jpg with index:730
# Processing file: frame_731.jpg with index:731
# Processing file: frame_732.jpg with index:732
# Processing file: frame_733.jpg with index:733
# Processing file: frame_734.jpg with index:734
# Processing file: frame_735.jpg with index:735
# Processing file: frame_736.jpg with index:736
# Processing file: frame_737.jpg with index:737
# Processing file: frame_738.jpg with index:738
# Processing file: frame_739.jpg with index:739
# Processing file: frame_74.jpg with index:74
# Processing file: frame_740.jpg with index:740
# Processing file: frame_741.jpg with index:741
# Processing file: frame_742.jpg with index:742
# Processing file: frame_743.jpg with index:743
# Processing file: frame_744.jpg with index:744
# Processing file: frame_745.jpg with index:745
# Processing file: frame_746.jpg with index:746
# Processing file: frame_747.jpg with index:747
# Processing file: frame_748.jpg with index:748
# Processing file: frame_749.jpg with index:749
# Processing file: frame_75.jpg with index:75
# Processing file: frame_750.jpg with index:750
# Processing file: frame_751.jpg with index:751
# Processing file: frame_752.jpg with index:752
# Processing file: frame_753.jpg with index:753
# Processing file: frame_754.jpg with index:754
# Processing file: frame_755.jpg with index:755
# Processing file: frame_756.jpg with index:756
# Processing file: frame_757.jpg with index:757
# Processing file: frame_758.jpg with index:758
# Processing file: frame_759.jpg with index:759
# Processing file: frame_76.jpg with index:76
# Processing file: frame_760.jpg with index:760
# Processing file: frame_761.jpg with index:761
# Processing file: frame_762.jpg with index:762
# Processing file: frame_763.jpg with index:763
# Processing file: frame_764.jpg with index:764
# Processing file: frame_765.jpg with index:765
# Processing file: frame_766.jpg with index:766
# Processing file: frame_767.jpg with index:767
# Processing file: frame_768.jpg with index:768
# Processing file: frame_769.jpg with index:769
# Processing file: frame_77.jpg with index:77
# Processing file: frame_770.jpg with index:770
# Processing file: frame_771.jpg with index:771
# Processing file: frame_772.jpg with index:772
# Processing file: frame_773.jpg with index:773
# Processing file: frame_774.jpg with index:774
# Processing file: frame_775.jpg with index:775
# Processing file: frame_776.jpg with index:776
# Processing file: frame_777.jpg with index:777
# Processing file: frame_778.jpg with index:778
# Processing file: frame_779.jpg with index:779
# Processing file: frame_78.jpg with index:78
# Processing file: frame_780.jpg with index:780
# Processing file: frame_781.jpg with index:781
# Processing file: frame_782.jpg with index:782
# Processing file: frame_783.jpg with index:783
# Processing file: frame_784.jpg with index:784
# Processing file: frame_785.jpg with index:785
# Processing file: frame_786.jpg with index:786
# Processing file: frame_787.jpg with index:787
# Processing file: frame_788.jpg with index:788
# Processing file: frame_789.jpg with index:789
# Processing file: frame_79.jpg with index:79
# Processing file: frame_790.jpg with index:790
# Processing file: frame_791.jpg with index:791
# Processing file: frame_792.jpg with index:792
# Processing file: frame_793.jpg with index:793
# Processing file: frame_794.jpg with index:794
# Processing file: frame_795.jpg with index:795
# Processing file: frame_796.jpg with index:796
# Processing file: frame_797.jpg with index:797
# Processing file: frame_798.jpg with index:798
# Processing file: frame_799.jpg with index:799
# Processing file: frame_8.jpg with index:8
# Processing file: frame_80.jpg with index:80
# Processing file: frame_800.jpg with index:800
# Processing file: frame_801.jpg with index:801
# Processing file: frame_802.jpg with index:802
# Processing file: frame_803.jpg with index:803
# Processing file: frame_804.jpg with index:804
# Processing file: frame_805.jpg with index:805
# Processing file: frame_806.jpg with index:806
# Processing file: frame_807.jpg with index:807
# Processing file: frame_808.jpg with index:808
# Processing file: frame_809.jpg with index:809
# Processing file: frame_81.jpg with index:81
# Processing file: frame_810.jpg with index:810
# Processing file: frame_811.jpg with index:811
# Processing file: frame_812.jpg with index:812
# Processing file: frame_813.jpg with index:813
# Processing file: frame_814.jpg with index:814
# Processing file: frame_815.jpg with index:815
# Processing file: frame_816.jpg with index:816
# Processing file: frame_817.jpg with index:817
# Processing file: frame_818.jpg with index:818
# Processing file: frame_819.jpg with index:819
# Processing file: frame_82.jpg with index:82
# Processing file: frame_820.jpg with index:820
# Processing file: frame_821.jpg with index:821
# Processing file: frame_822.jpg with index:822
# Processing file: frame_823.jpg with index:823
# Processing file: frame_824.jpg with index:824
# Processing file: frame_825.jpg with index:825
# Processing file: frame_826.jpg with index:826
# Processing file: frame_827.jpg with index:827
# Processing file: frame_828.jpg with index:828
# Processing file: frame_829.jpg with index:829
# Processing file: frame_83.jpg with index:83
# Processing file: frame_830.jpg with index:830
# Processing file: frame_831.jpg with index:831
# Processing file: frame_832.jpg with index:832
# Processing file: frame_833.jpg with index:833
# Processing file: frame_834.jpg with index:834
# Processing file: frame_835.jpg with index:835
# Processing file: frame_836.jpg with index:836
# Processing file: frame_837.jpg with index:837
# Processing file: frame_838.jpg with index:838
# Processing file: frame_839.jpg with index:839
# Processing file: frame_84.jpg with index:84
# Processing file: frame_840.jpg with index:840
# Processing file: frame_841.jpg with index:841
# Processing file: frame_842.jpg with index:842
# Processing file: frame_843.jpg with index:843
# Processing file: frame_844.jpg with index:844
# Processing file: frame_845.jpg with index:845
# Processing file: frame_846.jpg with index:846
# Processing file: frame_847.jpg with index:847
# Processing file: frame_848.jpg with index:848
# Processing file: frame_849.jpg with index:849
# Processing file: frame_85.jpg with index:85
# Processing file: frame_850.jpg with index:850
# Processing file: frame_851.jpg with index:851
# Processing file: frame_852.jpg with index:852
# Processing file: frame_853.jpg with index:853
# Processing file: frame_854.jpg with index:854
# Processing file: frame_855.jpg with index:855
# Processing file: frame_856.jpg with index:856
# Processing file: frame_857.jpg with index:857
# Processing file: frame_858.jpg with index:858
# Processing file: frame_859.jpg with index:859
# Processing file: frame_86.jpg with index:86
# Processing file: frame_860.jpg with index:860
# Processing file: frame_861.jpg with index:861
# Processing file: frame_862.jpg with index:862
# Processing file: frame_863.jpg with index:863
# Processing file: frame_864.jpg with index:864
# Processing file: frame_865.jpg with index:865
# Processing file: frame_866.jpg with index:866
# Processing file: frame_867.jpg with index:867
# Processing file: frame_868.jpg with index:868
# Processing file: frame_869.jpg with index:869
# Processing file: frame_87.jpg with index:87
# Processing file: frame_870.jpg with index:870
# Processing file: frame_871.jpg with index:871
# Processing file: frame_872.jpg with index:872
# Processing file: frame_873.jpg with index:873
# Processing file: frame_874.jpg with index:874
# Processing file: frame_875.jpg with index:875
# Processing file: frame_876.jpg with index:876
# Processing file: frame_877.jpg with index:877
# Processing file: frame_878.jpg with index:878
# Processing file: frame_879.jpg with index:879
# Processing file: frame_88.jpg with index:88
# Processing file: frame_880.jpg with index:880
# Processing file: frame_881.jpg with index:881
# Processing file: frame_882.jpg with index:882
# Processing file: frame_883.jpg with index:883
# Processing file: frame_884.jpg with index:884
# Processing file: frame_885.jpg with index:885
# Processing file: frame_886.jpg with index:886
# Processing file: frame_887.jpg with index:887
# Processing file: frame_888.jpg with index:888
# Processing file: frame_889.jpg with index:889
# Processing file: frame_89.jpg with index:89
# Processing file: frame_890.jpg with index:890
# Processing file: frame_891.jpg with index:891
# Processing file: frame_892.jpg with index:892
# Processing file: frame_893.jpg with index:893
# Processing file: frame_894.jpg with index:894
# Processing file: frame_895.jpg with index:895
# Processing file: frame_896.jpg with index:896
# Processing file: frame_897.jpg with index:897
# Processing file: frame_898.jpg with index:898
# Processing file: frame_899.jpg with index:899
# Processing file: frame_9.jpg with index:9
# Processing file: frame_90.jpg with index:90
# Processing file: frame_900.jpg with index:900
# Processing file: frame_901.jpg with index:901
# Processing file: frame_902.jpg with index:902
# Processing file: frame_903.jpg with index:903
# Processing file: frame_904.jpg with index:904
# Processing file: frame_905.jpg with index:905
# Processing file: frame_906.jpg with index:906
# Processing file: frame_907.jpg with index:907
# Processing file: frame_908.jpg with index:908
# Processing file: frame_909.jpg with index:909
# Processing file: frame_91.jpg with index:91
# Processing file: frame_910.jpg with index:910
# Processing file: frame_911.jpg with index:911
# Processing file: frame_912.jpg with index:912
# Processing file: frame_913.jpg with index:913
# Processing file: frame_914.jpg with index:914
# Processing file: frame_915.jpg with index:915
# Processing file: frame_916.jpg with index:916
# Processing file: frame_917.jpg with index:917
# Processing file: frame_918.jpg with index:918
# Processing file: frame_919.jpg with index:919
# Processing file: frame_92.jpg with index:92
# Processing file: frame_920.jpg with index:920
# Processing file: frame_921.jpg with index:921
# Processing file: frame_922.jpg with index:922
# Processing file: frame_923.jpg with index:923
# Processing file: frame_924.jpg with index:924
# Processing file: frame_925.jpg with index:925
# Processing file: frame_926.jpg with index:926
# Processing file: frame_927.jpg with index:927
# Processing file: frame_928.jpg with index:928
# Processing file: frame_929.jpg with index:929
# Processing file: frame_93.jpg with index:93
# Processing file: frame_930.jpg with index:930
# Processing file: frame_931.jpg with index:931
# Processing file: frame_932.jpg with index:932
# Processing file: frame_933.jpg with index:933
# Processing file: frame_934.jpg with index:934
# Processing file: frame_935.jpg with index:935
# Processing file: frame_936.jpg with index:936
# Processing file: frame_937.jpg with index:937
# Processing file: frame_938.jpg with index:938
# Processing file: frame_939.jpg with index:939
# Processing file: frame_94.jpg with index:94
# Processing file: frame_940.jpg with index:940
# Processing file: frame_941.jpg with index:941
# Processing file: frame_942.jpg with index:942
# Processing file: frame_943.jpg with index:943
# Processing file: frame_944.jpg with index:944
# Processing file: frame_945.jpg with index:945
# Processing file: frame_946.jpg with index:946
# Processing file: frame_947.jpg with index:947
# Processing file: frame_948.jpg with index:948
# Processing file: frame_949.jpg with index:949
# Processing file: frame_95.jpg with index:95
# Processing file: frame_950.jpg with index:950
# Processing file: frame_951.jpg with index:951
# Processing file: frame_952.jpg with index:952
# Processing file: frame_953.jpg with index:953
# Processing file: frame_954.jpg with index:954
# Processing file: frame_955.jpg with index:955
# Processing file: frame_956.jpg with index:956
# Processing file: frame_957.jpg with index:957
# Processing file: frame_958.jpg with index:958
# Processing file: frame_959.jpg with index:959
# Processing file: frame_96.jpg with index:96
# Processing file: frame_960.jpg with index:960
# Processing file: frame_961.jpg with index:961
# Processing file: frame_962.jpg with index:962
# Processing file: frame_963.jpg with index:963
# Processing file: frame_964.jpg with index:964
# Processing file: frame_965.jpg with index:965
# Processing file: frame_966.jpg with index:966
# Processing file: frame_967.jpg with index:967
# Processing file: frame_968.jpg with index:968
# Processing file: frame_969.jpg with index:969
# Processing file: frame_97.jpg with index:97
# Processing file: frame_970.jpg with index:970
# Processing file: frame_971.jpg with index:971
# Processing file: frame_972.jpg with index:972
# Processing file: frame_973.jpg with index:973
# Processing file: frame_974.jpg with index:974
# Processing file: frame_975.jpg with index:975
# Processing file: frame_976.jpg with index:976
# Processing file: frame_977.jpg with index:977
# Processing file: frame_978.jpg with index:978
# Processing file: frame_979.jpg with index:979
# Processing file: frame_98.jpg with index:98
# Processing file: frame_980.jpg with index:980
# Processing file: frame_981.jpg with index:981
# Processing file: frame_982.jpg with index:982
# Processing file: frame_983.jpg with index:983
# Processing file: frame_984.jpg with index:984
# Processing file: frame_985.jpg with index:985
# Processing file: frame_986.jpg with index:986
# Processing file: frame_987.jpg with index:987
# Processing file: frame_988.jpg with index:988
# Processing file: frame_989.jpg with index:989
# Processing file: frame_99.jpg with index:99
# Processing file: frame_990.jpg with index:990
# Processing file: frame_991.jpg with index:991
# Processing file: frame_992.jpg with index:992
# Processing file: frame_993.jpg with index:993
# Processing file: frame_994.jpg with index:994
# Processing file: frame_995.jpg with index:995
# Processing file: frame_996.jpg with index:996
# Processing file: frame_997.jpg with index:997
# Processing file: frame_998.jpg with index:998
# Processing file: frame_999.jpg with index:999
# Results saved in: /kaggle/working/bounding_boxes_6_model.json

# %% [markdown]
# # POST PROCESS

# %%
PATH_OUT = "/kaggle/working"
PATH_XML_5 = "/kaggle/input/computer-vision-futbal/dataset_soccer/dataset_soccer/test/ID-5.xml"
PATH_XML_6 = "/kaggle/input/computer-vision-futbal/dataset_soccer/dataset_soccer/test/ID-6.xml"
#PATH_5 = "/kaggle/input/faster-json-w-bounding-boxes/bounding_boxes_5.json"
#PATH_6 = "/kaggle/input/faster-json-w-bounding-boxes/bounding_boxes_6.json"
PATH_5 = '/kaggle/working/bounding_boxes_5_model.json'
PATH_6 = '/kaggle/working/bounding_boxes_6_model.json'

# %% [markdown]
# ## METODI AUSILIARI

# %%
import os
import re
import json
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

plt.rcParams["figure.figsize"] = (10, 8)

# %%
class TrackingEvaluator:
    def __init__(self, gt_ann_file, pred_file):
        self.gt_ann_file = gt_ann_file
        self.pred_file = pred_file
        self.gt_data_points = {}
        self.pred_points = {}
        self.frames_idx = None

    @staticmethod
    def extract_points_data(xml_content):
        root = ET.fromstring(xml_content)
        points_data = {}
        
        for track in root.findall(".//track"):
            for point in track.findall("points"):
                data = {
                    'frame': int(point.get("frame")),
                    'outside': int(point.get("outside")),
                    'occluded': int(point.get("occluded")),
                    'keyframe': int(point.get("keyframe")),
                    'points': tuple(map(float, point.get("points").split(","))),
                    'z_order': int(point.get("z_order")),
                }
                if data['frame'] in points_data:
                    print(f'Alert: multiple frame entries for ID {data["frame"]}')
                points_data[data['frame']] = data
        
        return points_data

    @staticmethod
    def _convert_key(k):
        return int(Path(k).stem)

    def load_data(self):
        # Load ground truth data
        gt_content = Path(self.gt_ann_file).read_text()
        self.gt_data_points = self.extract_points_data(gt_content)

        # Load prediction data
        pred_content = Path(self.pred_file).read_text().replace('-Infinity', '-1').replace('Infinity', '-1')
        raw_pred_points = json.loads(pred_content)
        self.pred_points = {
            self._convert_key(k): v for k, v in raw_pred_points.items() if v['x'] >= 0
        }

    def compute_frame_indices(self):
        ordered_list_pred_frame = sorted(self.pred_points.keys())
        ordered_list_gt_frame = sorted(self.gt_data_points.keys())
        
        print(f'GT   frames: {ordered_list_gt_frame[0]} - {ordered_list_gt_frame[-1]}')
        print(f'PRED frames: {ordered_list_pred_frame[0]} - {ordered_list_pred_frame[-1]}')

        self.frames_idx = (
            min(ordered_list_gt_frame[0], ordered_list_pred_frame[0]),
            max(ordered_list_gt_frame[-1], ordered_list_pred_frame[-1]),
        )
        print(f'Frame Index Range: {self.frames_idx}')

    @staticmethod
    def is_match(x1, y1, x2, y2, threshold=4):
        p1 = np.array((x1, y1))
        p2 = np.array((x2, y2))
        euclid_dist = np.sqrt(np.dot((p1 - p2).T, (p1 - p2)))
        return euclid_dist < threshold

    def evaluate_metrics(self):
        cnt_match = 0
        cnt_no_match = 0
        cnt_no_pred = 0
        cnt_no_frame = 0

        for i in range(self.frames_idx[0], self.frames_idx[1] + 1):
            if i not in self.gt_data_points:
                cnt_no_frame += 1
                continue
            if i not in self.pred_points:
                cnt_no_pred += 1
                continue

            p1 = self.gt_data_points[i]
            p2 = self.pred_points[i]

            if self.is_match(*p1['points'], p2['x'], p2['y']):
                cnt_match += 1
            else:
                cnt_no_match += 1

        total_frames = len(self.gt_data_points)
        print(f'Total frames: {total_frames}')
        print(f'Total predictions: {len(self.pred_points)}')
        print(f'Matches: {cnt_match} ({cnt_match / total_frames:.3f})')
        print(f'No matches: {cnt_no_match} ({cnt_no_match / total_frames:.3f})')
        print(f'No predictions: {cnt_no_pred} ({cnt_no_pred / total_frames:.3f})')
        print(f'No frame data: {cnt_no_frame} ({cnt_no_frame / (self.frames_idx[1] - self.frames_idx[0] + 1):.3f})')

    def compute_tracking_sequence(self):
        norm_width = 1920
        norm_height = 1080

        gt_seq = []
        pred_seq = []

        for i in range(min(self.gt_data_points.keys()), max(self.gt_data_points.keys()) + 1):
            if i in self.gt_data_points:
                if i not in self.pred_points:
                    pred_seq.append((0, 0))
                else:
                    p2 = self.pred_points[i]
                    pred_seq.append((p2['x'] / norm_width, p2['y'] / norm_height))

                x, y = self.gt_data_points[i]['points']
                gt_seq.append((x / norm_width, y / norm_height))

        return gt_seq, pred_seq

    def compute_mse(self):
        gt_seq, pred_seq = self.compute_tracking_sequence()
        mse = mean_squared_error(gt_seq, pred_seq)
        print(f'Mean Squared Error: {mse}')
        return mse

# %%
def open_json(path):
    """
        Il metodo si occupa di caricare un file JSON.
    
        :Params:
            :path = Il percorso del file JSON da aprire.
    
        :Returns:
            :data_result = E' il dizionario con gli elementi ordinati in base alla 
                parte numerica della chiave. Deve essere ordinato poichè il JSON possiede le chiavi
                nel seguente modo: "00000.jpg", seguento l'ordinamento lessicale si ottiene che la 
                chiave "000010.jpg" viene prima di "00002.jpg" e questo rompe l'ordinamento del video.
    """
    with open(path, 'r') as file:
        data = json.load(file)
    
    ordinato = dict(sorted(data.items(), key=lambda x: int(x[0].split('.')[0])))
    
    return ordinato

def save_json(path, data):
    """
        Il metodo si occupa di salvare il file JSON in una specifica posizione.

        :Params:
            :path = Indica il percorso in cui salvare il file JSON;
            :data = Rappresenta il file da salvare.
    """
    
    with open(path, 'w') as f:
        json.dump(data, f, indent=4)
        
    print(f"JSON saved in: {path}")

# %% [markdown]
# # CALCOLO MSE

# %% [markdown]
# ## ALTRI METODI AUSILIARI

# %%
import json

def filter_and_transform_bboxes(data, score_threshold=0.1):
    """    
        Questa funzione filtra e trasforma le bounding boxes per ogni frame, presenti
        nel file fornito in input, selezionando solo quelle con un punteggio maggiore 
        o uguale alla soglia specificata. 
        Per ogni frame, dopo aver selezionato le bounding box con score maggiore
        del valore di soglia, viene selezionata la bounding box con il punteggio 
        massimo e trasformata nel formato richiesto, contenente le coordinate della 
        bounding box (xmin, ymin, xmax, ymax) e il relativo score di predizione.

        :Params:
            :data = Il file JSON delle predizioni che ha come chiave "00000.jgp" e una 
                lista di bounding boxes come valore. 
                Ogni bounding box è un dizionario che contiene le coordinate e lo score di 
                predizione.
            :score_threshold = Rappresenta la soglia del punteggio minimo per considerare 
            una bounding box.

        :Return:
            :result = Un file JSON dove per ogni frame vengono contenute le informazioni filtrate.
    """
    result = {}
    
    for file_name in sorted(data.keys()):
        bboxes = data[file_name]
        
        if bboxes:

            filtered_bboxes = [bbox for bbox in bboxes if bbox['score'] >= score_threshold]
            
            if filtered_bboxes:
                
                #La migliore bb è quella che possiede lo score maggiore.
                best_bbox = max(filtered_bboxes, key=lambda x: x['score'])
                
                result[file_name] = {
                    'xmin': best_bbox['bbox'][0],
                    'ymin': best_bbox['bbox'][1],
                    'xmax': best_bbox['bbox'][2],
                    'ymax': best_bbox['bbox'][3],
                    'score': best_bbox['score']
                }
            else:
                result[file_name] = {}
        else:
            result[file_name] = {}
    
    return result

# %%
def rimuovi_falsi_positivi(data):
    """    
        Questa funzione analizza i frame contenuti nel file JSON delle predizioni, 
        e rimuove i frame che vengono considerati falsi positivi.
        Un frame viene considerato un falso positivo se soddisfa due condizioni:
            - Se il punteggio di predizione è basso (minore di una certa soglia).
            - Se l'immagine ha molti frame vuoti sia precedenti che successivi, 
                 suggerendo che il rilevamento potrebbe essere errato o irrilevante.
        
        Per determinare se un frame è un falso positivo, la funzione verifica i frame 
        precedenti e successivi per determinare se sono vuoti. 
        Se ci sono almeno 5 frame vuoti prima e dopo e il punteggio è basso, 
        l'immagine viene contrassegnata come un falso positivo e il suo contenuto 
        viene rimosso (impostato a un dizionario vuoto).
        
        :Params:
            :data = Un file JSON contenente le predizioni, con il nome del frame come chiave 
                    e un dizionario che rappresenta le coordinate della bounding box e 
                    il punteggio di predizione come valore.
        :Return:
            :data = Il file JSON delle predizioni aggiornato, dove le immagini considerate 
                    falsi positivi sono state rimosse.
    """
    
    images = list(data.keys())

    for i, image in enumerate(images):

        if data[image]:
            score = data[image].get('score', 0)

            prev_empty_count = 0
            next_empty_count = 0

            # Prendiamoci quanti frame precedenti e successivi sono vuoti
            for j in range(i-1, -1, -1):
                if not data[images[j]]:
                    prev_empty_count += 1
                else:
                    break 

            for j in range(i + 1, len(images)):
                if not data[images[j]]: 
                    next_empty_count += 1
                else:
                    break 

           #Condizione per considerarlo falso positivo:
                #almeno 5 frame prima e dopo nulli e score < 0.99
                #score < 0.7
            if (prev_empty_count >=5  and next_empty_count >= 5 and score < 0.99) or score < 0.70:
                print(f"Suspicious frame: {image}, with {prev_empty_count} empty frames before and {next_empty_count} empty frames after, info: {data[image]}")
                data[image] = {}
    return data

# %%
import json

def process_bounding_boxes(input_data):
    """    
        Questa funzione elabora le informazioni delle bounding boxes per ogni frame nel 
        file JSON di input, calcolando il centro di ogni bounding box e restituendo un 
        nuovo file JSON con le coordinate (x, y) dei centri, come richiesto.
            
        :Params:
            :input_data = Un file JSON contenente le informazioni delle bounding boxes, 
                        dove il nome del frame è la chiave e il valore è un dizionario 
                        con le coordinate xmin, ymin, xmax, ymax della bounding box.
        
        :Return:
            :output_data = Un file JSON contenente per ogni frame il centro della 
                           bounding box sotto forma di coordinate (x, y). Se non 
                           ci sono dati per un frame, viene restituito (-1, -1) come coordinate.
    """
    output_data = {}

    for filename, bbox_info in input_data.items():
        if bbox_info:
            
            xmin = bbox_info.get('xmin')
            ymin = bbox_info.get('ymin')
            xmax = bbox_info.get('xmax')
            ymax = bbox_info.get('ymax')

            center_x = (xmin + xmax) / 2
            center_y = (ymin + ymax) / 2
            
            output_data[filename] = {'x': center_x, 'y': center_y}
        else:
            output_data[filename] = {'x': -1, 'y': -1}
    
    return output_data

# %% [markdown]
# ## CALCOLO MSE SENZA POST PROCESSING

# %%
save_json(f"{PATH_OUT}/json_5_nots.json",process_bounding_boxes(filter_and_transform_bboxes(open_json(PATH_5),score_threshold=0)))
# Out:
# JSON saved in: /kaggle/working/json_5_nots.json

# %%
save_json(f"{PATH_OUT}/json_6_nots.json",process_bounding_boxes(filter_and_transform_bboxes(open_json(PATH_6),score_threshold=0)))
# Out:
# JSON saved in: /kaggle/working/json_6_nots.json

# %%
gt_ann_file = Path.home() / PATH_XML_5
pred_file = Path.home() / f'{PATH_OUT}/json_5_nots.json'

evaluator = TrackingEvaluator(gt_ann_file, pred_file)
evaluator.load_data()
evaluator.compute_frame_indices()
evaluator.evaluate_metrics()
mse5 = evaluator.compute_mse();
# Out:
# GT   frames: 420 - 2580
# PRED frames: 32 - 2966
# Frame Index Range: (32, 2966)
# Total frames: 346
# Total predictions: 534
# Matches: 265 (0.766)
# No matches: 27 (0.078)
# No predictions: 54 (0.156)
# No frame data: 2589 (0.882)
# Mean Squared Error: 0.05456320838758867

# %%
gt_ann_file = Path.home() / PATH_XML_6
pred_file = Path.home() / f'{PATH_OUT}/json_6_nots.json'

evaluator = TrackingEvaluator(gt_ann_file, pred_file)
evaluator.load_data()
evaluator.compute_frame_indices()
evaluator.evaluate_metrics()
mse6 = evaluator.compute_mse();
# Out:
# GT   frames: 417 - 2495
# PRED frames: 0 - 2962
# Frame Index Range: (0, 2962)
# Total frames: 263
# Total predictions: 981
# Matches: 246 (0.935)
# No matches: 9 (0.034)
# No predictions: 8 (0.030)
# No frame data: 2700 (0.911)
# Mean Squared Error: 0.018005002783646654

# %%
print(f'FINAL MSE {np.mean([mse5, mse6])}')
# Out:
# FINAL MSE 0.03628410558561766

# %% [markdown]
# ## CALCOLO MSE CON TRESHOLDING

# %%
save_json(f"{PATH_OUT}/json_5_ts.json",process_bounding_boxes(rimuovi_falsi_positivi(filter_and_transform_bboxes(open_json(PATH_5),score_threshold=0.8))))
# Out:
# Suspicious frame: 00032.jpg, with 32 empty frames before and 18 empty frames after, info: {'xmin': 316.5431213378906, 'ymin': 55.160499572753906, 'xmax': 341.571533203125, 'ymax': 80.30467224121094, 'score': 0.904865562915802}
# Suspicious frame: 00051.jpg, with 51 empty frames before and 6 empty frames after, info: {'xmin': 277.176025390625, 'ymin': 58.080078125, 'xmax': 302.1291809082031, 'ymax': 83.93463897705078, 'score': 0.8420079946517944}
# Suspicious frame: 00058.jpg, with 58 empty frames before and 365 empty frames after, info: {'xmin': 263.1426696777344, 'ymin': 57.018028259277344, 'xmax': 288.32879638671875, 'ymax': 81.7767105102539, 'score': 0.8761492967605591}
# Suspicious frame: 00694.jpg, with 75 empty frames before and 34 empty frames after, info: {'xmin': 1905.5531005859375, 'ymin': 124.76521301269531, 'xmax': 1920.0, 'ymax': 150.0313262939453, 'score': 0.8463476896286011}
# Suspicious frame: 00729.jpg, with 110 empty frames before and 19 empty frames after, info: {'xmin': 1861.1156005859375, 'ymin': 78.15499114990234, 'xmax': 1887.348388671875, 'ymax': 104.8904037475586, 'score': 0.9478008151054382}
# Suspicious frame: 00896.jpg, with 145 empty frames before and 1547 empty frames after, info: {'xmin': 1906.5347900390625, 'ymin': 235.0340118408203, 'xmax': 1920.0, 'ymax': 261.00128173828125, 'score': 0.9795364141464233}
# JSON saved in: /kaggle/working/json_5_ts.json

# %%
save_json(f"{PATH_OUT}/json_6_ts.json",process_bounding_boxes(rimuovi_falsi_positivi(filter_and_transform_bboxes(open_json(PATH_6),score_threshold=0.8))))
# Out:
# Suspicious frame: 00859.jpg, with 218 empty frames before and 641 empty frames after, info: {'xmin': 1901.3675537109375, 'ymin': 977.2528076171875, 'xmax': 1920.0, 'ymax': 1003.6451416015625, 'score': 0.8416836261749268}
# Suspicious frame: 01501.jpg, with 860 empty frames before and 13 empty frames after, info: {'xmin': 1628.141357421875, 'ymin': 12.353048324584961, 'xmax': 1654.0811767578125, 'ymax': 38.62401580810547, 'score': 0.8094037771224976}
# Suspicious frame: 01596.jpg, with 78 empty frames before and 490 empty frames after, info: {'xmin': 1610.1160888671875, 'ymin': 14.827753067016602, 'xmax': 1636.2947998046875, 'ymax': 41.9946403503418, 'score': 0.8214535713195801}
# Suspicious frame: 02087.jpg, with 569 empty frames before and 5 empty frames after, info: {'xmin': 1643.8026123046875, 'ymin': 64.59578704833984, 'xmax': 1669.826171875, 'ymax': 90.81431579589844, 'score': 0.9194740056991577}
# Suspicious frame: 02093.jpg, with 575 empty frames before and 352 empty frames after, info: {'xmin': 1597.972412109375, 'ymin': 95.5059585571289, 'xmax': 1623.1439208984375, 'ymax': 121.66190338134766, 'score': 0.973003089427948}
# Suspicious frame: 02446.jpg, with 928 empty frames before and 8 empty frames after, info: {'xmin': 1850.289794921875, 'ymin': 588.3661499023438, 'xmax': 1876.76953125, 'ymax': 614.4552001953125, 'score': 0.9041323065757751}
# JSON saved in: /kaggle/working/json_6_ts.json

# %%
gt_ann_file = Path.home() / PATH_XML_5
pred_file = Path.home() / f'{PATH_OUT}/json_5_ts.json'

evaluator = TrackingEvaluator(gt_ann_file, pred_file)
evaluator.load_data()
evaluator.compute_frame_indices()
evaluator.evaluate_metrics()
mse5 = evaluator.compute_mse();
# Out:
# GT   frames: 420 - 2580
# PRED frames: 424 - 2966
# Frame Index Range: (420, 2966)
# Total frames: 346
# Total predictions: 281
# Matches: 255 (0.737)
# No matches: 10 (0.029)
# No predictions: 81 (0.234)
# No frame data: 2201 (0.864)
# Mean Squared Error: 0.07505830962815216

# %%
gt_ann_file = Path.home() / PATH_XML_6
pred_file = Path.home() / f'{PATH_OUT}/json_6_ts.json'

evaluator = TrackingEvaluator(gt_ann_file, pred_file)
evaluator.load_data()
evaluator.compute_frame_indices()
evaluator.evaluate_metrics()
mse6 = evaluator.compute_mse();
# Out:
# GT   frames: 417 - 2495
# PRED frames: 418 - 2494
# Frame Index Range: (417, 2495)
# Total frames: 263
# Total predictions: 248
# Matches: 242 (0.920)
# No matches: 3 (0.011)
# No predictions: 18 (0.068)
# No frame data: 1816 (0.873)
# Mean Squared Error: 0.028571952201042798

# %%
print(f'FINAL MSE {np.mean([mse5, mse6])}')
# Out:
# FINAL MSE 0.05181513091459748

# %% [markdown]
# Le considerazioni che possiamo trarre sono le seguenti:
#
#  **VIDEO 5 SENZA TS**
# * Total frames: 346
# * Total predictions: 534
# * MSE = 0.05456320838758867
#
#  **VIDEO 5 CON TS**
# * Total frames: 346
# * Total predictions: 281
# * MSE = 0.07505830962815216
#
#  **VIDEO 6 SENZA TS**
# * Total frames: 346
# * Total predictions: 534
# * MSE = 0.018005002783646654
#
#  **VIDEO 6 CON TS**
# * Total frames: 263
# * Total predictions: 248
# * MSE = 0.028571952201042798
#
# Notiamo che anche impostando un valore di tresholding pari a 0.8 abbattiamo tanti falsi positivi, lo si può notare dalle total prediction.
# Questo risultato è anche ottenuto grazie all'invocazione della semplice funzione di rimozione dei falsi positivi.
# Ma tralasciando il conteggio dei falsi positivi (anche se impatta molto nel risultato visivo finale) il valore dell'MSE tende ad aumentare, questo perchè dimunuiscono i valori di No Matched e aumentano quelli di No Prediction.
#
# **media MSE video 5 e 6 senza TS**
#
# FINAL MSE 0.03628410558561766
#
#
# **media MSE video 5 e 6 con TS**
#
# FINAL MSE 0.05181513091459748
#
# L'ideale sarebbe abbassare il valore dell'MSE dei risultati prodotti con il tresholding in quanto più accurati. Per ridurre il valore dei no prediction usiamo un interpolazione classica, lineare.

# %% [markdown]
# ## INTERPOLAZIONE

# %% [markdown]
# L'interpolazione lineare è un metodo per stimare un valore all'interno di un intervallo, partendo da due punti noti. L'idea è quella di applicarla per colmare un gap di frame mancanti tra due predizioni.

# %%
def interpolare_bounding_box(frame_precedente, frame_successivo, dist_prec, dist_succ):
    """    
        Esegue l'interpolazione lineare delle coordinate della bounding box tra due frame adiacenti 
        in base alla distanza tra il frame corrente e ciascuno dei frame validi. 
        
        :Params:
            :frame_precedente = Il dizionario contenente le informazioni della bounding box 
                                 e lo score del frame precedente;
            :frame_successivo = Il dizionario contenente le informazioni della bounding box
                                 e lo score del frame successivo;
            :dist_prec = La distanza tra il frame corrente e il frame precedente:
            :dist_succ = La distanza tra il frame corrente e il frame successivo.
        
        :Return:
            :return = Un dizionario con le coordinate della bounding box interpolata.
    """
    xmin_interpolato = frame_precedente["xmin"]+ (dist_prec / (dist_prec + dist_succ)) * (frame_successivo["xmin"] - frame_precedente["xmin"])
    ymin_interpolato = frame_precedente["ymin"] + (dist_prec / (dist_prec + dist_succ)) * (frame_successivo["ymin"] -frame_precedente["ymin"])
    xmax_interpolato = frame_precedente["xmax"] +(dist_prec / (dist_prec + dist_succ)) * (frame_successivo["xmax"] -frame_precedente["xmax"])
    ymax_interpolato = frame_precedente["ymax"] + (dist_prec / (dist_prec + dist_succ)) * (frame_successivo["ymax"]- frame_precedente["ymax"])

    return {
        "xmin": xmin_interpolato,
        "ymin": ymin_interpolato,
        "xmax": xmax_interpolato,
        "ymax": ymax_interpolato
    }

def interpolare_score(frame_precedente, frame_successivo, dist_prec, dist_succ):
    """    
        Calcola la media pesata degli score tra il frame precedente e successivo, 
        basata sulle distanze tra il frame corrente e i due frame validi. 
        Lo score risultante da un peso maggiore al frame più vicino al frame corrente.
        
        :Params:
            :frame_precedente = Il dizionario contenente lo score del frame precedente;
            :frame_successivo = Il dizionario contenente lo score del frame successivo;
            :dist_prec = La distanza tra il frame corrente e il frame precedente;
            :dist_succ = La distanza tra il frame corrente e il frame successivo.
        
        :Return:
            :score_interpolato = Lo score interpolato risultante dalla media pesata tra i due score.
    """
    score_prec = frame_precedente["score"]
    score_succ = frame_successivo["score"]
    score_interpolato = (score_prec * dist_succ + score_succ * dist_prec) / (dist_prec + dist_succ)
    return score_interpolato

def interpolare_frames(frames, gap=5):
    """    
        Funzione di richiamo per quelle descritte in precedenza. La funzione cerca i frame vuoti 
        e, se sono entro una distanza massima tra i frame validi precedenti e successivi, interpola 
        le loro bounding box e gli score.
        
        L'interpolazione delle bounding boxes avviene tramite interpolazione lineare tra i 
        frame adiacenti, mentre lo score viene calcolato come una media pesata in base alla distanza 
        tra i frame adiacenti e il frame da interpolare. 
        
        :Params:
            :frames = Un dizionario contenente i frame, dove la chiave è il nome del frame e 
                      il valore è un dizionario con le informazioni della 
                      bounding box (xmin, ymin, xmax, ymax) e lo score del frame.
            :gap = La distanza massima tra i frame validi che viene considerata per l'interpolazione. 
                   Se la distanza tra un frame vuoto e i frame validi circostanti è maggiore di questo 
                   valore, non viene eseguita l'interpolazione.
        :Return:
            :frames = Il dizionario aggiornato con le bounding boxes e gli score interpolati per i frame vuoti.
    """
    
    frame_keys = list(frames.keys())
    
    for i in range(1, len(frame_keys) - 1):
        current_frame = frame_keys[i]
    
        if frames[current_frame] == {}:
            previous_frame = None
            next_frame = None

            for j in range(i-1, -1, -1):
                if frames[frame_keys[j]] != {}:
                    previous_frame = frame_keys[j]
                    break

            for k in range(i+1, len(frame_keys)):
                if frames[frame_keys[k]] != {}:
                    next_frame = frame_keys[k]
                    break
            
            if previous_frame and next_frame:
                dist_prec = abs(i - frame_keys.index(previous_frame))  # Dist tra precedente e corrente
                dist_succ = abs(i - frame_keys.index(next_frame))  #Dist tra successivo e corrente
                if dist_prec + dist_succ <= gap:
                    frames[current_frame] = interpolare_bounding_box(frames[previous_frame], frames[next_frame], dist_prec, dist_succ)
                    frames[current_frame]["score"] = interpolare_score(frames[previous_frame], frames[next_frame], dist_prec, dist_succ)
    
    return frames

# %%
save_json(f"{PATH_OUT}/json_5_interpolated.json",process_bounding_boxes(interpolare_frames(filter_and_transform_bboxes(open_json(PATH_5),score_threshold=0.5),gap=35)))
# Out:
# JSON saved in: /kaggle/working/json_5_interpolated.json

# %%
save_json(f"{PATH_OUT}/json_6_interpolated.json",process_bounding_boxes(interpolare_frames(filter_and_transform_bboxes(open_json(PATH_6),score_threshold=0.5),gap=35)))
# Out:
# JSON saved in: /kaggle/working/json_6_interpolated.json

# %%
gt_ann_file = Path.home() / PATH_XML_5
pred_file = Path.home() / f'{PATH_OUT}/json_5_interpolated.json'

evaluator = TrackingEvaluator(gt_ann_file, pred_file)
evaluator.load_data()
evaluator.compute_frame_indices()
evaluator.evaluate_metrics()
mse5 = evaluator.compute_mse();
# Out:
# GT   frames: 420 - 2580
# PRED frames: 32 - 2966
# Frame Index Range: (32, 2966)
# Total frames: 346
# Total predictions: 537
# Matches: 276 (0.798)
# No matches: 48 (0.139)
# No predictions: 22 (0.064)
# No frame data: 2589 (0.882)
# Mean Squared Error: 0.024265127309402047

# %%
gt_ann_file = Path.home() / PATH_XML_6
pred_file = Path.home() / f'{PATH_OUT}/json_6_interpolated.json'

evaluator = TrackingEvaluator(gt_ann_file, pred_file)
evaluator.load_data()
evaluator.compute_frame_indices()
evaluator.evaluate_metrics()
mse6 = evaluator.compute_mse();
# Out:
# GT   frames: 417 - 2495
# PRED frames: 7 - 2615
# Frame Index Range: (7, 2615)
# Total frames: 263
# Total predictions: 418
# Matches: 249 (0.947)
# No matches: 12 (0.046)
# No predictions: 2 (0.008)
# No frame data: 2346 (0.899)
# Mean Squared Error: 0.005526862526945486

# %%
print(f'FINAL MSE {np.mean([mse5, mse6])}')
# Out:
# FINAL MSE 0.014895994918173765

# %% [markdown]
# Notiamo che il valore di MSE finale è molto basso ma abbiamo la presenza di tanti falsi positivi che impattano nel video finale di output. Di seguito viene presentato l'ultimo metodo di post-process.

# %%
def post_process(json_data_original, json_data_ts):
    """
        Funzione main di post-processing per elaborare e correggere i dati delle bounding box.

        L'idea alla base è la seguente:
            @ (1)Prendere il file con tresholding con un valore relativamente basso ed successivamente interpolato;
            @ (2)Prendere il file con tresholding con un valore estremamente alto;
            - Usare il (2) per andare a rilevare i limiti da dove iniziano e finiscono le predizioni.
              Quest'ultime vengono prese solo quelle sicure, ecco perchè lo score è alto.
            - Eliminare tutte i frame dal (1) che stanno al di fuori dell'intervallo individuato in precedenza.
            - Iterare su questo intervallo per controllare se ci sono dei falsi positivi, ossia singoli frame,
              diversi da -1,-1 che sono circondati da tanti -1,-1;
            - Iterare nuovamente su questo intervallo e considerare sequenze di frame diversi da -1,-1 che 
            potrebbero essere dei falsi positivi, ossia una sequenza relativamente piccola che è circondata 
            da -1,-1.
            @ Restituire il file interpolato che ha subito tutte le modifiche necessarie.
            
        :Params:
            :json_data_original: Un dizionario contenente i dati interpolati.
            :json_data_ts: Un dizionario contenente i dati post operazione di tresholding.
            
        :Return:
            :json_data_original: Il dizionario aggiornato con i dati modificati.
    """

    print("Starting Post-Processing...")
    
    index_start = -1
    index_end = -1

    #TROVIAMO INDICE DI INIZIO E FINE
    for i in range(len(json_data_ts)):
        file_name = f"{i:05d}.jpg"
        if json_data_ts[file_name]['x'] != -1 and json_data_ts[file_name]['y'] != -1:
            index_start = i
            break

    for j in range(len(json_data_ts)-1, -1, -1):
        file_name = f"{j:05d}.jpg"
        if json_data_ts[file_name]['x'] != -1 and json_data_ts[file_name]['y'] != -1:
            index_end = j
            break

    #Abbiamo gli indici per individuare le irrilevant prediction
    print(f"Index founded. Index Start:{index_start}, Index End:{index_end}")

    # SCARTIAMO TUTTI I FRAME CHE SONO AL DI FUORI DI QUESTO RANGE / IRRILEVANT ANNOTATION
    for k in range(len(json_data_original)):
        file_name = f"{k:05d}.jpg"
        if k < index_start or k > index_end:
            json_data_original[file_name]['x'] = -1
            json_data_original[file_name]['y'] = -1


    #OPERIAMO SULLE STRONG ANNOTATION DATE DA json_data_ts E SULLE WEAK ANNOTATION 
    #CHE SONO QUELLE CHE RIMANGONO DALLE PRECEDENTI OPERAZIONI.
    
    #ELIMINAZIONE DEI FALSI POSITIVI / WEAK ANNOTATION INUTILI
    for l in range(index_start + 1, index_end):
        count_invalid_before = 0
        count_invalid_after = 0
        frame_name = f"{l:05d}.jpg"

        # Conteggio frame = a -1,-1 pre e dopo quello corrente
        if json_data_original[frame_name]['x'] != -1 and json_data_original[frame_name]['y'] != -1:
            i = l - 1
            while i >= 0 and json_data_original[f"{i:05d}.jpg"]['x'] == -1 and json_data_original[f"{i:05d}.jpg"]['y'] == -1:
                count_invalid_before += 1
                i -= 1

            i = l + 1
            while i <= index_end and json_data_original[f"{i:05d}.jpg"]['x'] == -1 and json_data_original[f"{i:05d}.jpg"]['y'] == -1:
                count_invalid_after += 1
                i += 1

        if count_invalid_after >= 10 and count_invalid_before >= 10:
            json_data_original[frame_name]['x'] = -1
            json_data_original[frame_name]['y'] = -1

    # CONTROLLO DELLA WEAK SEQUENCE
    for l in range(index_start, index_end+1):
        valid_frame_sequence = []
        count_invalid_before_sequence = 0
        count_invalid_after_sequence = 0
        frame_name = f"{l:05d}.jpg"
        
        if json_data_original[frame_name]['x'] != -1 and json_data_original[frame_name]['y'] != -1:

            valid_frame_sequence.append(l)
            
            i = l + 1
            while i <= index_end and json_data_original[f"{i:05d}.jpg"]['x'] != -1 and json_data_original[f"{i:05d}.jpg"]['y'] != -1:
                valid_frame_sequence.append(i)
                i += 1

            #Da qui iniza il controllo della weak sequence
            if 15 <= len(valid_frame_sequence) <= 70:

                i = valid_frame_sequence[0] - 1
                while i >= 0 and json_data_original[f"{i:05d}.jpg"]['x'] == -1 and json_data_original[f"{i:05d}.jpg"]['y'] == -1:
                    count_invalid_before_sequence += 1
                    i -= 1
                
                i = valid_frame_sequence[-1] + 1
                while i <= index_end and json_data_original[f"{i:05d}.jpg"]['x'] == -1 and json_data_original[f"{i:05d}.jpg"]['y'] == -1:
                    count_invalid_after_sequence += 1
                    i += 1
                
                # Se i valori -1,-1 prima e dopo sono abbastanza grandi rimuoviamo la sequenza
                if count_invalid_before_sequence >= 40 and count_invalid_after_sequence >= 40:
                    print(f"Sequence: {valid_frame_sequence} with total invalid frame before:{count_invalid_before_sequence} and total invalid frame after: {count_invalid_after_sequence}")
                    for frame_idx in valid_frame_sequence:
                        frame_name = f"{frame_idx:05d}.jpg"
                        json_data_original[frame_name]['x'] = -1
                        json_data_original[frame_name]['y'] = -1

    print("Post-Processing finished!")
    return json_data_original

# %%
save_json(f"{PATH_OUT}/ID_5_256942_252050.json",post_process(open_json(f"{PATH_OUT}/json_5_interpolated.json"),process_bounding_boxes(rimuovi_falsi_positivi(filter_and_transform_bboxes(open_json(PATH_5),score_threshold=0.90)))))
# Out:
# Suspicious frame: 00032.jpg, with 32 empty frames before and 391 empty frames after, info: {'xmin': 316.5431213378906, 'ymin': 55.160499572753906, 'xmax': 341.571533203125, 'ymax': 80.30467224121094, 'score': 0.904865562915802}
# Suspicious frame: 00729.jpg, with 110 empty frames before and 19 empty frames after, info: {'xmin': 1861.1156005859375, 'ymin': 78.15499114990234, 'xmax': 1887.348388671875, 'ymax': 104.8904037475586, 'score': 0.9478008151054382}
# Suspicious frame: 00749.jpg, with 130 empty frames before and 146 empty frames after, info: {'xmin': 1213.257080078125, 'ymin': 57.7552604675293, 'xmax': 1241.1192626953125, 'ymax': 83.89463806152344, 'score': 0.9620065093040466}
# Suspicious frame: 00896.jpg, with 277 empty frames before and 1547 empty frames after, info: {'xmin': 1906.5347900390625, 'ymin': 235.0340118408203, 'xmax': 1920.0, 'ymax': 261.00128173828125, 'score': 0.9795364141464233}
# Starting Post-Processing...
# Index founded. Index Start:424, Index End:2966
# Sequence: [694, 695, 696, 697, 698, 699, 700, 701, 702, 703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714, 715, 716, 717, 718, 719, 720, 721, 722, 723, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753] with total invalid frame before:75 and total invalid frame after: 1658
# Sequence: [2685, 2686, 2687, 2688, 2689, 2690, 2691, 2692, 2693, 2694, 2695, 2696, 2697, 2698, 2699, 2700, 2701, 2702, 2703, 2704, 2705, 2706, 2707, 2708, 2709, 2710, 2711, 2712, 2713] with total invalid frame before:115 and total invalid frame after: 242
# Post-Processing finished!
# JSON saved in: /kaggle/working/ID_5_256942_252050.json

# %%
save_json(f"{PATH_OUT}/ID_6_256942_252050.json",post_process(open_json(f"{PATH_OUT}/json_6_interpolated.json"),process_bounding_boxes(rimuovi_falsi_positivi(filter_and_transform_bboxes(open_json(PATH_6),score_threshold=0.90)))))
# Out:
# Suspicious frame: 01517.jpg, with 879 empty frames before and 569 empty frames after, info: {'xmin': 1611.41748046875, 'ymin': 14.920388221740723, 'xmax': 1636.544921875, 'ymax': 41.916534423828125, 'score': 0.9402928948402405}
# Suspicious frame: 02087.jpg, with 1449 empty frames before and 5 empty frames after, info: {'xmin': 1643.8026123046875, 'ymin': 64.59578704833984, 'xmax': 1669.826171875, 'ymax': 90.81431579589844, 'score': 0.9194740056991577}
# Suspicious frame: 02093.jpg, with 1455 empty frames before and 352 empty frames after, info: {'xmin': 1597.972412109375, 'ymin': 95.5059585571289, 'xmax': 1623.1439208984375, 'ymax': 121.66190338134766, 'score': 0.973003089427948}
# Suspicious frame: 02446.jpg, with 1808 empty frames before and 8 empty frames after, info: {'xmin': 1850.289794921875, 'ymin': 588.3661499023438, 'xmax': 1876.76953125, 'ymax': 614.4552001953125, 'score': 0.9041323065757751}
# Starting Post-Processing...
# Index founded. Index Start:418, Index End:2494
# Sequence: [1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519] with total invalid frame before:245 and total invalid frame after: 76
# Sequence: [1596, 1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643] with total invalid frame before:340 and total invalid frame after: 443
# Sequence: [2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100, 2101, 2102, 2103, 2104, 2105, 2106, 2107, 2108] with total invalid frame before:831 and total invalid frame after: 337
# Post-Processing finished!
# JSON saved in: /kaggle/working/ID_6_256942_252050.json

# %%
gt_ann_file = Path.home() / PATH_XML_5
pred_file = Path.home() / f'{PATH_OUT}/ID_5_256942_252050.json'

evaluator = TrackingEvaluator(gt_ann_file, pred_file)
evaluator.load_data()
evaluator.compute_frame_indices()
evaluator.evaluate_metrics()
mse5 = evaluator.compute_mse();
# Out:
# GT   frames: 420 - 2580
# PRED frames: 424 - 2966
# Frame Index Range: (420, 2966)
# Total frames: 346
# Total predictions: 364
# Matches: 276 (0.798)
# No matches: 44 (0.127)
# No predictions: 26 (0.075)
# No frame data: 2201 (0.864)
# Mean Squared Error: 0.02769434631639687

# %%
gt_ann_file = Path.home() / PATH_XML_6
pred_file = Path.home() / f'{PATH_OUT}/ID_6_256942_252050.json'

evaluator = TrackingEvaluator(gt_ann_file, pred_file)
evaluator.load_data()
evaluator.compute_frame_indices()
evaluator.evaluate_metrics()
mse6 = evaluator.compute_mse();
# Out:
# GT   frames: 417 - 2495
# PRED frames: 418 - 2494
# Frame Index Range: (417, 2495)
# Total frames: 263
# Total predictions: 284
# Matches: 249 (0.947)
# No matches: 12 (0.046)
# No predictions: 2 (0.008)
# No frame data: 1816 (0.873)
# Mean Squared Error: 0.005526862526945486

# %%
print(f'FINAL MSE {np.mean([mse5, mse6])}')
# Out:
# FINAL MSE 0.016610604421671178

# %% [markdown]
# # CREAZIONE DEL VIDEO

# %%
import cv2
import json
import os
import re
import numpy as np

def crea_video_con_annotazioni(cartella_immagini, file_json, output_video):
    
    print(f"Caricamento del file JSON: {file_json}")
    
    with open(file_json, 'r') as f:
        annotazioni = json.load(f)
        
    print(f"Annotazioni caricate. Numero di frame nel JSON: {len(annotazioni)}")

    frame_files = sorted(
        [f for f in os.listdir(cartella_immagini) if f.endswith('.jpg')],
        key=lambda f: int(re.sub('\D', '', f)) #cosi otteniamo solo il numero
    )
    
    print(f"Numero di immagini trovate nella cartella: {len(frame_files)}")

    img = cv2.imread(os.path.join(cartella_immagini, frame_files[0]))
    altezza, larghezza, _ = img.shape
    print(f"Dimensioni del frame: larghezza = {larghezza}, altezza = {altezza}")

    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    video = cv2.VideoWriter(output_video, fourcc, 25.0, (larghezza, altezza))
    print(f"Video writer creato. Output: {output_video}")

    # solo per i 5 frame precedenti
    traccia_palla = []

    for i, frame_file in enumerate(frame_files):
        print(f"Processando il frame: {frame_file}")

        frame_number = re.search(r'(\d+)', frame_file).group(0)
        frame_name = f"{int(frame_number):05d}.jpg"

        print(f"Nome frame formato per JSON: {frame_name}")

        frame = cv2.imread(os.path.join(cartella_immagini, frame_file))

        previsione = None
        if frame_name in annotazioni:
            x, y = annotazioni[frame_name]['x'], annotazioni[frame_name]['y']
            print(f"Annotazioni trovate per {frame_name}: x = {x}, y = {y}")

            if x != -1 and y != -1:
                print(f"Aggiungendo cerchio al frame {frame_name} alle coordinate ({x}, {y})")
                traccia_palla.append((int(x), int(y)))
                previsione = (int(x), int(y))
            else:
                # Se l'annotazione è (-1, -1),la dobbiamo comunque considerare altrimenti abbiamo un video sballato
                print(f"Frame {frame_name} con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.")
                traccia_palla.append((-1, -1))
        else:
            print(f"Nessuna annotazione trovata per il frame: {frame_name}")
            traccia_palla.append((-1, -1))

        # Limitiamo la traccia della palla ai 5 frame precedenti
        if len(traccia_palla) > 5:
            traccia_palla.pop(0)

        for idx, (px, py) in enumerate(traccia_palla[:-1]): 
            if px != -1 and py != -1:
                color = (0, 0, int(255 * (idx / len(traccia_palla))))  #Per ottenere un effetto graduale del colore rosso
                if idx > 0 and traccia_palla[idx - 1] != (-1, -1):
                    prev_x, prev_y = traccia_palla[idx - 1]
                    cv2.line(frame, (prev_x, prev_y), (px, py), color, 2)

        if previsione:
            px, py = previsione
            cv2.circle(frame, (px, py), 10, (0, 0, 255), 2)

        video.write(frame)

    video.release()
    print(f"Video salvato come: {output_video}")

# %%
cartella_immagini = '/kaggle/input/computer-vision-futbal/dataset/dataset/test/ID-5'
file_json = f"{PATH_OUT}/ID_5_256942_252050.json"
output_video = f"{PATH_OUT}/video_5.avi"

crea_video_con_annotazioni(cartella_immagini, file_json, output_video)
# Out:
# Caricamento del file JSON: /kaggle/working/ID_5_256942_252050.json
# Annotazioni caricate. Numero di frame nel JSON: 2999
# Numero di immagini trovate nella cartella: 2999
# Dimensioni del frame: larghezza = 1920, altezza = 1080
# Video writer creato. Output: /kaggle/working/video_5.avi
# Processando il frame: frame_0.jpg
# Nome frame formato per JSON: 00000.jpg
# Annotazioni trovate per 00000.jpg: x = -1, y = -1
# Frame 00000.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_1.jpg
# Nome frame formato per JSON: 00001.jpg
# Annotazioni trovate per 00001.jpg: x = -1, y = -1
# Frame 00001.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2.jpg
# Nome frame formato per JSON: 00002.jpg
# Annotazioni trovate per 00002.jpg: x = -1, y = -1
# Frame 00002.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_3.jpg
# Nome frame formato per JSON: 00003.jpg
# Annotazioni trovate per 00003.jpg: x = -1, y = -1
# Frame 00003.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_4.jpg
# Nome frame formato per JSON: 00004.jpg
# Annotazioni trovate per 00004.jpg: x = -1, y = -1
# Frame 00004.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_5.jpg
# Nome frame formato per JSON: 00005.jpg
# Annotazioni trovate per 00005.jpg: x = -1, y = -1
# Frame 00005.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_6.jpg
# Nome frame formato per JSON: 00006.jpg
# Annotazioni trovate per 00006.jpg: x = -1, y = -1
# Frame 00006.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_7.jpg
# Nome frame formato per JSON: 00007.jpg
# Annotazioni trovate per 00007.jpg: x = -1, y = -1
# Frame 00007.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_8.jpg
# Nome frame formato per JSON: 00008.jpg
# Annotazioni trovate per 00008.jpg: x = -1, y = -1
# Frame 00008.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_9.jpg
# Nome frame formato per JSON: 00009.jpg
# Annotazioni trovate per 00009.jpg: x = -1, y = -1
# Frame 00009.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_10.jpg
# Nome frame formato per JSON: 00010.jpg
# Annotazioni trovate per 00010.jpg: x = -1, y = -1
# Frame 00010.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_11.jpg
# Nome frame formato per JSON: 00011.jpg
# Annotazioni trovate per 00011.jpg: x = -1, y = -1
# Frame 00011.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_12.jpg
# Nome frame formato per JSON: 00012.jpg
# Annotazioni trovate per 00012.jpg: x = -1, y = -1
# Frame 00012.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_13.jpg
# Nome frame formato per JSON: 00013.jpg
# Annotazioni trovate per 00013.jpg: x = -1, y = -1
# Frame 00013.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_14.jpg
# Nome frame formato per JSON: 00014.jpg
# Annotazioni trovate per 00014.jpg: x = -1, y = -1
# Frame 00014.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_15.jpg
# Nome frame formato per JSON: 00015.jpg
# Annotazioni trovate per 00015.jpg: x = -1, y = -1
# Frame 00015.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_16.jpg
# Nome frame formato per JSON: 00016.jpg
# Annotazioni trovate per 00016.jpg: x = -1, y = -1
# Frame 00016.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_17.jpg
# Nome frame formato per JSON: 00017.jpg
# Annotazioni trovate per 00017.jpg: x = -1, y = -1
# Frame 00017.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_18.jpg
# Nome frame formato per JSON: 00018.jpg
# Annotazioni trovate per 00018.jpg: x = -1, y = -1
# Frame 00018.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_19.jpg
# Nome frame formato per JSON: 00019.jpg
# Annotazioni trovate per 00019.jpg: x = -1, y = -1
# Frame 00019.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_20.jpg
# Nome frame formato per JSON: 00020.jpg
# Annotazioni trovate per 00020.jpg: x = -1, y = -1
# Frame 00020.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_21.jpg
# Nome frame formato per JSON: 00021.jpg
# Annotazioni trovate per 00021.jpg: x = -1, y = -1
# Frame 00021.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_22.jpg
# Nome frame formato per JSON: 00022.jpg
# Annotazioni trovate per 00022.jpg: x = -1, y = -1
# Frame 00022.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_23.jpg
# Nome frame formato per JSON: 00023.jpg
# Annotazioni trovate per 00023.jpg: x = -1, y = -1
# Frame 00023.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_24.jpg
# Nome frame formato per JSON: 00024.jpg
# Annotazioni trovate per 00024.jpg: x = -1, y = -1
# Frame 00024.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_25.jpg
# Nome frame formato per JSON: 00025.jpg
# Annotazioni trovate per 00025.jpg: x = -1, y = -1
# Frame 00025.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_26.jpg
# Nome frame formato per JSON: 00026.jpg
# Annotazioni trovate per 00026.jpg: x = -1, y = -1
# Frame 00026.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_27.jpg
# Nome frame formato per JSON: 00027.jpg
# Annotazioni trovate per 00027.jpg: x = -1, y = -1
# Frame 00027.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_28.jpg
# Nome frame formato per JSON: 00028.jpg
# Annotazioni trovate per 00028.jpg: x = -1, y = -1
# Frame 00028.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_29.jpg
# Nome frame formato per JSON: 00029.jpg
# Annotazioni trovate per 00029.jpg: x = -1, y = -1
# Frame 00029.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_30.jpg
# Nome frame formato per JSON: 00030.jpg
# Annotazioni trovate per 00030.jpg: x = -1, y = -1
# Frame 00030.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_31.jpg
# Nome frame formato per JSON: 00031.jpg
# Annotazioni trovate per 00031.jpg: x = -1, y = -1
# Frame 00031.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_32.jpg
# Nome frame formato per JSON: 00032.jpg
# Annotazioni trovate per 00032.jpg: x = -1, y = -1
# Frame 00032.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_33.jpg
# Nome frame formato per JSON: 00033.jpg
# Annotazioni trovate per 00033.jpg: x = -1, y = -1
# Frame 00033.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_34.jpg
# Nome frame formato per JSON: 00034.jpg
# Annotazioni trovate per 00034.jpg: x = -1, y = -1
# Frame 00034.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_35.jpg
# Nome frame formato per JSON: 00035.jpg
# Annotazioni trovate per 00035.jpg: x = -1, y = -1
# Frame 00035.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_36.jpg
# Nome frame formato per JSON: 00036.jpg
# Annotazioni trovate per 00036.jpg: x = -1, y = -1
# Frame 00036.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_37.jpg
# Nome frame formato per JSON: 00037.jpg
# Annotazioni trovate per 00037.jpg: x = -1, y = -1
# Frame 00037.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_38.jpg
# Nome frame formato per JSON: 00038.jpg
# Annotazioni trovate per 00038.jpg: x = -1, y = -1
# Frame 00038.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_39.jpg
# Nome frame formato per JSON: 00039.jpg
# Annotazioni trovate per 00039.jpg: x = -1, y = -1
# Frame 00039.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_40.jpg
# Nome frame formato per JSON: 00040.jpg
# Annotazioni trovate per 00040.jpg: x = -1, y = -1
# Frame 00040.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_41.jpg
# Nome frame formato per JSON: 00041.jpg
# Annotazioni trovate per 00041.jpg: x = -1, y = -1
# Frame 00041.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_42.jpg
# Nome frame formato per JSON: 00042.jpg
# Annotazioni trovate per 00042.jpg: x = -1, y = -1
# Frame 00042.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_43.jpg
# Nome frame formato per JSON: 00043.jpg
# Annotazioni trovate per 00043.jpg: x = -1, y = -1
# Frame 00043.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_44.jpg
# Nome frame formato per JSON: 00044.jpg
# Annotazioni trovate per 00044.jpg: x = -1, y = -1
# Frame 00044.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_45.jpg
# Nome frame formato per JSON: 00045.jpg
# Annotazioni trovate per 00045.jpg: x = -1, y = -1
# Frame 00045.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_46.jpg
# Nome frame formato per JSON: 00046.jpg
# Annotazioni trovate per 00046.jpg: x = -1, y = -1
# Frame 00046.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_47.jpg
# Nome frame formato per JSON: 00047.jpg
# Annotazioni trovate per 00047.jpg: x = -1, y = -1
# Frame 00047.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_48.jpg
# Nome frame formato per JSON: 00048.jpg
# Annotazioni trovate per 00048.jpg: x = -1, y = -1
# Frame 00048.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_49.jpg
# Nome frame formato per JSON: 00049.jpg
# Annotazioni trovate per 00049.jpg: x = -1, y = -1
# Frame 00049.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_50.jpg
# Nome frame formato per JSON: 00050.jpg
# Annotazioni trovate per 00050.jpg: x = -1, y = -1
# Frame 00050.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_51.jpg
# Nome frame formato per JSON: 00051.jpg
# Annotazioni trovate per 00051.jpg: x = -1, y = -1
# Frame 00051.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_52.jpg
# Nome frame formato per JSON: 00052.jpg
# Annotazioni trovate per 00052.jpg: x = -1, y = -1
# Frame 00052.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_53.jpg
# Nome frame formato per JSON: 00053.jpg
# Annotazioni trovate per 00053.jpg: x = -1, y = -1
# Frame 00053.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_54.jpg
# Nome frame formato per JSON: 00054.jpg
# Annotazioni trovate per 00054.jpg: x = -1, y = -1
# Frame 00054.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_55.jpg
# Nome frame formato per JSON: 00055.jpg
# Annotazioni trovate per 00055.jpg: x = -1, y = -1
# Frame 00055.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_56.jpg
# Nome frame formato per JSON: 00056.jpg
# Annotazioni trovate per 00056.jpg: x = -1, y = -1
# Frame 00056.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_57.jpg
# Nome frame formato per JSON: 00057.jpg
# Annotazioni trovate per 00057.jpg: x = -1, y = -1
# Frame 00057.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_58.jpg
# Nome frame formato per JSON: 00058.jpg
# Annotazioni trovate per 00058.jpg: x = -1, y = -1
# Frame 00058.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_59.jpg
# Nome frame formato per JSON: 00059.jpg
# Annotazioni trovate per 00059.jpg: x = -1, y = -1
# Frame 00059.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_60.jpg
# Nome frame formato per JSON: 00060.jpg
# Annotazioni trovate per 00060.jpg: x = -1, y = -1
# Frame 00060.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_61.jpg
# Nome frame formato per JSON: 00061.jpg
# Annotazioni trovate per 00061.jpg: x = -1, y = -1
# Frame 00061.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_62.jpg
# Nome frame formato per JSON: 00062.jpg
# Annotazioni trovate per 00062.jpg: x = -1, y = -1
# Frame 00062.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_63.jpg
# Nome frame formato per JSON: 00063.jpg
# Annotazioni trovate per 00063.jpg: x = -1, y = -1
# Frame 00063.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_64.jpg
# Nome frame formato per JSON: 00064.jpg
# Annotazioni trovate per 00064.jpg: x = -1, y = -1
# Frame 00064.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_65.jpg
# Nome frame formato per JSON: 00065.jpg
# Annotazioni trovate per 00065.jpg: x = -1, y = -1
# Frame 00065.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_66.jpg
# Nome frame formato per JSON: 00066.jpg
# Annotazioni trovate per 00066.jpg: x = -1, y = -1
# Frame 00066.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_67.jpg
# Nome frame formato per JSON: 00067.jpg
# Annotazioni trovate per 00067.jpg: x = -1, y = -1
# Frame 00067.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_68.jpg
# Nome frame formato per JSON: 00068.jpg
# Annotazioni trovate per 00068.jpg: x = -1, y = -1
# Frame 00068.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_69.jpg
# Nome frame formato per JSON: 00069.jpg
# Annotazioni trovate per 00069.jpg: x = -1, y = -1
# Frame 00069.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_70.jpg
# Nome frame formato per JSON: 00070.jpg
# Annotazioni trovate per 00070.jpg: x = -1, y = -1
# Frame 00070.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_71.jpg
# Nome frame formato per JSON: 00071.jpg
# Annotazioni trovate per 00071.jpg: x = -1, y = -1
# Frame 00071.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_72.jpg
# Nome frame formato per JSON: 00072.jpg
# Annotazioni trovate per 00072.jpg: x = -1, y = -1
# Frame 00072.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_73.jpg
# Nome frame formato per JSON: 00073.jpg
# Annotazioni trovate per 00073.jpg: x = -1, y = -1
# Frame 00073.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_74.jpg
# Nome frame formato per JSON: 00074.jpg
# Annotazioni trovate per 00074.jpg: x = -1, y = -1
# Frame 00074.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_75.jpg
# Nome frame formato per JSON: 00075.jpg
# Annotazioni trovate per 00075.jpg: x = -1, y = -1
# Frame 00075.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_76.jpg
# Nome frame formato per JSON: 00076.jpg
# Annotazioni trovate per 00076.jpg: x = -1, y = -1
# Frame 00076.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_77.jpg
# Nome frame formato per JSON: 00077.jpg
# Annotazioni trovate per 00077.jpg: x = -1, y = -1
# Frame 00077.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_78.jpg
# Nome frame formato per JSON: 00078.jpg
# Annotazioni trovate per 00078.jpg: x = -1, y = -1
# Frame 00078.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_79.jpg
# Nome frame formato per JSON: 00079.jpg
# Annotazioni trovate per 00079.jpg: x = -1, y = -1
# Frame 00079.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_80.jpg
# Nome frame formato per JSON: 00080.jpg
# Annotazioni trovate per 00080.jpg: x = -1, y = -1
# Frame 00080.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_81.jpg
# Nome frame formato per JSON: 00081.jpg
# Annotazioni trovate per 00081.jpg: x = -1, y = -1
# Frame 00081.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_82.jpg
# Nome frame formato per JSON: 00082.jpg
# Annotazioni trovate per 00082.jpg: x = -1, y = -1
# Frame 00082.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_83.jpg
# Nome frame formato per JSON: 00083.jpg
# Annotazioni trovate per 00083.jpg: x = -1, y = -1
# Frame 00083.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_84.jpg
# Nome frame formato per JSON: 00084.jpg
# Annotazioni trovate per 00084.jpg: x = -1, y = -1
# Frame 00084.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_85.jpg
# Nome frame formato per JSON: 00085.jpg
# Annotazioni trovate per 00085.jpg: x = -1, y = -1
# Frame 00085.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_86.jpg
# Nome frame formato per JSON: 00086.jpg
# Annotazioni trovate per 00086.jpg: x = -1, y = -1
# Frame 00086.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_87.jpg
# Nome frame formato per JSON: 00087.jpg
# Annotazioni trovate per 00087.jpg: x = -1, y = -1
# Frame 00087.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_88.jpg
# Nome frame formato per JSON: 00088.jpg
# Annotazioni trovate per 00088.jpg: x = -1, y = -1
# Frame 00088.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_89.jpg
# Nome frame formato per JSON: 00089.jpg
# Annotazioni trovate per 00089.jpg: x = -1, y = -1
# Frame 00089.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_90.jpg
# Nome frame formato per JSON: 00090.jpg
# Annotazioni trovate per 00090.jpg: x = -1, y = -1
# Frame 00090.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_91.jpg
# Nome frame formato per JSON: 00091.jpg
# Annotazioni trovate per 00091.jpg: x = -1, y = -1
# Frame 00091.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_92.jpg
# Nome frame formato per JSON: 00092.jpg
# Annotazioni trovate per 00092.jpg: x = -1, y = -1
# Frame 00092.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_93.jpg
# Nome frame formato per JSON: 00093.jpg
# Annotazioni trovate per 00093.jpg: x = -1, y = -1
# Frame 00093.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_94.jpg
# Nome frame formato per JSON: 00094.jpg
# Annotazioni trovate per 00094.jpg: x = -1, y = -1
# Frame 00094.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_95.jpg
# Nome frame formato per JSON: 00095.jpg
# Annotazioni trovate per 00095.jpg: x = -1, y = -1
# Frame 00095.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_96.jpg
# Nome frame formato per JSON: 00096.jpg
# Annotazioni trovate per 00096.jpg: x = -1, y = -1
# Frame 00096.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_97.jpg
# Nome frame formato per JSON: 00097.jpg
# Annotazioni trovate per 00097.jpg: x = -1, y = -1
# Frame 00097.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_98.jpg
# Nome frame formato per JSON: 00098.jpg
# Annotazioni trovate per 00098.jpg: x = -1, y = -1
# Frame 00098.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_99.jpg
# Nome frame formato per JSON: 00099.jpg
# Annotazioni trovate per 00099.jpg: x = -1, y = -1
# Frame 00099.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_100.jpg
# Nome frame formato per JSON: 00100.jpg
# Annotazioni trovate per 00100.jpg: x = -1, y = -1
# Frame 00100.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_101.jpg
# Nome frame formato per JSON: 00101.jpg
# Annotazioni trovate per 00101.jpg: x = -1, y = -1
# Frame 00101.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_102.jpg
# Nome frame formato per JSON: 00102.jpg
# Annotazioni trovate per 00102.jpg: x = -1, y = -1
# Frame 00102.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_103.jpg
# Nome frame formato per JSON: 00103.jpg
# Annotazioni trovate per 00103.jpg: x = -1, y = -1
# Frame 00103.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_104.jpg
# Nome frame formato per JSON: 00104.jpg
# Annotazioni trovate per 00104.jpg: x = -1, y = -1
# Frame 00104.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_105.jpg
# Nome frame formato per JSON: 00105.jpg
# Annotazioni trovate per 00105.jpg: x = -1, y = -1
# Frame 00105.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_106.jpg
# Nome frame formato per JSON: 00106.jpg
# Annotazioni trovate per 00106.jpg: x = -1, y = -1
# Frame 00106.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_107.jpg
# Nome frame formato per JSON: 00107.jpg
# Annotazioni trovate per 00107.jpg: x = -1, y = -1
# Frame 00107.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_108.jpg
# Nome frame formato per JSON: 00108.jpg
# Annotazioni trovate per 00108.jpg: x = -1, y = -1
# Frame 00108.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_109.jpg
# Nome frame formato per JSON: 00109.jpg
# Annotazioni trovate per 00109.jpg: x = -1, y = -1
# Frame 00109.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_110.jpg
# Nome frame formato per JSON: 00110.jpg
# Annotazioni trovate per 00110.jpg: x = -1, y = -1
# Frame 00110.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_111.jpg
# Nome frame formato per JSON: 00111.jpg
# Annotazioni trovate per 00111.jpg: x = -1, y = -1
# Frame 00111.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_112.jpg
# Nome frame formato per JSON: 00112.jpg
# Annotazioni trovate per 00112.jpg: x = -1, y = -1
# Frame 00112.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_113.jpg
# Nome frame formato per JSON: 00113.jpg
# Annotazioni trovate per 00113.jpg: x = -1, y = -1
# Frame 00113.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_114.jpg
# Nome frame formato per JSON: 00114.jpg
# Annotazioni trovate per 00114.jpg: x = -1, y = -1
# Frame 00114.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_115.jpg
# Nome frame formato per JSON: 00115.jpg
# Annotazioni trovate per 00115.jpg: x = -1, y = -1
# Frame 00115.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_116.jpg
# Nome frame formato per JSON: 00116.jpg
# Annotazioni trovate per 00116.jpg: x = -1, y = -1
# Frame 00116.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_117.jpg
# Nome frame formato per JSON: 00117.jpg
# Annotazioni trovate per 00117.jpg: x = -1, y = -1
# Frame 00117.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_118.jpg
# Nome frame formato per JSON: 00118.jpg
# Annotazioni trovate per 00118.jpg: x = -1, y = -1
# Frame 00118.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_119.jpg
# Nome frame formato per JSON: 00119.jpg
# Annotazioni trovate per 00119.jpg: x = -1, y = -1
# Frame 00119.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_120.jpg
# Nome frame formato per JSON: 00120.jpg
# Annotazioni trovate per 00120.jpg: x = -1, y = -1
# Frame 00120.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_121.jpg
# Nome frame formato per JSON: 00121.jpg
# Annotazioni trovate per 00121.jpg: x = -1, y = -1
# Frame 00121.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_122.jpg
# Nome frame formato per JSON: 00122.jpg
# Annotazioni trovate per 00122.jpg: x = -1, y = -1
# Frame 00122.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_123.jpg
# Nome frame formato per JSON: 00123.jpg
# Annotazioni trovate per 00123.jpg: x = -1, y = -1
# Frame 00123.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_124.jpg
# Nome frame formato per JSON: 00124.jpg
# Annotazioni trovate per 00124.jpg: x = -1, y = -1
# Frame 00124.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_125.jpg
# Nome frame formato per JSON: 00125.jpg
# Annotazioni trovate per 00125.jpg: x = -1, y = -1
# Frame 00125.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_126.jpg
# Nome frame formato per JSON: 00126.jpg
# Annotazioni trovate per 00126.jpg: x = -1, y = -1
# Frame 00126.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_127.jpg
# Nome frame formato per JSON: 00127.jpg
# Annotazioni trovate per 00127.jpg: x = -1, y = -1
# Frame 00127.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_128.jpg
# Nome frame formato per JSON: 00128.jpg
# Annotazioni trovate per 00128.jpg: x = -1, y = -1
# Frame 00128.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_129.jpg
# Nome frame formato per JSON: 00129.jpg
# Annotazioni trovate per 00129.jpg: x = -1, y = -1
# Frame 00129.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_130.jpg
# Nome frame formato per JSON: 00130.jpg
# Annotazioni trovate per 00130.jpg: x = -1, y = -1
# Frame 00130.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_131.jpg
# Nome frame formato per JSON: 00131.jpg
# Annotazioni trovate per 00131.jpg: x = -1, y = -1
# Frame 00131.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_132.jpg
# Nome frame formato per JSON: 00132.jpg
# Annotazioni trovate per 00132.jpg: x = -1, y = -1
# Frame 00132.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_133.jpg
# Nome frame formato per JSON: 00133.jpg
# Annotazioni trovate per 00133.jpg: x = -1, y = -1
# Frame 00133.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_134.jpg
# Nome frame formato per JSON: 00134.jpg
# Annotazioni trovate per 00134.jpg: x = -1, y = -1
# Frame 00134.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_135.jpg
# Nome frame formato per JSON: 00135.jpg
# Annotazioni trovate per 00135.jpg: x = -1, y = -1
# Frame 00135.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_136.jpg
# Nome frame formato per JSON: 00136.jpg
# Annotazioni trovate per 00136.jpg: x = -1, y = -1
# Frame 00136.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_137.jpg
# Nome frame formato per JSON: 00137.jpg
# Annotazioni trovate per 00137.jpg: x = -1, y = -1
# Frame 00137.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_138.jpg
# Nome frame formato per JSON: 00138.jpg
# Annotazioni trovate per 00138.jpg: x = -1, y = -1
# Frame 00138.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_139.jpg
# Nome frame formato per JSON: 00139.jpg
# Annotazioni trovate per 00139.jpg: x = -1, y = -1
# Frame 00139.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_140.jpg
# Nome frame formato per JSON: 00140.jpg
# Annotazioni trovate per 00140.jpg: x = -1, y = -1
# Frame 00140.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_141.jpg
# Nome frame formato per JSON: 00141.jpg
# Annotazioni trovate per 00141.jpg: x = -1, y = -1
# Frame 00141.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_142.jpg
# Nome frame formato per JSON: 00142.jpg
# Annotazioni trovate per 00142.jpg: x = -1, y = -1
# Frame 00142.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_143.jpg
# Nome frame formato per JSON: 00143.jpg
# Annotazioni trovate per 00143.jpg: x = -1, y = -1
# Frame 00143.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_144.jpg
# Nome frame formato per JSON: 00144.jpg
# Annotazioni trovate per 00144.jpg: x = -1, y = -1
# Frame 00144.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_145.jpg
# Nome frame formato per JSON: 00145.jpg
# Annotazioni trovate per 00145.jpg: x = -1, y = -1
# Frame 00145.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_146.jpg
# Nome frame formato per JSON: 00146.jpg
# Annotazioni trovate per 00146.jpg: x = -1, y = -1
# Frame 00146.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_147.jpg
# Nome frame formato per JSON: 00147.jpg
# Annotazioni trovate per 00147.jpg: x = -1, y = -1
# Frame 00147.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_148.jpg
# Nome frame formato per JSON: 00148.jpg
# Annotazioni trovate per 00148.jpg: x = -1, y = -1
# Frame 00148.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_149.jpg
# Nome frame formato per JSON: 00149.jpg
# Annotazioni trovate per 00149.jpg: x = -1, y = -1
# Frame 00149.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_150.jpg
# Nome frame formato per JSON: 00150.jpg
# Annotazioni trovate per 00150.jpg: x = -1, y = -1
# Frame 00150.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_151.jpg
# Nome frame formato per JSON: 00151.jpg
# Annotazioni trovate per 00151.jpg: x = -1, y = -1
# Frame 00151.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_152.jpg
# Nome frame formato per JSON: 00152.jpg
# Annotazioni trovate per 00152.jpg: x = -1, y = -1
# Frame 00152.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_153.jpg
# Nome frame formato per JSON: 00153.jpg
# Annotazioni trovate per 00153.jpg: x = -1, y = -1
# Frame 00153.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_154.jpg
# Nome frame formato per JSON: 00154.jpg
# Annotazioni trovate per 00154.jpg: x = -1, y = -1
# Frame 00154.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_155.jpg
# Nome frame formato per JSON: 00155.jpg
# Annotazioni trovate per 00155.jpg: x = -1, y = -1
# Frame 00155.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_156.jpg
# Nome frame formato per JSON: 00156.jpg
# Annotazioni trovate per 00156.jpg: x = -1, y = -1
# Frame 00156.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_157.jpg
# Nome frame formato per JSON: 00157.jpg
# Annotazioni trovate per 00157.jpg: x = -1, y = -1
# Frame 00157.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_158.jpg
# Nome frame formato per JSON: 00158.jpg
# Annotazioni trovate per 00158.jpg: x = -1, y = -1
# Frame 00158.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_159.jpg
# Nome frame formato per JSON: 00159.jpg
# Annotazioni trovate per 00159.jpg: x = -1, y = -1
# Frame 00159.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_160.jpg
# Nome frame formato per JSON: 00160.jpg
# Annotazioni trovate per 00160.jpg: x = -1, y = -1
# Frame 00160.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_161.jpg
# Nome frame formato per JSON: 00161.jpg
# Annotazioni trovate per 00161.jpg: x = -1, y = -1
# Frame 00161.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_162.jpg
# Nome frame formato per JSON: 00162.jpg
# Annotazioni trovate per 00162.jpg: x = -1, y = -1
# Frame 00162.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_163.jpg
# Nome frame formato per JSON: 00163.jpg
# Annotazioni trovate per 00163.jpg: x = -1, y = -1
# Frame 00163.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_164.jpg
# Nome frame formato per JSON: 00164.jpg
# Annotazioni trovate per 00164.jpg: x = -1, y = -1
# Frame 00164.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_165.jpg
# Nome frame formato per JSON: 00165.jpg
# Annotazioni trovate per 00165.jpg: x = -1, y = -1
# Frame 00165.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_166.jpg
# Nome frame formato per JSON: 00166.jpg
# Annotazioni trovate per 00166.jpg: x = -1, y = -1
# Frame 00166.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_167.jpg
# Nome frame formato per JSON: 00167.jpg
# Annotazioni trovate per 00167.jpg: x = -1, y = -1
# Frame 00167.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_168.jpg
# Nome frame formato per JSON: 00168.jpg
# Annotazioni trovate per 00168.jpg: x = -1, y = -1
# Frame 00168.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_169.jpg
# Nome frame formato per JSON: 00169.jpg
# Annotazioni trovate per 00169.jpg: x = -1, y = -1
# Frame 00169.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_170.jpg
# Nome frame formato per JSON: 00170.jpg
# Annotazioni trovate per 00170.jpg: x = -1, y = -1
# Frame 00170.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_171.jpg
# Nome frame formato per JSON: 00171.jpg
# Annotazioni trovate per 00171.jpg: x = -1, y = -1
# Frame 00171.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_172.jpg
# Nome frame formato per JSON: 00172.jpg
# Annotazioni trovate per 00172.jpg: x = -1, y = -1
# Frame 00172.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_173.jpg
# Nome frame formato per JSON: 00173.jpg
# Annotazioni trovate per 00173.jpg: x = -1, y = -1
# Frame 00173.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_174.jpg
# Nome frame formato per JSON: 00174.jpg
# Annotazioni trovate per 00174.jpg: x = -1, y = -1
# Frame 00174.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_175.jpg
# Nome frame formato per JSON: 00175.jpg
# Annotazioni trovate per 00175.jpg: x = -1, y = -1
# Frame 00175.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_176.jpg
# Nome frame formato per JSON: 00176.jpg
# Annotazioni trovate per 00176.jpg: x = -1, y = -1
# Frame 00176.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_177.jpg
# Nome frame formato per JSON: 00177.jpg
# Annotazioni trovate per 00177.jpg: x = -1, y = -1
# Frame 00177.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_178.jpg
# Nome frame formato per JSON: 00178.jpg
# Annotazioni trovate per 00178.jpg: x = -1, y = -1
# Frame 00178.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_179.jpg
# Nome frame formato per JSON: 00179.jpg
# Annotazioni trovate per 00179.jpg: x = -1, y = -1
# Frame 00179.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_180.jpg
# Nome frame formato per JSON: 00180.jpg
# Annotazioni trovate per 00180.jpg: x = -1, y = -1
# Frame 00180.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_181.jpg
# Nome frame formato per JSON: 00181.jpg
# Annotazioni trovate per 00181.jpg: x = -1, y = -1
# Frame 00181.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_182.jpg
# Nome frame formato per JSON: 00182.jpg
# Annotazioni trovate per 00182.jpg: x = -1, y = -1
# Frame 00182.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_183.jpg
# Nome frame formato per JSON: 00183.jpg
# Annotazioni trovate per 00183.jpg: x = -1, y = -1
# Frame 00183.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_184.jpg
# Nome frame formato per JSON: 00184.jpg
# Annotazioni trovate per 00184.jpg: x = -1, y = -1
# Frame 00184.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_185.jpg
# Nome frame formato per JSON: 00185.jpg
# Annotazioni trovate per 00185.jpg: x = -1, y = -1
# Frame 00185.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_186.jpg
# Nome frame formato per JSON: 00186.jpg
# Annotazioni trovate per 00186.jpg: x = -1, y = -1
# Frame 00186.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_187.jpg
# Nome frame formato per JSON: 00187.jpg
# Annotazioni trovate per 00187.jpg: x = -1, y = -1
# Frame 00187.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_188.jpg
# Nome frame formato per JSON: 00188.jpg
# Annotazioni trovate per 00188.jpg: x = -1, y = -1
# Frame 00188.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_189.jpg
# Nome frame formato per JSON: 00189.jpg
# Annotazioni trovate per 00189.jpg: x = -1, y = -1
# Frame 00189.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_190.jpg
# Nome frame formato per JSON: 00190.jpg
# Annotazioni trovate per 00190.jpg: x = -1, y = -1
# Frame 00190.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_191.jpg
# Nome frame formato per JSON: 00191.jpg
# Annotazioni trovate per 00191.jpg: x = -1, y = -1
# Frame 00191.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_192.jpg
# Nome frame formato per JSON: 00192.jpg
# Annotazioni trovate per 00192.jpg: x = -1, y = -1
# Frame 00192.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_193.jpg
# Nome frame formato per JSON: 00193.jpg
# Annotazioni trovate per 00193.jpg: x = -1, y = -1
# Frame 00193.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_194.jpg
# Nome frame formato per JSON: 00194.jpg
# Annotazioni trovate per 00194.jpg: x = -1, y = -1
# Frame 00194.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_195.jpg
# Nome frame formato per JSON: 00195.jpg
# Annotazioni trovate per 00195.jpg: x = -1, y = -1
# Frame 00195.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_196.jpg
# Nome frame formato per JSON: 00196.jpg
# Annotazioni trovate per 00196.jpg: x = -1, y = -1
# Frame 00196.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_197.jpg
# Nome frame formato per JSON: 00197.jpg
# Annotazioni trovate per 00197.jpg: x = -1, y = -1
# Frame 00197.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_198.jpg
# Nome frame formato per JSON: 00198.jpg
# Annotazioni trovate per 00198.jpg: x = -1, y = -1
# Frame 00198.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_199.jpg
# Nome frame formato per JSON: 00199.jpg
# Annotazioni trovate per 00199.jpg: x = -1, y = -1
# Frame 00199.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_200.jpg
# Nome frame formato per JSON: 00200.jpg
# Annotazioni trovate per 00200.jpg: x = -1, y = -1
# Frame 00200.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_201.jpg
# Nome frame formato per JSON: 00201.jpg
# Annotazioni trovate per 00201.jpg: x = -1, y = -1
# Frame 00201.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_202.jpg
# Nome frame formato per JSON: 00202.jpg
# Annotazioni trovate per 00202.jpg: x = -1, y = -1
# Frame 00202.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_203.jpg
# Nome frame formato per JSON: 00203.jpg
# Annotazioni trovate per 00203.jpg: x = -1, y = -1
# Frame 00203.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_204.jpg
# Nome frame formato per JSON: 00204.jpg
# Annotazioni trovate per 00204.jpg: x = -1, y = -1
# Frame 00204.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_205.jpg
# Nome frame formato per JSON: 00205.jpg
# Annotazioni trovate per 00205.jpg: x = -1, y = -1
# Frame 00205.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_206.jpg
# Nome frame formato per JSON: 00206.jpg
# Annotazioni trovate per 00206.jpg: x = -1, y = -1
# Frame 00206.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_207.jpg
# Nome frame formato per JSON: 00207.jpg
# Annotazioni trovate per 00207.jpg: x = -1, y = -1
# Frame 00207.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_208.jpg
# Nome frame formato per JSON: 00208.jpg
# Annotazioni trovate per 00208.jpg: x = -1, y = -1
# Frame 00208.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_209.jpg
# Nome frame formato per JSON: 00209.jpg
# Annotazioni trovate per 00209.jpg: x = -1, y = -1
# Frame 00209.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_210.jpg
# Nome frame formato per JSON: 00210.jpg
# Annotazioni trovate per 00210.jpg: x = -1, y = -1
# Frame 00210.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_211.jpg
# Nome frame formato per JSON: 00211.jpg
# Annotazioni trovate per 00211.jpg: x = -1, y = -1
# Frame 00211.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_212.jpg
# Nome frame formato per JSON: 00212.jpg
# Annotazioni trovate per 00212.jpg: x = -1, y = -1
# Frame 00212.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_213.jpg
# Nome frame formato per JSON: 00213.jpg
# Annotazioni trovate per 00213.jpg: x = -1, y = -1
# Frame 00213.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_214.jpg
# Nome frame formato per JSON: 00214.jpg
# Annotazioni trovate per 00214.jpg: x = -1, y = -1
# Frame 00214.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_215.jpg
# Nome frame formato per JSON: 00215.jpg
# Annotazioni trovate per 00215.jpg: x = -1, y = -1
# Frame 00215.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_216.jpg
# Nome frame formato per JSON: 00216.jpg
# Annotazioni trovate per 00216.jpg: x = -1, y = -1
# Frame 00216.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_217.jpg
# Nome frame formato per JSON: 00217.jpg
# Annotazioni trovate per 00217.jpg: x = -1, y = -1
# Frame 00217.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_218.jpg
# Nome frame formato per JSON: 00218.jpg
# Annotazioni trovate per 00218.jpg: x = -1, y = -1
# Frame 00218.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_219.jpg
# Nome frame formato per JSON: 00219.jpg
# Annotazioni trovate per 00219.jpg: x = -1, y = -1
# Frame 00219.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_220.jpg
# Nome frame formato per JSON: 00220.jpg
# Annotazioni trovate per 00220.jpg: x = -1, y = -1
# Frame 00220.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_221.jpg
# Nome frame formato per JSON: 00221.jpg
# Annotazioni trovate per 00221.jpg: x = -1, y = -1
# Frame 00221.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_222.jpg
# Nome frame formato per JSON: 00222.jpg
# Annotazioni trovate per 00222.jpg: x = -1, y = -1
# Frame 00222.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_223.jpg
# Nome frame formato per JSON: 00223.jpg
# Annotazioni trovate per 00223.jpg: x = -1, y = -1
# Frame 00223.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_224.jpg
# Nome frame formato per JSON: 00224.jpg
# Annotazioni trovate per 00224.jpg: x = -1, y = -1
# Frame 00224.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_225.jpg
# Nome frame formato per JSON: 00225.jpg
# Annotazioni trovate per 00225.jpg: x = -1, y = -1
# Frame 00225.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_226.jpg
# Nome frame formato per JSON: 00226.jpg
# Annotazioni trovate per 00226.jpg: x = -1, y = -1
# Frame 00226.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_227.jpg
# Nome frame formato per JSON: 00227.jpg
# Annotazioni trovate per 00227.jpg: x = -1, y = -1
# Frame 00227.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_228.jpg
# Nome frame formato per JSON: 00228.jpg
# Annotazioni trovate per 00228.jpg: x = -1, y = -1
# Frame 00228.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_229.jpg
# Nome frame formato per JSON: 00229.jpg
# Annotazioni trovate per 00229.jpg: x = -1, y = -1
# Frame 00229.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_230.jpg
# Nome frame formato per JSON: 00230.jpg
# Annotazioni trovate per 00230.jpg: x = -1, y = -1
# Frame 00230.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_231.jpg
# Nome frame formato per JSON: 00231.jpg
# Annotazioni trovate per 00231.jpg: x = -1, y = -1
# Frame 00231.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_232.jpg
# ...
# Annotazioni trovate per 02924.jpg: x = -1, y = -1
# Frame 02924.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2925.jpg
# Nome frame formato per JSON: 02925.jpg
# Annotazioni trovate per 02925.jpg: x = -1, y = -1
# Frame 02925.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2926.jpg
# Nome frame formato per JSON: 02926.jpg
# Annotazioni trovate per 02926.jpg: x = -1, y = -1
# Frame 02926.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2927.jpg
# Nome frame formato per JSON: 02927.jpg
# Annotazioni trovate per 02927.jpg: x = -1, y = -1
# Frame 02927.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2928.jpg
# Nome frame formato per JSON: 02928.jpg
# Annotazioni trovate per 02928.jpg: x = -1, y = -1
# Frame 02928.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2929.jpg
# Nome frame formato per JSON: 02929.jpg
# Annotazioni trovate per 02929.jpg: x = -1, y = -1
# Frame 02929.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2930.jpg
# Nome frame formato per JSON: 02930.jpg
# Annotazioni trovate per 02930.jpg: x = -1, y = -1
# Frame 02930.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2931.jpg
# Nome frame formato per JSON: 02931.jpg
# Annotazioni trovate per 02931.jpg: x = -1, y = -1
# Frame 02931.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2932.jpg
# Nome frame formato per JSON: 02932.jpg
# Annotazioni trovate per 02932.jpg: x = -1, y = -1
# Frame 02932.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2933.jpg
# Nome frame formato per JSON: 02933.jpg
# Annotazioni trovate per 02933.jpg: x = -1, y = -1
# Frame 02933.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2934.jpg
# Nome frame formato per JSON: 02934.jpg
# Annotazioni trovate per 02934.jpg: x = -1, y = -1
# Frame 02934.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2935.jpg
# Nome frame formato per JSON: 02935.jpg
# Annotazioni trovate per 02935.jpg: x = -1, y = -1
# Frame 02935.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2936.jpg
# Nome frame formato per JSON: 02936.jpg
# Annotazioni trovate per 02936.jpg: x = -1, y = -1
# Frame 02936.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2937.jpg
# Nome frame formato per JSON: 02937.jpg
# Annotazioni trovate per 02937.jpg: x = -1, y = -1
# Frame 02937.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2938.jpg
# Nome frame formato per JSON: 02938.jpg
# Annotazioni trovate per 02938.jpg: x = -1, y = -1
# Frame 02938.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2939.jpg
# Nome frame formato per JSON: 02939.jpg
# Annotazioni trovate per 02939.jpg: x = -1, y = -1
# Frame 02939.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2940.jpg
# Nome frame formato per JSON: 02940.jpg
# Annotazioni trovate per 02940.jpg: x = -1, y = -1
# Frame 02940.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2941.jpg
# Nome frame formato per JSON: 02941.jpg
# Annotazioni trovate per 02941.jpg: x = -1, y = -1
# Frame 02941.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2942.jpg
# Nome frame formato per JSON: 02942.jpg
# Annotazioni trovate per 02942.jpg: x = -1, y = -1
# Frame 02942.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2943.jpg
# Nome frame formato per JSON: 02943.jpg
# Annotazioni trovate per 02943.jpg: x = -1, y = -1
# Frame 02943.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2944.jpg
# Nome frame formato per JSON: 02944.jpg
# Annotazioni trovate per 02944.jpg: x = -1, y = -1
# Frame 02944.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2945.jpg
# Nome frame formato per JSON: 02945.jpg
# Annotazioni trovate per 02945.jpg: x = -1, y = -1
# Frame 02945.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2946.jpg
# Nome frame formato per JSON: 02946.jpg
# Annotazioni trovate per 02946.jpg: x = -1, y = -1
# Frame 02946.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2947.jpg
# Nome frame formato per JSON: 02947.jpg
# Annotazioni trovate per 02947.jpg: x = -1, y = -1
# Frame 02947.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2948.jpg
# Nome frame formato per JSON: 02948.jpg
# Annotazioni trovate per 02948.jpg: x = -1, y = -1
# Frame 02948.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2949.jpg
# Nome frame formato per JSON: 02949.jpg
# Annotazioni trovate per 02949.jpg: x = -1, y = -1
# Frame 02949.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2950.jpg
# Nome frame formato per JSON: 02950.jpg
# Annotazioni trovate per 02950.jpg: x = -1, y = -1
# Frame 02950.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2951.jpg
# Nome frame formato per JSON: 02951.jpg
# Annotazioni trovate per 02951.jpg: x = -1, y = -1
# Frame 02951.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2952.jpg
# Nome frame formato per JSON: 02952.jpg
# Annotazioni trovate per 02952.jpg: x = -1, y = -1
# Frame 02952.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2953.jpg
# Nome frame formato per JSON: 02953.jpg
# Annotazioni trovate per 02953.jpg: x = -1, y = -1
# Frame 02953.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2954.jpg
# Nome frame formato per JSON: 02954.jpg
# Annotazioni trovate per 02954.jpg: x = -1, y = -1
# Frame 02954.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2955.jpg
# Nome frame formato per JSON: 02955.jpg
# Annotazioni trovate per 02955.jpg: x = -1, y = -1
# Frame 02955.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2956.jpg
# Nome frame formato per JSON: 02956.jpg
# Annotazioni trovate per 02956.jpg: x = 1907.0638427734375, y = 213.2087631225586
# Aggiungendo cerchio al frame 02956.jpg alle coordinate (1907.0638427734375, 213.2087631225586)
# Processando il frame: frame_2957.jpg
# Nome frame formato per JSON: 02957.jpg
# Annotazioni trovate per 02957.jpg: x = 1899.9094848632812, y = 219.08098220825195
# Aggiungendo cerchio al frame 02957.jpg alle coordinate (1899.9094848632812, 219.08098220825195)
# Processando il frame: frame_2958.jpg
# Nome frame formato per JSON: 02958.jpg
# Annotazioni trovate per 02958.jpg: x = 1892.755126953125, y = 224.9532012939453
# Aggiungendo cerchio al frame 02958.jpg alle coordinate (1892.755126953125, 224.9532012939453)
# Processando il frame: frame_2959.jpg
# Nome frame formato per JSON: 02959.jpg
# Annotazioni trovate per 02959.jpg: x = 1884.34716796875, y = 232.26882934570312
# Aggiungendo cerchio al frame 02959.jpg alle coordinate (1884.34716796875, 232.26882934570312)
# Processando il frame: frame_2960.jpg
# Nome frame formato per JSON: 02960.jpg
# Annotazioni trovate per 02960.jpg: x = 1875.939208984375, y = 239.58445739746094
# Aggiungendo cerchio al frame 02960.jpg alle coordinate (1875.939208984375, 239.58445739746094)
# Processando il frame: frame_2961.jpg
# Nome frame formato per JSON: 02961.jpg
# Annotazioni trovate per 02961.jpg: x = 1867.53125, y = 246.90008544921875
# Aggiungendo cerchio al frame 02961.jpg alle coordinate (1867.53125, 246.90008544921875)
# Processando il frame: frame_2962.jpg
# Nome frame formato per JSON: 02962.jpg
# Annotazioni trovate per 02962.jpg: x = 1859.0643920898438, y = 255.84075164794922
# Aggiungendo cerchio al frame 02962.jpg alle coordinate (1859.0643920898438, 255.84075164794922)
# Processando il frame: frame_2963.jpg
# Nome frame formato per JSON: 02963.jpg
# Annotazioni trovate per 02963.jpg: x = 1854.5245971679688, y = 264.5622329711914
# Aggiungendo cerchio al frame 02963.jpg alle coordinate (1854.5245971679688, 264.5622329711914)
# Processando il frame: frame_2964.jpg
# Nome frame formato per JSON: 02964.jpg
# Annotazioni trovate per 02964.jpg: x = 1870.7093505859375, y = 253.06792449951172
# Aggiungendo cerchio al frame 02964.jpg alle coordinate (1870.7093505859375, 253.06792449951172)
# Processando il frame: frame_2965.jpg
# Nome frame formato per JSON: 02965.jpg
# Annotazioni trovate per 02965.jpg: x = 1888.1471557617188, y = 241.37876892089844
# Aggiungendo cerchio al frame 02965.jpg alle coordinate (1888.1471557617188, 241.37876892089844)
# Processando il frame: frame_2966.jpg
# Nome frame formato per JSON: 02966.jpg
# Annotazioni trovate per 02966.jpg: x = 1905.3203125, y = 230.1302261352539
# Aggiungendo cerchio al frame 02966.jpg alle coordinate (1905.3203125, 230.1302261352539)
# Processando il frame: frame_2967.jpg
# Nome frame formato per JSON: 02967.jpg
# Annotazioni trovate per 02967.jpg: x = -1, y = -1
# Frame 02967.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2968.jpg
# Nome frame formato per JSON: 02968.jpg
# Annotazioni trovate per 02968.jpg: x = -1, y = -1
# Frame 02968.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2969.jpg
# Nome frame formato per JSON: 02969.jpg
# Annotazioni trovate per 02969.jpg: x = -1, y = -1
# Frame 02969.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2970.jpg
# Nome frame formato per JSON: 02970.jpg
# Annotazioni trovate per 02970.jpg: x = -1, y = -1
# Frame 02970.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2971.jpg
# Nome frame formato per JSON: 02971.jpg
# Annotazioni trovate per 02971.jpg: x = -1, y = -1
# Frame 02971.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2972.jpg
# Nome frame formato per JSON: 02972.jpg
# Annotazioni trovate per 02972.jpg: x = -1, y = -1
# Frame 02972.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2973.jpg
# Nome frame formato per JSON: 02973.jpg
# Annotazioni trovate per 02973.jpg: x = -1, y = -1
# Frame 02973.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2974.jpg
# Nome frame formato per JSON: 02974.jpg
# Annotazioni trovate per 02974.jpg: x = -1, y = -1
# Frame 02974.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2975.jpg
# Nome frame formato per JSON: 02975.jpg
# Annotazioni trovate per 02975.jpg: x = -1, y = -1
# Frame 02975.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2976.jpg
# Nome frame formato per JSON: 02976.jpg
# Annotazioni trovate per 02976.jpg: x = -1, y = -1
# Frame 02976.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2977.jpg
# Nome frame formato per JSON: 02977.jpg
# Annotazioni trovate per 02977.jpg: x = -1, y = -1
# Frame 02977.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2978.jpg
# Nome frame formato per JSON: 02978.jpg
# Annotazioni trovate per 02978.jpg: x = -1, y = -1
# Frame 02978.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2979.jpg
# Nome frame formato per JSON: 02979.jpg
# Annotazioni trovate per 02979.jpg: x = -1, y = -1
# Frame 02979.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2980.jpg
# Nome frame formato per JSON: 02980.jpg
# Annotazioni trovate per 02980.jpg: x = -1, y = -1
# Frame 02980.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2981.jpg
# Nome frame formato per JSON: 02981.jpg
# Annotazioni trovate per 02981.jpg: x = -1, y = -1
# Frame 02981.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2982.jpg
# Nome frame formato per JSON: 02982.jpg
# Annotazioni trovate per 02982.jpg: x = -1, y = -1
# Frame 02982.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2983.jpg
# Nome frame formato per JSON: 02983.jpg
# Annotazioni trovate per 02983.jpg: x = -1, y = -1
# Frame 02983.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2984.jpg
# Nome frame formato per JSON: 02984.jpg
# Annotazioni trovate per 02984.jpg: x = -1, y = -1
# Frame 02984.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2985.jpg
# Nome frame formato per JSON: 02985.jpg
# Annotazioni trovate per 02985.jpg: x = -1, y = -1
# Frame 02985.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2986.jpg
# Nome frame formato per JSON: 02986.jpg
# Annotazioni trovate per 02986.jpg: x = -1, y = -1
# Frame 02986.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2987.jpg
# Nome frame formato per JSON: 02987.jpg
# Annotazioni trovate per 02987.jpg: x = -1, y = -1
# Frame 02987.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2988.jpg
# Nome frame formato per JSON: 02988.jpg
# Annotazioni trovate per 02988.jpg: x = -1, y = -1
# Frame 02988.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2989.jpg
# Nome frame formato per JSON: 02989.jpg
# Annotazioni trovate per 02989.jpg: x = -1, y = -1
# Frame 02989.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2990.jpg
# Nome frame formato per JSON: 02990.jpg
# Annotazioni trovate per 02990.jpg: x = -1, y = -1
# Frame 02990.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2991.jpg
# Nome frame formato per JSON: 02991.jpg
# Annotazioni trovate per 02991.jpg: x = -1, y = -1
# Frame 02991.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2992.jpg
# Nome frame formato per JSON: 02992.jpg
# Annotazioni trovate per 02992.jpg: x = -1, y = -1
# Frame 02992.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2993.jpg
# Nome frame formato per JSON: 02993.jpg
# Annotazioni trovate per 02993.jpg: x = -1, y = -1
# Frame 02993.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2994.jpg
# Nome frame formato per JSON: 02994.jpg
# Annotazioni trovate per 02994.jpg: x = -1, y = -1
# Frame 02994.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2995.jpg
# Nome frame formato per JSON: 02995.jpg
# Annotazioni trovate per 02995.jpg: x = -1, y = -1
# Frame 02995.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2996.jpg
# Nome frame formato per JSON: 02996.jpg
# Annotazioni trovate per 02996.jpg: x = -1, y = -1
# Frame 02996.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2997.jpg
# Nome frame formato per JSON: 02997.jpg
# Annotazioni trovate per 02997.jpg: x = -1, y = -1
# Frame 02997.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2998.jpg
# Nome frame formato per JSON: 02998.jpg
# Annotazioni trovate per 02998.jpg: x = -1, y = -1
# Frame 02998.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Video salvato come: /kaggle/working/video_5.avi

# %%
cartella_immagini = '/kaggle/input/computer-vision-futbal/dataset/dataset/test/ID-6'
file_json = f"{PATH_OUT}/ID_6_256942_252050.json"
output_video = f"{PATH_OUT}/video_6.avi"

crea_video_con_annotazioni(cartella_immagini, file_json, output_video)
# Out:
# Caricamento del file JSON: /kaggle/working/ID_6_256942_252050.json
# Annotazioni caricate. Numero di frame nel JSON: 3000
# Numero di immagini trovate nella cartella: 3000
# Dimensioni del frame: larghezza = 1920, altezza = 1080
# Video writer creato. Output: /kaggle/working/video_6.avi
# Processando il frame: frame_0.jpg
# Nome frame formato per JSON: 00000.jpg
# Annotazioni trovate per 00000.jpg: x = -1, y = -1
# Frame 00000.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_1.jpg
# Nome frame formato per JSON: 00001.jpg
# Annotazioni trovate per 00001.jpg: x = -1, y = -1
# Frame 00001.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2.jpg
# Nome frame formato per JSON: 00002.jpg
# Annotazioni trovate per 00002.jpg: x = -1, y = -1
# Frame 00002.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_3.jpg
# Nome frame formato per JSON: 00003.jpg
# Annotazioni trovate per 00003.jpg: x = -1, y = -1
# Frame 00003.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_4.jpg
# Nome frame formato per JSON: 00004.jpg
# Annotazioni trovate per 00004.jpg: x = -1, y = -1
# Frame 00004.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_5.jpg
# Nome frame formato per JSON: 00005.jpg
# Annotazioni trovate per 00005.jpg: x = -1, y = -1
# Frame 00005.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_6.jpg
# Nome frame formato per JSON: 00006.jpg
# Annotazioni trovate per 00006.jpg: x = -1, y = -1
# Frame 00006.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_7.jpg
# Nome frame formato per JSON: 00007.jpg
# Annotazioni trovate per 00007.jpg: x = -1, y = -1
# Frame 00007.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_8.jpg
# Nome frame formato per JSON: 00008.jpg
# Annotazioni trovate per 00008.jpg: x = -1, y = -1
# Frame 00008.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_9.jpg
# Nome frame formato per JSON: 00009.jpg
# Annotazioni trovate per 00009.jpg: x = -1, y = -1
# Frame 00009.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_10.jpg
# Nome frame formato per JSON: 00010.jpg
# Annotazioni trovate per 00010.jpg: x = -1, y = -1
# Frame 00010.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_11.jpg
# Nome frame formato per JSON: 00011.jpg
# Annotazioni trovate per 00011.jpg: x = -1, y = -1
# Frame 00011.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_12.jpg
# Nome frame formato per JSON: 00012.jpg
# Annotazioni trovate per 00012.jpg: x = -1, y = -1
# Frame 00012.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_13.jpg
# Nome frame formato per JSON: 00013.jpg
# Annotazioni trovate per 00013.jpg: x = -1, y = -1
# Frame 00013.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_14.jpg
# Nome frame formato per JSON: 00014.jpg
# Annotazioni trovate per 00014.jpg: x = -1, y = -1
# Frame 00014.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_15.jpg
# Nome frame formato per JSON: 00015.jpg
# Annotazioni trovate per 00015.jpg: x = -1, y = -1
# Frame 00015.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_16.jpg
# Nome frame formato per JSON: 00016.jpg
# Annotazioni trovate per 00016.jpg: x = -1, y = -1
# Frame 00016.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_17.jpg
# Nome frame formato per JSON: 00017.jpg
# Annotazioni trovate per 00017.jpg: x = -1, y = -1
# Frame 00017.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_18.jpg
# Nome frame formato per JSON: 00018.jpg
# Annotazioni trovate per 00018.jpg: x = -1, y = -1
# Frame 00018.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_19.jpg
# Nome frame formato per JSON: 00019.jpg
# Annotazioni trovate per 00019.jpg: x = -1, y = -1
# Frame 00019.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_20.jpg
# Nome frame formato per JSON: 00020.jpg
# Annotazioni trovate per 00020.jpg: x = -1, y = -1
# Frame 00020.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_21.jpg
# Nome frame formato per JSON: 00021.jpg
# Annotazioni trovate per 00021.jpg: x = -1, y = -1
# Frame 00021.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_22.jpg
# Nome frame formato per JSON: 00022.jpg
# Annotazioni trovate per 00022.jpg: x = -1, y = -1
# Frame 00022.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_23.jpg
# Nome frame formato per JSON: 00023.jpg
# Annotazioni trovate per 00023.jpg: x = -1, y = -1
# Frame 00023.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_24.jpg
# Nome frame formato per JSON: 00024.jpg
# Annotazioni trovate per 00024.jpg: x = -1, y = -1
# Frame 00024.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_25.jpg
# Nome frame formato per JSON: 00025.jpg
# Annotazioni trovate per 00025.jpg: x = -1, y = -1
# Frame 00025.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_26.jpg
# Nome frame formato per JSON: 00026.jpg
# Annotazioni trovate per 00026.jpg: x = -1, y = -1
# Frame 00026.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_27.jpg
# Nome frame formato per JSON: 00027.jpg
# Annotazioni trovate per 00027.jpg: x = -1, y = -1
# Frame 00027.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_28.jpg
# Nome frame formato per JSON: 00028.jpg
# Annotazioni trovate per 00028.jpg: x = -1, y = -1
# Frame 00028.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_29.jpg
# Nome frame formato per JSON: 00029.jpg
# Annotazioni trovate per 00029.jpg: x = -1, y = -1
# Frame 00029.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_30.jpg
# Nome frame formato per JSON: 00030.jpg
# Annotazioni trovate per 00030.jpg: x = -1, y = -1
# Frame 00030.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_31.jpg
# Nome frame formato per JSON: 00031.jpg
# Annotazioni trovate per 00031.jpg: x = -1, y = -1
# Frame 00031.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_32.jpg
# Nome frame formato per JSON: 00032.jpg
# Annotazioni trovate per 00032.jpg: x = -1, y = -1
# Frame 00032.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_33.jpg
# Nome frame formato per JSON: 00033.jpg
# Annotazioni trovate per 00033.jpg: x = -1, y = -1
# Frame 00033.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_34.jpg
# Nome frame formato per JSON: 00034.jpg
# Annotazioni trovate per 00034.jpg: x = -1, y = -1
# Frame 00034.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_35.jpg
# Nome frame formato per JSON: 00035.jpg
# Annotazioni trovate per 00035.jpg: x = -1, y = -1
# Frame 00035.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_36.jpg
# Nome frame formato per JSON: 00036.jpg
# Annotazioni trovate per 00036.jpg: x = -1, y = -1
# Frame 00036.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_37.jpg
# Nome frame formato per JSON: 00037.jpg
# Annotazioni trovate per 00037.jpg: x = -1, y = -1
# Frame 00037.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_38.jpg
# Nome frame formato per JSON: 00038.jpg
# Annotazioni trovate per 00038.jpg: x = -1, y = -1
# Frame 00038.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_39.jpg
# Nome frame formato per JSON: 00039.jpg
# Annotazioni trovate per 00039.jpg: x = -1, y = -1
# Frame 00039.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_40.jpg
# Nome frame formato per JSON: 00040.jpg
# Annotazioni trovate per 00040.jpg: x = -1, y = -1
# Frame 00040.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_41.jpg
# Nome frame formato per JSON: 00041.jpg
# Annotazioni trovate per 00041.jpg: x = -1, y = -1
# Frame 00041.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_42.jpg
# Nome frame formato per JSON: 00042.jpg
# Annotazioni trovate per 00042.jpg: x = -1, y = -1
# Frame 00042.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_43.jpg
# Nome frame formato per JSON: 00043.jpg
# Annotazioni trovate per 00043.jpg: x = -1, y = -1
# Frame 00043.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_44.jpg
# Nome frame formato per JSON: 00044.jpg
# Annotazioni trovate per 00044.jpg: x = -1, y = -1
# Frame 00044.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_45.jpg
# Nome frame formato per JSON: 00045.jpg
# Annotazioni trovate per 00045.jpg: x = -1, y = -1
# Frame 00045.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_46.jpg
# Nome frame formato per JSON: 00046.jpg
# Annotazioni trovate per 00046.jpg: x = -1, y = -1
# Frame 00046.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_47.jpg
# Nome frame formato per JSON: 00047.jpg
# Annotazioni trovate per 00047.jpg: x = -1, y = -1
# Frame 00047.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_48.jpg
# Nome frame formato per JSON: 00048.jpg
# Annotazioni trovate per 00048.jpg: x = -1, y = -1
# Frame 00048.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_49.jpg
# Nome frame formato per JSON: 00049.jpg
# Annotazioni trovate per 00049.jpg: x = -1, y = -1
# Frame 00049.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_50.jpg
# Nome frame formato per JSON: 00050.jpg
# Annotazioni trovate per 00050.jpg: x = -1, y = -1
# Frame 00050.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_51.jpg
# Nome frame formato per JSON: 00051.jpg
# Annotazioni trovate per 00051.jpg: x = -1, y = -1
# Frame 00051.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_52.jpg
# Nome frame formato per JSON: 00052.jpg
# Annotazioni trovate per 00052.jpg: x = -1, y = -1
# Frame 00052.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_53.jpg
# Nome frame formato per JSON: 00053.jpg
# Annotazioni trovate per 00053.jpg: x = -1, y = -1
# Frame 00053.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_54.jpg
# Nome frame formato per JSON: 00054.jpg
# Annotazioni trovate per 00054.jpg: x = -1, y = -1
# Frame 00054.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_55.jpg
# Nome frame formato per JSON: 00055.jpg
# Annotazioni trovate per 00055.jpg: x = -1, y = -1
# Frame 00055.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_56.jpg
# Nome frame formato per JSON: 00056.jpg
# Annotazioni trovate per 00056.jpg: x = -1, y = -1
# Frame 00056.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_57.jpg
# Nome frame formato per JSON: 00057.jpg
# Annotazioni trovate per 00057.jpg: x = -1, y = -1
# Frame 00057.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_58.jpg
# Nome frame formato per JSON: 00058.jpg
# Annotazioni trovate per 00058.jpg: x = -1, y = -1
# Frame 00058.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_59.jpg
# Nome frame formato per JSON: 00059.jpg
# Annotazioni trovate per 00059.jpg: x = -1, y = -1
# Frame 00059.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_60.jpg
# Nome frame formato per JSON: 00060.jpg
# Annotazioni trovate per 00060.jpg: x = -1, y = -1
# Frame 00060.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_61.jpg
# Nome frame formato per JSON: 00061.jpg
# Annotazioni trovate per 00061.jpg: x = -1, y = -1
# Frame 00061.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_62.jpg
# Nome frame formato per JSON: 00062.jpg
# Annotazioni trovate per 00062.jpg: x = -1, y = -1
# Frame 00062.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_63.jpg
# Nome frame formato per JSON: 00063.jpg
# Annotazioni trovate per 00063.jpg: x = -1, y = -1
# Frame 00063.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_64.jpg
# Nome frame formato per JSON: 00064.jpg
# Annotazioni trovate per 00064.jpg: x = -1, y = -1
# Frame 00064.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_65.jpg
# Nome frame formato per JSON: 00065.jpg
# Annotazioni trovate per 00065.jpg: x = -1, y = -1
# Frame 00065.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_66.jpg
# Nome frame formato per JSON: 00066.jpg
# Annotazioni trovate per 00066.jpg: x = -1, y = -1
# Frame 00066.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_67.jpg
# Nome frame formato per JSON: 00067.jpg
# Annotazioni trovate per 00067.jpg: x = -1, y = -1
# Frame 00067.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_68.jpg
# Nome frame formato per JSON: 00068.jpg
# Annotazioni trovate per 00068.jpg: x = -1, y = -1
# Frame 00068.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_69.jpg
# Nome frame formato per JSON: 00069.jpg
# Annotazioni trovate per 00069.jpg: x = -1, y = -1
# Frame 00069.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_70.jpg
# Nome frame formato per JSON: 00070.jpg
# Annotazioni trovate per 00070.jpg: x = -1, y = -1
# Frame 00070.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_71.jpg
# Nome frame formato per JSON: 00071.jpg
# Annotazioni trovate per 00071.jpg: x = -1, y = -1
# Frame 00071.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_72.jpg
# Nome frame formato per JSON: 00072.jpg
# Annotazioni trovate per 00072.jpg: x = -1, y = -1
# Frame 00072.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_73.jpg
# Nome frame formato per JSON: 00073.jpg
# Annotazioni trovate per 00073.jpg: x = -1, y = -1
# Frame 00073.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_74.jpg
# Nome frame formato per JSON: 00074.jpg
# Annotazioni trovate per 00074.jpg: x = -1, y = -1
# Frame 00074.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_75.jpg
# Nome frame formato per JSON: 00075.jpg
# Annotazioni trovate per 00075.jpg: x = -1, y = -1
# Frame 00075.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_76.jpg
# Nome frame formato per JSON: 00076.jpg
# Annotazioni trovate per 00076.jpg: x = -1, y = -1
# Frame 00076.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_77.jpg
# Nome frame formato per JSON: 00077.jpg
# Annotazioni trovate per 00077.jpg: x = -1, y = -1
# Frame 00077.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_78.jpg
# Nome frame formato per JSON: 00078.jpg
# Annotazioni trovate per 00078.jpg: x = -1, y = -1
# Frame 00078.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_79.jpg
# Nome frame formato per JSON: 00079.jpg
# Annotazioni trovate per 00079.jpg: x = -1, y = -1
# Frame 00079.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_80.jpg
# Nome frame formato per JSON: 00080.jpg
# Annotazioni trovate per 00080.jpg: x = -1, y = -1
# Frame 00080.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_81.jpg
# Nome frame formato per JSON: 00081.jpg
# Annotazioni trovate per 00081.jpg: x = -1, y = -1
# Frame 00081.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_82.jpg
# Nome frame formato per JSON: 00082.jpg
# Annotazioni trovate per 00082.jpg: x = -1, y = -1
# Frame 00082.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_83.jpg
# Nome frame formato per JSON: 00083.jpg
# Annotazioni trovate per 00083.jpg: x = -1, y = -1
# Frame 00083.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_84.jpg
# Nome frame formato per JSON: 00084.jpg
# Annotazioni trovate per 00084.jpg: x = -1, y = -1
# Frame 00084.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_85.jpg
# Nome frame formato per JSON: 00085.jpg
# Annotazioni trovate per 00085.jpg: x = -1, y = -1
# Frame 00085.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_86.jpg
# Nome frame formato per JSON: 00086.jpg
# Annotazioni trovate per 00086.jpg: x = -1, y = -1
# Frame 00086.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_87.jpg
# Nome frame formato per JSON: 00087.jpg
# Annotazioni trovate per 00087.jpg: x = -1, y = -1
# Frame 00087.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_88.jpg
# Nome frame formato per JSON: 00088.jpg
# Annotazioni trovate per 00088.jpg: x = -1, y = -1
# Frame 00088.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_89.jpg
# Nome frame formato per JSON: 00089.jpg
# Annotazioni trovate per 00089.jpg: x = -1, y = -1
# Frame 00089.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_90.jpg
# Nome frame formato per JSON: 00090.jpg
# Annotazioni trovate per 00090.jpg: x = -1, y = -1
# Frame 00090.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_91.jpg
# Nome frame formato per JSON: 00091.jpg
# Annotazioni trovate per 00091.jpg: x = -1, y = -1
# Frame 00091.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_92.jpg
# Nome frame formato per JSON: 00092.jpg
# Annotazioni trovate per 00092.jpg: x = -1, y = -1
# Frame 00092.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_93.jpg
# Nome frame formato per JSON: 00093.jpg
# Annotazioni trovate per 00093.jpg: x = -1, y = -1
# Frame 00093.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_94.jpg
# Nome frame formato per JSON: 00094.jpg
# Annotazioni trovate per 00094.jpg: x = -1, y = -1
# Frame 00094.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_95.jpg
# Nome frame formato per JSON: 00095.jpg
# Annotazioni trovate per 00095.jpg: x = -1, y = -1
# Frame 00095.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_96.jpg
# Nome frame formato per JSON: 00096.jpg
# Annotazioni trovate per 00096.jpg: x = -1, y = -1
# Frame 00096.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_97.jpg
# Nome frame formato per JSON: 00097.jpg
# Annotazioni trovate per 00097.jpg: x = -1, y = -1
# Frame 00097.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_98.jpg
# Nome frame formato per JSON: 00098.jpg
# Annotazioni trovate per 00098.jpg: x = -1, y = -1
# Frame 00098.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_99.jpg
# Nome frame formato per JSON: 00099.jpg
# Annotazioni trovate per 00099.jpg: x = -1, y = -1
# Frame 00099.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_100.jpg
# Nome frame formato per JSON: 00100.jpg
# Annotazioni trovate per 00100.jpg: x = -1, y = -1
# Frame 00100.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_101.jpg
# Nome frame formato per JSON: 00101.jpg
# Annotazioni trovate per 00101.jpg: x = -1, y = -1
# Frame 00101.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_102.jpg
# Nome frame formato per JSON: 00102.jpg
# Annotazioni trovate per 00102.jpg: x = -1, y = -1
# Frame 00102.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_103.jpg
# Nome frame formato per JSON: 00103.jpg
# Annotazioni trovate per 00103.jpg: x = -1, y = -1
# Frame 00103.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_104.jpg
# Nome frame formato per JSON: 00104.jpg
# Annotazioni trovate per 00104.jpg: x = -1, y = -1
# Frame 00104.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_105.jpg
# Nome frame formato per JSON: 00105.jpg
# Annotazioni trovate per 00105.jpg: x = -1, y = -1
# Frame 00105.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_106.jpg
# Nome frame formato per JSON: 00106.jpg
# Annotazioni trovate per 00106.jpg: x = -1, y = -1
# Frame 00106.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_107.jpg
# Nome frame formato per JSON: 00107.jpg
# Annotazioni trovate per 00107.jpg: x = -1, y = -1
# Frame 00107.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_108.jpg
# Nome frame formato per JSON: 00108.jpg
# Annotazioni trovate per 00108.jpg: x = -1, y = -1
# Frame 00108.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_109.jpg
# Nome frame formato per JSON: 00109.jpg
# Annotazioni trovate per 00109.jpg: x = -1, y = -1
# Frame 00109.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_110.jpg
# Nome frame formato per JSON: 00110.jpg
# Annotazioni trovate per 00110.jpg: x = -1, y = -1
# Frame 00110.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_111.jpg
# Nome frame formato per JSON: 00111.jpg
# Annotazioni trovate per 00111.jpg: x = -1, y = -1
# Frame 00111.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_112.jpg
# Nome frame formato per JSON: 00112.jpg
# Annotazioni trovate per 00112.jpg: x = -1, y = -1
# Frame 00112.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_113.jpg
# Nome frame formato per JSON: 00113.jpg
# Annotazioni trovate per 00113.jpg: x = -1, y = -1
# Frame 00113.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_114.jpg
# Nome frame formato per JSON: 00114.jpg
# Annotazioni trovate per 00114.jpg: x = -1, y = -1
# Frame 00114.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_115.jpg
# Nome frame formato per JSON: 00115.jpg
# Annotazioni trovate per 00115.jpg: x = -1, y = -1
# Frame 00115.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_116.jpg
# Nome frame formato per JSON: 00116.jpg
# Annotazioni trovate per 00116.jpg: x = -1, y = -1
# Frame 00116.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_117.jpg
# Nome frame formato per JSON: 00117.jpg
# Annotazioni trovate per 00117.jpg: x = -1, y = -1
# Frame 00117.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_118.jpg
# Nome frame formato per JSON: 00118.jpg
# Annotazioni trovate per 00118.jpg: x = -1, y = -1
# Frame 00118.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_119.jpg
# Nome frame formato per JSON: 00119.jpg
# Annotazioni trovate per 00119.jpg: x = -1, y = -1
# Frame 00119.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_120.jpg
# Nome frame formato per JSON: 00120.jpg
# Annotazioni trovate per 00120.jpg: x = -1, y = -1
# Frame 00120.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_121.jpg
# Nome frame formato per JSON: 00121.jpg
# Annotazioni trovate per 00121.jpg: x = -1, y = -1
# Frame 00121.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_122.jpg
# Nome frame formato per JSON: 00122.jpg
# Annotazioni trovate per 00122.jpg: x = -1, y = -1
# Frame 00122.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_123.jpg
# Nome frame formato per JSON: 00123.jpg
# Annotazioni trovate per 00123.jpg: x = -1, y = -1
# Frame 00123.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_124.jpg
# Nome frame formato per JSON: 00124.jpg
# Annotazioni trovate per 00124.jpg: x = -1, y = -1
# Frame 00124.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_125.jpg
# Nome frame formato per JSON: 00125.jpg
# Annotazioni trovate per 00125.jpg: x = -1, y = -1
# Frame 00125.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_126.jpg
# Nome frame formato per JSON: 00126.jpg
# Annotazioni trovate per 00126.jpg: x = -1, y = -1
# Frame 00126.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_127.jpg
# Nome frame formato per JSON: 00127.jpg
# Annotazioni trovate per 00127.jpg: x = -1, y = -1
# Frame 00127.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_128.jpg
# Nome frame formato per JSON: 00128.jpg
# Annotazioni trovate per 00128.jpg: x = -1, y = -1
# Frame 00128.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_129.jpg
# Nome frame formato per JSON: 00129.jpg
# Annotazioni trovate per 00129.jpg: x = -1, y = -1
# Frame 00129.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_130.jpg
# Nome frame formato per JSON: 00130.jpg
# Annotazioni trovate per 00130.jpg: x = -1, y = -1
# Frame 00130.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_131.jpg
# Nome frame formato per JSON: 00131.jpg
# Annotazioni trovate per 00131.jpg: x = -1, y = -1
# Frame 00131.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_132.jpg
# Nome frame formato per JSON: 00132.jpg
# Annotazioni trovate per 00132.jpg: x = -1, y = -1
# Frame 00132.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_133.jpg
# Nome frame formato per JSON: 00133.jpg
# Annotazioni trovate per 00133.jpg: x = -1, y = -1
# Frame 00133.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_134.jpg
# Nome frame formato per JSON: 00134.jpg
# Annotazioni trovate per 00134.jpg: x = -1, y = -1
# Frame 00134.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_135.jpg
# Nome frame formato per JSON: 00135.jpg
# Annotazioni trovate per 00135.jpg: x = -1, y = -1
# Frame 00135.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_136.jpg
# Nome frame formato per JSON: 00136.jpg
# Annotazioni trovate per 00136.jpg: x = -1, y = -1
# Frame 00136.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_137.jpg
# Nome frame formato per JSON: 00137.jpg
# Annotazioni trovate per 00137.jpg: x = -1, y = -1
# Frame 00137.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_138.jpg
# Nome frame formato per JSON: 00138.jpg
# Annotazioni trovate per 00138.jpg: x = -1, y = -1
# Frame 00138.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_139.jpg
# Nome frame formato per JSON: 00139.jpg
# Annotazioni trovate per 00139.jpg: x = -1, y = -1
# Frame 00139.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_140.jpg
# Nome frame formato per JSON: 00140.jpg
# Annotazioni trovate per 00140.jpg: x = -1, y = -1
# Frame 00140.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_141.jpg
# Nome frame formato per JSON: 00141.jpg
# Annotazioni trovate per 00141.jpg: x = -1, y = -1
# Frame 00141.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_142.jpg
# Nome frame formato per JSON: 00142.jpg
# Annotazioni trovate per 00142.jpg: x = -1, y = -1
# Frame 00142.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_143.jpg
# Nome frame formato per JSON: 00143.jpg
# Annotazioni trovate per 00143.jpg: x = -1, y = -1
# Frame 00143.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_144.jpg
# Nome frame formato per JSON: 00144.jpg
# Annotazioni trovate per 00144.jpg: x = -1, y = -1
# Frame 00144.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_145.jpg
# Nome frame formato per JSON: 00145.jpg
# Annotazioni trovate per 00145.jpg: x = -1, y = -1
# Frame 00145.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_146.jpg
# Nome frame formato per JSON: 00146.jpg
# Annotazioni trovate per 00146.jpg: x = -1, y = -1
# Frame 00146.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_147.jpg
# Nome frame formato per JSON: 00147.jpg
# Annotazioni trovate per 00147.jpg: x = -1, y = -1
# Frame 00147.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_148.jpg
# Nome frame formato per JSON: 00148.jpg
# Annotazioni trovate per 00148.jpg: x = -1, y = -1
# Frame 00148.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_149.jpg
# Nome frame formato per JSON: 00149.jpg
# Annotazioni trovate per 00149.jpg: x = -1, y = -1
# Frame 00149.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_150.jpg
# Nome frame formato per JSON: 00150.jpg
# Annotazioni trovate per 00150.jpg: x = -1, y = -1
# Frame 00150.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_151.jpg
# Nome frame formato per JSON: 00151.jpg
# Annotazioni trovate per 00151.jpg: x = -1, y = -1
# Frame 00151.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_152.jpg
# Nome frame formato per JSON: 00152.jpg
# Annotazioni trovate per 00152.jpg: x = -1, y = -1
# Frame 00152.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_153.jpg
# Nome frame formato per JSON: 00153.jpg
# Annotazioni trovate per 00153.jpg: x = -1, y = -1
# Frame 00153.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_154.jpg
# Nome frame formato per JSON: 00154.jpg
# Annotazioni trovate per 00154.jpg: x = -1, y = -1
# Frame 00154.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_155.jpg
# Nome frame formato per JSON: 00155.jpg
# Annotazioni trovate per 00155.jpg: x = -1, y = -1
# Frame 00155.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_156.jpg
# Nome frame formato per JSON: 00156.jpg
# Annotazioni trovate per 00156.jpg: x = -1, y = -1
# Frame 00156.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_157.jpg
# Nome frame formato per JSON: 00157.jpg
# Annotazioni trovate per 00157.jpg: x = -1, y = -1
# Frame 00157.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_158.jpg
# Nome frame formato per JSON: 00158.jpg
# Annotazioni trovate per 00158.jpg: x = -1, y = -1
# Frame 00158.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_159.jpg
# Nome frame formato per JSON: 00159.jpg
# Annotazioni trovate per 00159.jpg: x = -1, y = -1
# Frame 00159.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_160.jpg
# Nome frame formato per JSON: 00160.jpg
# Annotazioni trovate per 00160.jpg: x = -1, y = -1
# Frame 00160.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_161.jpg
# Nome frame formato per JSON: 00161.jpg
# Annotazioni trovate per 00161.jpg: x = -1, y = -1
# Frame 00161.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_162.jpg
# Nome frame formato per JSON: 00162.jpg
# Annotazioni trovate per 00162.jpg: x = -1, y = -1
# Frame 00162.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_163.jpg
# Nome frame formato per JSON: 00163.jpg
# Annotazioni trovate per 00163.jpg: x = -1, y = -1
# Frame 00163.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_164.jpg
# Nome frame formato per JSON: 00164.jpg
# Annotazioni trovate per 00164.jpg: x = -1, y = -1
# Frame 00164.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_165.jpg
# Nome frame formato per JSON: 00165.jpg
# Annotazioni trovate per 00165.jpg: x = -1, y = -1
# Frame 00165.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_166.jpg
# Nome frame formato per JSON: 00166.jpg
# Annotazioni trovate per 00166.jpg: x = -1, y = -1
# Frame 00166.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_167.jpg
# Nome frame formato per JSON: 00167.jpg
# Annotazioni trovate per 00167.jpg: x = -1, y = -1
# Frame 00167.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_168.jpg
# Nome frame formato per JSON: 00168.jpg
# Annotazioni trovate per 00168.jpg: x = -1, y = -1
# Frame 00168.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_169.jpg
# Nome frame formato per JSON: 00169.jpg
# Annotazioni trovate per 00169.jpg: x = -1, y = -1
# Frame 00169.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_170.jpg
# Nome frame formato per JSON: 00170.jpg
# Annotazioni trovate per 00170.jpg: x = -1, y = -1
# Frame 00170.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_171.jpg
# Nome frame formato per JSON: 00171.jpg
# Annotazioni trovate per 00171.jpg: x = -1, y = -1
# Frame 00171.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_172.jpg
# Nome frame formato per JSON: 00172.jpg
# Annotazioni trovate per 00172.jpg: x = -1, y = -1
# Frame 00172.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_173.jpg
# Nome frame formato per JSON: 00173.jpg
# Annotazioni trovate per 00173.jpg: x = -1, y = -1
# Frame 00173.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_174.jpg
# Nome frame formato per JSON: 00174.jpg
# Annotazioni trovate per 00174.jpg: x = -1, y = -1
# Frame 00174.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_175.jpg
# Nome frame formato per JSON: 00175.jpg
# Annotazioni trovate per 00175.jpg: x = -1, y = -1
# Frame 00175.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_176.jpg
# Nome frame formato per JSON: 00176.jpg
# Annotazioni trovate per 00176.jpg: x = -1, y = -1
# Frame 00176.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_177.jpg
# Nome frame formato per JSON: 00177.jpg
# Annotazioni trovate per 00177.jpg: x = -1, y = -1
# Frame 00177.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_178.jpg
# Nome frame formato per JSON: 00178.jpg
# Annotazioni trovate per 00178.jpg: x = -1, y = -1
# Frame 00178.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_179.jpg
# Nome frame formato per JSON: 00179.jpg
# Annotazioni trovate per 00179.jpg: x = -1, y = -1
# Frame 00179.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_180.jpg
# Nome frame formato per JSON: 00180.jpg
# Annotazioni trovate per 00180.jpg: x = -1, y = -1
# Frame 00180.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_181.jpg
# Nome frame formato per JSON: 00181.jpg
# Annotazioni trovate per 00181.jpg: x = -1, y = -1
# Frame 00181.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_182.jpg
# Nome frame formato per JSON: 00182.jpg
# Annotazioni trovate per 00182.jpg: x = -1, y = -1
# Frame 00182.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_183.jpg
# Nome frame formato per JSON: 00183.jpg
# Annotazioni trovate per 00183.jpg: x = -1, y = -1
# Frame 00183.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_184.jpg
# Nome frame formato per JSON: 00184.jpg
# Annotazioni trovate per 00184.jpg: x = -1, y = -1
# Frame 00184.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_185.jpg
# Nome frame formato per JSON: 00185.jpg
# Annotazioni trovate per 00185.jpg: x = -1, y = -1
# Frame 00185.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_186.jpg
# Nome frame formato per JSON: 00186.jpg
# Annotazioni trovate per 00186.jpg: x = -1, y = -1
# Frame 00186.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_187.jpg
# Nome frame formato per JSON: 00187.jpg
# Annotazioni trovate per 00187.jpg: x = -1, y = -1
# Frame 00187.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_188.jpg
# Nome frame formato per JSON: 00188.jpg
# Annotazioni trovate per 00188.jpg: x = -1, y = -1
# Frame 00188.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_189.jpg
# Nome frame formato per JSON: 00189.jpg
# Annotazioni trovate per 00189.jpg: x = -1, y = -1
# Frame 00189.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_190.jpg
# Nome frame formato per JSON: 00190.jpg
# Annotazioni trovate per 00190.jpg: x = -1, y = -1
# Frame 00190.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_191.jpg
# Nome frame formato per JSON: 00191.jpg
# Annotazioni trovate per 00191.jpg: x = -1, y = -1
# Frame 00191.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_192.jpg
# Nome frame formato per JSON: 00192.jpg
# Annotazioni trovate per 00192.jpg: x = -1, y = -1
# Frame 00192.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_193.jpg
# Nome frame formato per JSON: 00193.jpg
# Annotazioni trovate per 00193.jpg: x = -1, y = -1
# Frame 00193.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_194.jpg
# Nome frame formato per JSON: 00194.jpg
# Annotazioni trovate per 00194.jpg: x = -1, y = -1
# Frame 00194.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_195.jpg
# Nome frame formato per JSON: 00195.jpg
# Annotazioni trovate per 00195.jpg: x = -1, y = -1
# Frame 00195.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_196.jpg
# Nome frame formato per JSON: 00196.jpg
# Annotazioni trovate per 00196.jpg: x = -1, y = -1
# Frame 00196.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_197.jpg
# Nome frame formato per JSON: 00197.jpg
# Annotazioni trovate per 00197.jpg: x = -1, y = -1
# Frame 00197.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_198.jpg
# Nome frame formato per JSON: 00198.jpg
# Annotazioni trovate per 00198.jpg: x = -1, y = -1
# Frame 00198.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_199.jpg
# Nome frame formato per JSON: 00199.jpg
# Annotazioni trovate per 00199.jpg: x = -1, y = -1
# Frame 00199.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_200.jpg
# Nome frame formato per JSON: 00200.jpg
# Annotazioni trovate per 00200.jpg: x = -1, y = -1
# Frame 00200.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_201.jpg
# Nome frame formato per JSON: 00201.jpg
# Annotazioni trovate per 00201.jpg: x = -1, y = -1
# Frame 00201.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_202.jpg
# Nome frame formato per JSON: 00202.jpg
# Annotazioni trovate per 00202.jpg: x = -1, y = -1
# Frame 00202.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_203.jpg
# Nome frame formato per JSON: 00203.jpg
# Annotazioni trovate per 00203.jpg: x = -1, y = -1
# Frame 00203.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_204.jpg
# Nome frame formato per JSON: 00204.jpg
# Annotazioni trovate per 00204.jpg: x = -1, y = -1
# Frame 00204.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_205.jpg
# Nome frame formato per JSON: 00205.jpg
# Annotazioni trovate per 00205.jpg: x = -1, y = -1
# Frame 00205.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_206.jpg
# Nome frame formato per JSON: 00206.jpg
# Annotazioni trovate per 00206.jpg: x = -1, y = -1
# Frame 00206.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_207.jpg
# Nome frame formato per JSON: 00207.jpg
# Annotazioni trovate per 00207.jpg: x = -1, y = -1
# Frame 00207.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_208.jpg
# Nome frame formato per JSON: 00208.jpg
# Annotazioni trovate per 00208.jpg: x = -1, y = -1
# Frame 00208.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_209.jpg
# Nome frame formato per JSON: 00209.jpg
# Annotazioni trovate per 00209.jpg: x = -1, y = -1
# Frame 00209.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_210.jpg
# Nome frame formato per JSON: 00210.jpg
# Annotazioni trovate per 00210.jpg: x = -1, y = -1
# Frame 00210.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_211.jpg
# Nome frame formato per JSON: 00211.jpg
# Annotazioni trovate per 00211.jpg: x = -1, y = -1
# Frame 00211.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_212.jpg
# Nome frame formato per JSON: 00212.jpg
# Annotazioni trovate per 00212.jpg: x = -1, y = -1
# Frame 00212.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_213.jpg
# Nome frame formato per JSON: 00213.jpg
# Annotazioni trovate per 00213.jpg: x = -1, y = -1
# Frame 00213.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_214.jpg
# Nome frame formato per JSON: 00214.jpg
# Annotazioni trovate per 00214.jpg: x = -1, y = -1
# Frame 00214.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_215.jpg
# Nome frame formato per JSON: 00215.jpg
# Annotazioni trovate per 00215.jpg: x = -1, y = -1
# Frame 00215.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_216.jpg
# Nome frame formato per JSON: 00216.jpg
# Annotazioni trovate per 00216.jpg: x = -1, y = -1
# Frame 00216.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_217.jpg
# Nome frame formato per JSON: 00217.jpg
# Annotazioni trovate per 00217.jpg: x = -1, y = -1
# Frame 00217.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_218.jpg
# Nome frame formato per JSON: 00218.jpg
# Annotazioni trovate per 00218.jpg: x = -1, y = -1
# Frame 00218.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_219.jpg
# Nome frame formato per JSON: 00219.jpg
# Annotazioni trovate per 00219.jpg: x = -1, y = -1
# Frame 00219.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_220.jpg
# Nome frame formato per JSON: 00220.jpg
# Annotazioni trovate per 00220.jpg: x = -1, y = -1
# Frame 00220.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_221.jpg
# Nome frame formato per JSON: 00221.jpg
# Annotazioni trovate per 00221.jpg: x = -1, y = -1
# Frame 00221.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_222.jpg
# Nome frame formato per JSON: 00222.jpg
# Annotazioni trovate per 00222.jpg: x = -1, y = -1
# Frame 00222.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_223.jpg
# Nome frame formato per JSON: 00223.jpg
# Annotazioni trovate per 00223.jpg: x = -1, y = -1
# Frame 00223.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_224.jpg
# Nome frame formato per JSON: 00224.jpg
# Annotazioni trovate per 00224.jpg: x = -1, y = -1
# Frame 00224.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_225.jpg
# Nome frame formato per JSON: 00225.jpg
# Annotazioni trovate per 00225.jpg: x = -1, y = -1
# Frame 00225.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_226.jpg
# Nome frame formato per JSON: 00226.jpg
# Annotazioni trovate per 00226.jpg: x = -1, y = -1
# Frame 00226.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_227.jpg
# Nome frame formato per JSON: 00227.jpg
# Annotazioni trovate per 00227.jpg: x = -1, y = -1
# Frame 00227.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_228.jpg
# Nome frame formato per JSON: 00228.jpg
# Annotazioni trovate per 00228.jpg: x = -1, y = -1
# Frame 00228.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_229.jpg
# Nome frame formato per JSON: 00229.jpg
# Annotazioni trovate per 00229.jpg: x = -1, y = -1
# Frame 00229.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_230.jpg
# Nome frame formato per JSON: 00230.jpg
# Annotazioni trovate per 00230.jpg: x = -1, y = -1
# Frame 00230.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_231.jpg
# Nome frame formato per JSON: 00231.jpg
# Annotazioni trovate per 00231.jpg: x = -1, y = -1
# Frame 00231.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_232.jpg
# ...
# Processando il frame: frame_2923.jpg
# Nome frame formato per JSON: 02923.jpg
# Annotazioni trovate per 02923.jpg: x = -1, y = -1
# Frame 02923.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2924.jpg
# Nome frame formato per JSON: 02924.jpg
# Annotazioni trovate per 02924.jpg: x = -1, y = -1
# Frame 02924.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2925.jpg
# Nome frame formato per JSON: 02925.jpg
# Annotazioni trovate per 02925.jpg: x = -1, y = -1
# Frame 02925.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2926.jpg
# Nome frame formato per JSON: 02926.jpg
# Annotazioni trovate per 02926.jpg: x = -1, y = -1
# Frame 02926.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2927.jpg
# Nome frame formato per JSON: 02927.jpg
# Annotazioni trovate per 02927.jpg: x = -1, y = -1
# Frame 02927.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2928.jpg
# Nome frame formato per JSON: 02928.jpg
# Annotazioni trovate per 02928.jpg: x = -1, y = -1
# Frame 02928.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2929.jpg
# Nome frame formato per JSON: 02929.jpg
# Annotazioni trovate per 02929.jpg: x = -1, y = -1
# Frame 02929.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2930.jpg
# Nome frame formato per JSON: 02930.jpg
# Annotazioni trovate per 02930.jpg: x = -1, y = -1
# Frame 02930.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2931.jpg
# Nome frame formato per JSON: 02931.jpg
# Annotazioni trovate per 02931.jpg: x = -1, y = -1
# Frame 02931.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2932.jpg
# Nome frame formato per JSON: 02932.jpg
# Annotazioni trovate per 02932.jpg: x = -1, y = -1
# Frame 02932.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2933.jpg
# Nome frame formato per JSON: 02933.jpg
# Annotazioni trovate per 02933.jpg: x = -1, y = -1
# Frame 02933.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2934.jpg
# Nome frame formato per JSON: 02934.jpg
# Annotazioni trovate per 02934.jpg: x = -1, y = -1
# Frame 02934.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2935.jpg
# Nome frame formato per JSON: 02935.jpg
# Annotazioni trovate per 02935.jpg: x = -1, y = -1
# Frame 02935.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2936.jpg
# Nome frame formato per JSON: 02936.jpg
# Annotazioni trovate per 02936.jpg: x = -1, y = -1
# Frame 02936.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2937.jpg
# Nome frame formato per JSON: 02937.jpg
# Annotazioni trovate per 02937.jpg: x = -1, y = -1
# Frame 02937.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2938.jpg
# Nome frame formato per JSON: 02938.jpg
# Annotazioni trovate per 02938.jpg: x = -1, y = -1
# Frame 02938.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2939.jpg
# Nome frame formato per JSON: 02939.jpg
# Annotazioni trovate per 02939.jpg: x = -1, y = -1
# Frame 02939.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2940.jpg
# Nome frame formato per JSON: 02940.jpg
# Annotazioni trovate per 02940.jpg: x = -1, y = -1
# Frame 02940.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2941.jpg
# Nome frame formato per JSON: 02941.jpg
# Annotazioni trovate per 02941.jpg: x = -1, y = -1
# Frame 02941.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2942.jpg
# Nome frame formato per JSON: 02942.jpg
# Annotazioni trovate per 02942.jpg: x = -1, y = -1
# Frame 02942.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2943.jpg
# Nome frame formato per JSON: 02943.jpg
# Annotazioni trovate per 02943.jpg: x = -1, y = -1
# Frame 02943.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2944.jpg
# Nome frame formato per JSON: 02944.jpg
# Annotazioni trovate per 02944.jpg: x = -1, y = -1
# Frame 02944.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2945.jpg
# Nome frame formato per JSON: 02945.jpg
# Annotazioni trovate per 02945.jpg: x = -1, y = -1
# Frame 02945.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2946.jpg
# Nome frame formato per JSON: 02946.jpg
# Annotazioni trovate per 02946.jpg: x = -1, y = -1
# Frame 02946.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2947.jpg
# Nome frame formato per JSON: 02947.jpg
# Annotazioni trovate per 02947.jpg: x = -1, y = -1
# Frame 02947.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2948.jpg
# Nome frame formato per JSON: 02948.jpg
# Annotazioni trovate per 02948.jpg: x = -1, y = -1
# Frame 02948.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2949.jpg
# Nome frame formato per JSON: 02949.jpg
# Annotazioni trovate per 02949.jpg: x = -1, y = -1
# Frame 02949.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2950.jpg
# Nome frame formato per JSON: 02950.jpg
# Annotazioni trovate per 02950.jpg: x = -1, y = -1
# Frame 02950.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2951.jpg
# Nome frame formato per JSON: 02951.jpg
# Annotazioni trovate per 02951.jpg: x = -1, y = -1
# Frame 02951.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2952.jpg
# Nome frame formato per JSON: 02952.jpg
# Annotazioni trovate per 02952.jpg: x = -1, y = -1
# Frame 02952.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2953.jpg
# Nome frame formato per JSON: 02953.jpg
# Annotazioni trovate per 02953.jpg: x = -1, y = -1
# Frame 02953.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2954.jpg
# Nome frame formato per JSON: 02954.jpg
# Annotazioni trovate per 02954.jpg: x = -1, y = -1
# Frame 02954.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2955.jpg
# Nome frame formato per JSON: 02955.jpg
# Annotazioni trovate per 02955.jpg: x = -1, y = -1
# Frame 02955.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2956.jpg
# Nome frame formato per JSON: 02956.jpg
# Annotazioni trovate per 02956.jpg: x = -1, y = -1
# Frame 02956.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2957.jpg
# Nome frame formato per JSON: 02957.jpg
# Annotazioni trovate per 02957.jpg: x = -1, y = -1
# Frame 02957.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2958.jpg
# Nome frame formato per JSON: 02958.jpg
# Annotazioni trovate per 02958.jpg: x = -1, y = -1
# Frame 02958.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2959.jpg
# Nome frame formato per JSON: 02959.jpg
# Annotazioni trovate per 02959.jpg: x = -1, y = -1
# Frame 02959.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2960.jpg
# Nome frame formato per JSON: 02960.jpg
# Annotazioni trovate per 02960.jpg: x = -1, y = -1
# Frame 02960.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2961.jpg
# Nome frame formato per JSON: 02961.jpg
# Annotazioni trovate per 02961.jpg: x = -1, y = -1
# Frame 02961.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2962.jpg
# Nome frame formato per JSON: 02962.jpg
# Annotazioni trovate per 02962.jpg: x = -1, y = -1
# Frame 02962.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2963.jpg
# Nome frame formato per JSON: 02963.jpg
# Annotazioni trovate per 02963.jpg: x = -1, y = -1
# Frame 02963.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2964.jpg
# Nome frame formato per JSON: 02964.jpg
# Annotazioni trovate per 02964.jpg: x = -1, y = -1
# Frame 02964.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2965.jpg
# Nome frame formato per JSON: 02965.jpg
# Annotazioni trovate per 02965.jpg: x = -1, y = -1
# Frame 02965.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2966.jpg
# Nome frame formato per JSON: 02966.jpg
# Annotazioni trovate per 02966.jpg: x = -1, y = -1
# Frame 02966.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2967.jpg
# Nome frame formato per JSON: 02967.jpg
# Annotazioni trovate per 02967.jpg: x = -1, y = -1
# Frame 02967.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2968.jpg
# Nome frame formato per JSON: 02968.jpg
# Annotazioni trovate per 02968.jpg: x = -1, y = -1
# Frame 02968.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2969.jpg
# Nome frame formato per JSON: 02969.jpg
# Annotazioni trovate per 02969.jpg: x = -1, y = -1
# Frame 02969.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2970.jpg
# Nome frame formato per JSON: 02970.jpg
# Annotazioni trovate per 02970.jpg: x = -1, y = -1
# Frame 02970.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2971.jpg
# Nome frame formato per JSON: 02971.jpg
# Annotazioni trovate per 02971.jpg: x = -1, y = -1
# Frame 02971.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2972.jpg
# Nome frame formato per JSON: 02972.jpg
# Annotazioni trovate per 02972.jpg: x = -1, y = -1
# Frame 02972.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2973.jpg
# Nome frame formato per JSON: 02973.jpg
# Annotazioni trovate per 02973.jpg: x = -1, y = -1
# Frame 02973.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2974.jpg
# Nome frame formato per JSON: 02974.jpg
# Annotazioni trovate per 02974.jpg: x = -1, y = -1
# Frame 02974.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2975.jpg
# Nome frame formato per JSON: 02975.jpg
# Annotazioni trovate per 02975.jpg: x = -1, y = -1
# Frame 02975.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2976.jpg
# Nome frame formato per JSON: 02976.jpg
# Annotazioni trovate per 02976.jpg: x = -1, y = -1
# Frame 02976.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2977.jpg
# Nome frame formato per JSON: 02977.jpg
# Annotazioni trovate per 02977.jpg: x = -1, y = -1
# Frame 02977.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2978.jpg
# Nome frame formato per JSON: 02978.jpg
# Annotazioni trovate per 02978.jpg: x = -1, y = -1
# Frame 02978.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2979.jpg
# Nome frame formato per JSON: 02979.jpg
# Annotazioni trovate per 02979.jpg: x = -1, y = -1
# Frame 02979.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2980.jpg
# Nome frame formato per JSON: 02980.jpg
# Annotazioni trovate per 02980.jpg: x = -1, y = -1
# Frame 02980.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2981.jpg
# Nome frame formato per JSON: 02981.jpg
# Annotazioni trovate per 02981.jpg: x = -1, y = -1
# Frame 02981.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2982.jpg
# Nome frame formato per JSON: 02982.jpg
# Annotazioni trovate per 02982.jpg: x = -1, y = -1
# Frame 02982.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2983.jpg
# Nome frame formato per JSON: 02983.jpg
# Annotazioni trovate per 02983.jpg: x = -1, y = -1
# Frame 02983.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2984.jpg
# Nome frame formato per JSON: 02984.jpg
# Annotazioni trovate per 02984.jpg: x = -1, y = -1
# Frame 02984.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2985.jpg
# Nome frame formato per JSON: 02985.jpg
# Annotazioni trovate per 02985.jpg: x = -1, y = -1
# Frame 02985.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2986.jpg
# Nome frame formato per JSON: 02986.jpg
# Annotazioni trovate per 02986.jpg: x = -1, y = -1
# Frame 02986.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2987.jpg
# Nome frame formato per JSON: 02987.jpg
# Annotazioni trovate per 02987.jpg: x = -1, y = -1
# Frame 02987.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2988.jpg
# Nome frame formato per JSON: 02988.jpg
# Annotazioni trovate per 02988.jpg: x = -1, y = -1
# Frame 02988.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2989.jpg
# Nome frame formato per JSON: 02989.jpg
# Annotazioni trovate per 02989.jpg: x = -1, y = -1
# Frame 02989.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2990.jpg
# Nome frame formato per JSON: 02990.jpg
# Annotazioni trovate per 02990.jpg: x = -1, y = -1
# Frame 02990.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2991.jpg
# Nome frame formato per JSON: 02991.jpg
# Annotazioni trovate per 02991.jpg: x = -1, y = -1
# Frame 02991.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2992.jpg
# Nome frame formato per JSON: 02992.jpg
# Annotazioni trovate per 02992.jpg: x = -1, y = -1
# Frame 02992.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2993.jpg
# Nome frame formato per JSON: 02993.jpg
# Annotazioni trovate per 02993.jpg: x = -1, y = -1
# Frame 02993.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2994.jpg
# Nome frame formato per JSON: 02994.jpg
# Annotazioni trovate per 02994.jpg: x = -1, y = -1
# Frame 02994.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2995.jpg
# Nome frame formato per JSON: 02995.jpg
# Annotazioni trovate per 02995.jpg: x = -1, y = -1
# Frame 02995.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2996.jpg
# Nome frame formato per JSON: 02996.jpg
# Annotazioni trovate per 02996.jpg: x = -1, y = -1
# Frame 02996.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2997.jpg
# Nome frame formato per JSON: 02997.jpg
# Annotazioni trovate per 02997.jpg: x = -1, y = -1
# Frame 02997.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2998.jpg
# Nome frame formato per JSON: 02998.jpg
# Annotazioni trovate per 02998.jpg: x = -1, y = -1
# Frame 02998.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Processando il frame: frame_2999.jpg
# Nome frame formato per JSON: 02999.jpg
# Annotazioni trovate per 02999.jpg: x = -1, y = -1
# Frame 02999.jpg con annotazione (-1,-1), aggiunto alla traccia ma senza cerchio.
# Video salvato come: /kaggle/working/video_6.avi
